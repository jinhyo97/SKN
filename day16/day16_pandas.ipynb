# %%
import pandas as pd
import numpy as np

# %%
np.array([[1, 2], [3, 4], [5, 6]]) + np.array([1, 2]) # np.array([[1, 2], [1, 2], [1, 2]])

# %%
np.random.rand(10, 5)
# Out:
# array([[0.11131869, 0.23122973, 0.89842662, 0.04443296, 0.59055779],
#        [0.51104678, 0.56041613, 0.75428939, 0.33199728, 0.49260416],
#        [0.20013319, 0.26653197, 0.40498024, 0.00289395, 0.45033039],
#        [0.49373264, 0.70203608, 0.85960268, 0.24733029, 0.8338275 ],
#        [0.19478698, 0.09365288, 0.20361867, 0.70840082, 0.34482881],
#        [0.17219851, 0.03008464, 0.1112176 , 0.01615473, 0.03565228],
#        [0.99526417, 0.75150831, 0.54652524, 0.64350704, 0.41618427],
#        [0.54846646, 0.55493997, 0.07205789, 0.32602013, 0.16187684],
#        [0.18683292, 0.59091155, 0.79344937, 0.60631552, 0.51834925],
#        [0.67267461, 0.65902823, 0.31826499, 0.96702638, 0.55645224]])

# %%
pd.DataFrame(np.random.rand(10, 5), columns=['X1', 'X2', 'X3', 'X4', 'X5'])
# Out:
#          X1        X2        X3        X4        X5
# 0  0.240174  0.003610  0.669428  0.734732  0.159670
# 1  0.169696  0.435944  0.526259  0.029255  0.423391
# 2  0.799578  0.461535  0.517846  0.555393  0.984713
# 3  0.149775  0.083216  0.459076  0.413674  0.601983
# 4  0.727785  0.625271  0.480517  0.859753  0.143153
# 5  0.779276  0.564432  0.363058  0.609327  0.559494
# 6  0.261384  0.858040  0.771521  0.067648  0.402399
# 7  0.472597  0.728133  0.708038  0.460823  0.583334
# 8  0.011452  0.902730  0.366087  0.133119  0.597175
# 9  0.422105  0.271543  0.238002  0.230329  0.809209

# %% [markdown]
# # Pandas

# %% [markdown]
# ##  Series
#
# Numpy와 유사하나 index를 가지고 있음

# %% [markdown]
# ### 생성
#
# ```python
# series = pd.Series(
#   [90, 85, 80, 75, 70]
#   ) # 인덱스를 지정하지 않으면 0부터 시작
#
# series = pd.Series(
#   [90, 85, 80, 75, 70],
#   index=['국', '영', '수', '사', '과']
#   )
# ```

# %%
pd.Series([90, 85, 80, 75, 85], dtype=np.int32)
# Out:
# 0    90
# 1    85
# 2    80
# 3    75
# 4    85
# dtype: int32

# %%
pd.Series(
    [90, 85, 80, 75, 85],
    index=['국', '영', '수', '사', '과'],
    dtype=np.int32,
)
# Out:
# 국    90
# 영    85
# 수    80
# 사    75
# 과    85
# dtype: int32

# %% [markdown]
# ### 추가, 변경, 삭제
# 기존 딕셔너리의 추가, 변경, 삭제와 동일 <br>
# <br>
#
# 추가
# ```python
# series['한국사'] = 100
# ```
# <br>
#
# 변경
# ```python
# series['국'] = 100
# series.국 = 100
# ```
# <br>
#
# 삭제
# ```python
# del series['국']
# ```

# %%
series = pd.Series(
    [90, 85, 80, 75, 85],
    index=['국', '영', '수', '사', '과'],
)

# %%
series['코'] = 90
series
# Out:
# 국    90
# 영    85
# 수    80
# 사    75
# 과    85
# 코    90
# dtype: int64

# %%
series['국'] = 80
series
# Out:
# 국    80
# 영    85
# 수    80
# 사    75
# 과    85
# 코    90
# dtype: int64

# %%
series.과 = 100
series
# Out:
# 국     80
# 영     85
# 수     80
# 사     75
# 과    100
# 코     90
# dtype: int64

# %%
series.체 = 100
series
# Out:
# 국     80
# 영     85
# 수     80
# 사     75
# 과    100
# 코     90
# dtype: int64

# %%
del series['코']

# %%
series
# Out:
# 국     80
# 영     85
# 수     80
# 사     75
# 과    100
# dtype: int64

# %% [markdown]
# ### name
# name 속성을 이용하여 series와 index에 이름 부여 가능
#
# ```python
# series.name = '성적'
# series.index.name = '과목'
# ```

# %%
series = pd.Series(
    [90, 85, 80, 75, 85],
    index=['국', '영', '수', '사', '과'],
)
series.name = '성적'
series
# Out:
# 국    90
# 영    85
# 수    80
# 사    75
# 과    85
# Name: 성적, dtype: int64

# %%
series.to_frame()
# Out:
#    성적
# 국  90
# 영  85
# 수  80
# 사  75
# 과  85

# %%
series = pd.Series(
    [90, 85, 80, 75, 85],
    index=['국', '영', '수', '사', '과'],
)
series.to_frame()
# Out:
#     0
# 국  90
# 영  85
# 수  80
# 사  75
# 과  85

# %%
series = pd.Series(
    [90, 85, 80, 75, 85],
    index=['국', '영', '수', '사', '과'],
)
series.name = '성적'
series.index.name = '성적'
series
# Out:
# 성적
# 국    90
# 영    85
# 수    80
# 사    75
# 과    85
# Name: 성적, dtype: int64

# %% [markdown]
# ### indexing
#
# ```python
# series[0], series['국']    # 특정 인덱스 번호 혹은 이름 지정
# series.국
#
# series[[0, 2, 1]]         # 인덱스 순서를 원하는 순서대로 변경하여 출력
# series[['국', '수', '영']]  # 인덱스 순서를 원하는 순서대로 변경하여 출력
#
# series[0:3]            # 슬라이싱
# series['국어':'수학']    # 슬라이싱, 끝 점 포함
# ```

# %%
series = pd.Series(
    [90, 85, 80, 75, 85],
    index=['국', '영', '수', '사', '과'],
)
series
# Out:
# 국    90
# 영    85
# 수    80
# 사    75
# 과    85
# dtype: int64

# %%
# series['수']
# series.수
series[2]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2224\4011047527.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   series[2]
# 80

# %%
x = np.array([1, 2, 3, 4, 5])
# np.extract(x%2==0, x)
# x[[1, 3]]
x[x%2==0] # x[[False, True, False, True, False]]
# Out:
# array([2, 4])

# %%
series = pd.Series(
    [90, 85, 80, 75, 85],
    index=['국', '영', '수', '사', '과'],
)
print(series)
print('-'*30)
print(series%2==0)
print('-'*30)
print(series[series%2==0])
# Out:
# 국    90
# 영    85
# 수    80
# 사    75
# 과    85
# dtype: int64
# ------------------------------
# 국     True
# 영    False
# 수     True
# 사    False
# 과    False
# dtype: bool
# ------------------------------
# 국    90
# 수    80
# dtype: int64

# %%
series[[0, 2]]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2224\1355500855.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   series[[0, 2]]
# 국    90
# 수    80
# dtype: int64

# %%
series[[True, False, True, False, False]]
# Out:
# 국    90
# 수    80
# dtype: int64

# %% [markdown]
# ### series 연산
#
# series끼리 연산 진행 가능 <br>
# 다만, series 연산은 동일 index끼리 연산이므로 index 정보가 다르면 연산 불가 <br>
# <br>
#
# ```python
# series1 = pd.Series(
#   [90, 85, 80, 75, 70],
#   index=['국', '영', '수', '사', '과']
#   )
#
# series2 = pd.Series(
#   [95, 80, 70, 80, 95],
#   index=['국', '영', '수', '사', '과']
#   )
# ```

# %%
series1 = pd.Series(
    [90, 85, 80, 75, 85],
    index=['국', '영', '수', '사', '과'],
)

series2 = pd.Series(
    [90, 85, 80, 75, 85],
    index=['국', '영', '수', '사', '과'],
)

series1 + series2
# Out:
# 국    180
# 영    170
# 수    160
# 사    150
# 과    170
# dtype: int64

# %%
series1 = pd.Series(
    [90, 75, 85, 85, 80],
    index=['국', '사', '과', '영', '수'],
)

series2 = pd.Series(
    [90, 85, 80, 75, 85],
    index=['국', '영', '수', '사', '과'],
)

series1 + series2
# Out:
# 과    170
# 국    180
# 사    150
# 수    160
# 영    170
# dtype: int64

# %%
series1 = pd.Series(
    [90, 75, 85, 85, 80],
    index=['국', '영', '수', '사', '코'],
)

series2 = pd.Series(
    [90, 85, 80, 75, 85],
    index=['국', '영', '수', '사', '과'],
)

series1 + series2
# Out:
# 과      NaN
# 국    180.0
# 사    160.0
# 수    165.0
# 영    160.0
# 코      NaN
# dtype: float64

# %% [markdown]
# ##  DataFrame
#
# Series가 1d 행렬에 index를 추가한 것과 같이 <br>
# DataFrame은 2d 행렬에 index와 column을 추가한 것 <br>
# 혹은 여러 Series의 합 <br>

# %% [markdown]
# ### 판다스 기초

# %% [markdown]
# #### 생성
#
# 딕셔너리 기반
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
# df
# ```
# <br>
# <br>
#
# 배열 기반
# ```python
# data = [
#   [90, 95, 85],
#   [85, 80, 95],
#   [80, 70, 90],
#   [75, 80, 70],
#   [70, 95, 85]
# ]
#
# index = ['국', '영', '수', '사', '과']
# columns = ['학생1', '학생2', '학생3']
# df = pd.DataFrame(data, index=index, columns=columns)
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 90, 85, 80, 75],
    '학생3': [85, 95, 90, 70, 85],
}
pd.DataFrame(data)
# Out:
#    학생1  학생2  학생3
# 0   90   95   85
# 1   85   90   95
# 2   80   85   90
# 3   75   80   70
# 4   70   75   85

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 90, 85, 80, 75],
    '학생3': [85, 95, 90, 70, 85],
}
pd.DataFrame(data, index=['국', '영', '수', '사', '과'])
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   90   95
# 수   80   85   90
# 사   75   80   70
# 과   70   75   85

# %%
pd.DataFrame(
    np.array([
        [90, 95, 85],
        [85, 90, 95],
        [80, 85, 90],
        [75, 80, 70],
        [70, 75, 85],
    ]),
    columns=['학생1', '학생2', '학생3']
)
# Out:
#    학생1  학생2  학생3
# 0   90   95   85
# 1   85   90   95
# 2   80   85   90
# 3   75   80   70
# 4   70   75   85

# %%
pd.DataFrame(
    np.array([
        [90, 95, 85],
        [85, 90, 95],
        [80, 85, 90],
        [75, 80, 70],
        [70, 75, 85],
    ]),
    columns=['학생1', '학생2', '학생3'],
    index=['국']
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 pd.DataFrame(
#       2     np.array([
#       3         [90, 95, 85],
#       4         [85, 90, 95],
#       5         [80, 85, 90],
#       6         [75, 80, 70],
#       7         [70, 75, 85],
#       8     ]),
#       9     columns=['학생1', '학생2', '학생3'],
#      10     index=['국']
#      11 )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)
#     824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
#     832             copy=copy,
#     833             typ=manager,
#     834         )
#     836 # For data is list-like, or Iterable (will consume into list)
#     837 elif is_list_like(data):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (5, 3), indices imply (1, 3)

# %% [markdown]
# #### 추가, 변경, 삭제
# **추가** <br>
# DataFrame의 추가는 기본적으로 열 단위 추가
#
# ```python
# # 현재 row는 국, 영, 수, 사, 과의 5개 정보인데 1개 정보만 추가하게 되면, 이 값을 전체에 복사
# # 즉, 모든 row 값을 90으로 채움
# df['학생4'] = 90
#
# # 만약 2개 이상의 값을 넣고 싶으면 배열을 이용하여 넣어야 함
# # 이 경우 row수와 일치하지 않으면 에러 발생
# df['학생4'] = [90, 80]     # 에러
# df['학생4'] = [90, 80, 70, 60, 50]
# ```
# <br>
#
# **변경** <br>
# 데이터프레임.컬럼.인덱스 = 변경값 <br>
# 기존 컬럼이 존재하면 생성과 유사하게 동작
# ```python
# df.학생3.국 = 100
# df['학생3'] = 100    # df.학생3 = 100
# df['학생3'] = [100, 99, 98, 97, 96]    # df.학생3 = [100, 99, 98, 97, 96]
# ```
#
#
#
# **삭제**
# ```python
# del df['학생4']
# df.drop(columns='학생4')
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 90, 85, 80, 75],
    '학생3': [85, 95, 90, 70, 85],
}
df = pd.DataFrame(data, index=['국', '영', '수', '사', '과'])

# %%
df['학생4'] = 90
print(df)
print('-'*30)
df['학생4'] = [100, 90, 80, 70, 60]
print(df)
print('-'*30)
df['학생4'] = [100, 90, 80]
print(df)
# Out:
#    학생1  학생2  학생3  학생4
# 국   90   95   85   90
# 영   85   90   95   90
# 수   80   85   90   90
# 사   75   80   70   90
# 과   70   75   85   90
# ------------------------------
#    학생1  학생2  학생3  학생4
# 국   90   95   85  100
# 영   85   90   95   90
# 수   80   85   90   80
# 사   75   80   70   70
# 과   70   75   85   60
# ------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 7
#       5 print(df)
#       6 print('-'*30)
# ----> 7 df['학생4'] = [100, 90, 80]
#       8 print(df)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (3) does not match length of index (5)

# %%
data = {
    '학생1': [90, 85, 80, 75],
    '학생2': [95, 90, 85, 80],
    '학생3': [85, 95, 90, 70],
}
df = pd.DataFrame(data, index=['국', '영', '수', '사'])
df['학생4'] = [100, 90]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 7
#       1 data = {
#       2     '학생1': [90, 85, 80, 75],
#       3     '학생2': [95, 90, 85, 80],
#       4     '학생3': [85, 95, 90, 70],
#       5 }
#       6 df = pd.DataFrame(data, index=['국', '영', '수', '사'])
# ----> 7 df['학생4'] = [100, 90]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (2) does not match length of index (4)

# %%
df.학생1.국 = 100
display(df)
df.학생3 = 100
display(df)
df.학생3 = [90, 80, 70, 60]
display(df)
# Out:
#    학생1  학생2  학생3
# 국  100   95  100
# 영   85   90  100
# 수   80   85  100
# 사   75   80  100
#    학생1  학생2  학생3
# 국  100   95  100
# 영   85   90  100
# 수   80   85  100
# 사   75   80  100
#    학생1  학생2  학생3
# 국  100   95   90
# 영   85   90   80
# 수   80   85   70
# 사   75   80   60

# %%
df.학생3[1:] = [70, 80, 90]
df
# Out:
#    학생1  학생2  학생3
# 국  100   95   90
# 영   85   90   70
# 수   80   85   80
# 사   75   80   90

# %%
del df['학생3']
df
# Out:
#    학생1  학생2
# 국  100   95
# 영   85   90
# 수   80   85
# 사   75   80

# %%
display(df.drop(columns=['학생2']))
display(df)
# Out:
#    학생1
# 국  100
# 영   85
# 수   80
# 사   75
#    학생1  학생2
# 국  100   95
# 영   85   90
# 수   80   85
# 사   75   80

# %% [markdown]
# #### name
#
# Series에서와 마찬가지로 이름을 지정할 수 있음 <br>
# 다만, DataFrame은 2차원이므로 index와 column 모두에 이름 지정 가능 <br>
#
# ```python
# df.index.name = '과목'
# df.columns.name = '학생'
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 90, 85, 80, 75],
    '학생3': [85, 95, 90, 70, 85],
}
df = pd.DataFrame(data, index=['국', '영', '수', '사', '과'])

df.index.name = '과목'
df
# Out:
#     학생1  학생2  학생3
# 과목
# 국    90   95   85
# 영    85   90   95
# 수    80   85   90
# 사    75   80   70
# 과    70   75   85

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 90, 85, 80, 75],
    '학생3': [85, 95, 90, 70, 85],
}
df = pd.DataFrame(data, index=['국', '영', '수', '사', '과'])

df.columns.name = '학생'
df
# Out:
# 학생  학생1  학생2  학생3
# 국    90   95   85
# 영    85   90   95
# 수    80   85   90
# 사    75   80   70
# 과    70   75   85

# %% [markdown]
# #### column 이름 변경
# dataframe의 column 정보는 df.columns에 저장 <br>
# 여기에 저장된 값을 다른 값으로 입력하면 변경 가능 <br>
# 단, 열 전체 정보를 입력해야 함 (열 개수와 입력 값이 일치하지 않으면 에러) <br>
# 개별 column 이름을 변경하고 싶으면 rename 사용
# <br>
#
# ```python
# df.columns
# df.columns = '학생4'    # 에러
# df.columns = ['학생4']  # 에러
# df.rename(columns={'학생1': '학생4'})
# df.columns = ['학생4', '학생5', '학생6']
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 90, 85, 80, 75],
    '학생3': [85, 95, 90, 70, 85],
}
df = pd.DataFrame(data, index=['국', '영', '수', '사', '과'])

df.columns = ['재수생1', '재수생2', '재수생3']
df
# Out:
#    재수생1  재수생2  재수생3
# 국    90    95    85
# 영    85    90    95
# 수    80    85    90
# 사    75    80    70
# 과    70    75    85

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 90, 85, 80, 75],
    '학생3': [85, 95, 90, 70, 85],
}
df = pd.DataFrame(data, index=['국', '영', '수', '사', '과'])

df.columns = '재수생1' # df.columns = ['재수생1']
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 9
#       6 df = pd.DataFrame(data, index=['국', '영', '수', '사', '과'])
#       8 # df.columns = ['재수생1']
# ----> 9 df.columns = '재수생1'
#      10 df
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:813, in NDFrame._set_axis(self, axis, labels)
#     807 @final
#     808 def _set_axis(self, axis: AxisInt, labels: AnyArrayLike | list) -> None:
#     809     """
#     810     This is called from the cython code when we set the `index` attribute
#     811     directly, e.g. `series.index = [1, 2, 3]`.
#     812     """
# --> 813     labels = ensure_index(labels)
#     814     self._mgr.set_axis(axis, labels)
#     815     self._clear_item_cache()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7649, in ensure_index(index_like, copy)
#    7647         return Index(index_like, copy=copy, tupleize_cols=False)
#    7648 else:
# -> 7649     return Index(index_like, copy=copy)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:526, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     523         data = com.asarray_tuplesafe(data, dtype=_dtype_obj)
#     525 elif is_scalar(data):
# --> 526     raise cls._raise_scalar_data_error(data)
#     527 elif hasattr(data, "__array__"):
#     528     return cls(np.asarray(data), dtype=dtype, copy=copy, name=name)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5289, in Index._raise_scalar_data_error(cls, data)
#    5284 @final
#    5285 @classmethod
#    5286 def _raise_scalar_data_error(cls, data):
#    5287     # We return the TypeError so that we can raise it from the constructor
#    5288     #  in order to keep mypy happy
# -> 5289     raise TypeError(
#    5290         f"{cls.__name__}(...) must be called with a collection of some "
#    5291         f"kind, {repr(data) if not isinstance(data, np.generic) else str(data)} "
#    5292         "was passed"
#    5293     )
#
# TypeError: Index(...) must be called with a collection of some kind, '재수생1' was passed

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 90, 85, 80, 75],
    '학생3': [85, 95, 90, 70, 85],
}
df = pd.DataFrame(data, index=['국', '영', '수', '사', '과'])

display(df.rename(columns={'학생1': '재수생1'}))
display(df)
df = df.rename(columns={'학생1': '재수생1'})
display(df)
# Out:
#    재수생1  학생2  학생3
# 국    90   95   85
# 영    85   90   95
# 수    80   85   90
# 사    75   80   70
# 과    70   75   85
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   90   95
# 수   80   85   90
# 사   75   80   70
# 과   70   75   85
#    재수생1  학생2  학생3
# 국    90   95   85
# 영    85   90   95
# 수    80   85   90
# 사    75   80   70
# 과    70   75   85

# %%
display(df.rename(columns={'학생2': '재수생2'}))
display(df)
df.rename(columns={'학생2': '재수생2'}, inplace=True)   # 연산 효율이 좋지 않음
df = df.rename(columns={'학생2': '재수생2'})
display(df)
# Out:
#    재수생1  재수생2  학생3
# 국    90    95   85
# 영    85    90   95
# 수    80    85   90
# 사    75    80   70
# 과    70    75   85
#    재수생1  학생2  학생3
# 국    90   95   85
# 영    85   90   95
# 수    80   85   90
# 사    75   80   70
# 과    70   75   85
#    재수생1  재수생2  학생3
# 국    90    95   85
# 영    85    90   95
# 수    80    85   90
# 사    75    80   70
# 과    70    75   85

# %% [markdown]
# #### indexing
# **column** <br>
# ```python
# df['학생1']           # Series 반환
# df[['학생1']]         # DataFrame 반환
# df[['학생1', '학생2']] # 다수의 컬럼 선택
# ```
# <br>
#
# **row** <br>
# 항상 슬라이싱(:) 사용
# ```python
# df[:1]
# df[1:3]
# df['국':'수']
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 90, 85, 80, 75],
    '학생3': [85, 95, 90, 70, 85],
}
df = pd.DataFrame(data, index=['국', '영', '수', '사', '과'])

display(df)
display(df[1:3])
display(df[['학생1', '학생3']])
display(df['영':'사'])
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   90   95
# 수   80   85   90
# 사   75   80   70
# 과   70   75   85
#    학생1  학생2  학생3
# 영   85   90   95
# 수   80   85   90
#    학생1  학생3
# 국   90   85
# 영   85   95
# 수   80   90
# 사   75   70
# 과   70   85
#    학생1  학생2  학생3
# 영   85   90   95
# 수   80   85   90
# 사   75   80   70

# %% [markdown]
# ##### iloc, loc
#
# 판다스 데이터프레임에는 위의 인덱싱을 보다 효과적으로 수행할 수 있는 특별한 방법이 존재 <br>
# <br>
#
# > **loc** <br>
# 행 인덱싱은 정수 또는 행 인덱스 데이터, 열 인덱스는 문자열 <br>
# ```python
# dataframe.loc[행 인덱싱]
# dataframe.loc[행 인덱싱, 열 인덱싱]
# ```
#
# <br>
# <br>
#
# > **iloc** <br>
# 사용법은 loc와 큰 차이가 없으나 iloc 내부에는 반드시 정수 인덱싱만 허용 <br>
# ```python
# dataframe.iloc[행 인덱싱]
# dataframe.iloc[행 인덱싱, 열 인덱싱]
# ```

# %%
df
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   90   95
# 수   80   85   90
# 사   75   80   70
# 과   70   75   85

# %%
print(df.values[0, 0])
print(df.values[3, 1])
print(df.values[1:3, 1])
print(df.values[1:3, 1:3])
# Out:
# 90
# 80
# [90 85]
# [[90 95]
#  [85 90]]

# %%
print(df.iloc[0, 0])
print(df.iloc[3, 1])
display(df.iloc[1:3, 1])
display(df.iloc[1:3, 1:3])
display(df.iloc[1:3, 1:2])
# Out:
# 90
# 80
# 영    90
# 수    85
# Name: 학생2, dtype: int64
#    학생2  학생3
# 영   90   95
# 수   85   90
#    학생2
# 영   90
# 수   85

# %%
display(df.loc[:, ['학생1']])
# Out:
#    학생1
# 국   90
# 영   85
# 수   80
# 사   75
# 과   70

# %%
display(df.학생1%2 == 0)
display(df.loc[df.학생1%2 == 0])
display(df.loc[df.학생1%2 == 0, [True, False, True]])
# Out:
# 국     True
# 영    False
# 수     True
# 사    False
# 과     True
# Name: 학생1, dtype: bool
#    학생1  학생2  학생3
# 국   90   95   85
# 수   80   85   90
# 과   70   75   85
#    학생1  학생3
# 국   90   85
# 수   80   90
# 과   70   85

# %%
display(df.loc[:, ['학생3', '학생1', '학생2']])
display(df.loc['국':'수', ['학생3', '학생1', '학생2']])
# Out:
#    학생3  학생1  학생2
# 국   85   90   95
# 영   95   85   90
# 수   90   80   85
# 사   70   75   80
# 과   85   70   75
#    학생3  학생1  학생2
# 국   85   90   95
# 영   95   85   90
# 수   90   80   85

# %%
# 학생1의 점수가 80점을 넘으면서 학생 3의 점수가 90점을 넘는 row를 선택
display(df.loc[(df.학생1>=80) * (df.학생3>=90)])    # element-wise operation
display(df.loc[(df.학생1>=80) & (df.학생3>=90)])    # bit operation
# Out:
#    학생1  학생2  학생3
# 영   85   90   95
# 수   80   85   90
#    학생1  학생2  학생3
# 영   85   90   95
# 수   80   85   90

# %%
df.iloc[1, -1] = 100
display(df)
# Out:
#     학생1  학생2  학생3
# 국   NaN   95   85
# 영  85.0   90  100
# 수  80.0   85   90
# 사  75.0   80   70
# 과  70.0   75   85

# %%
df.iloc[6, 1] = 50
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 df.iloc[6, 1] = 50
#       2 df
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:908, in _LocationIndexer.__setitem__(self, key, value)
#     906     key = self._check_deprecated_callable_usage(key, maybe_callable)
#     907 indexer = self._get_setitem_indexer(key)
# --> 908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
#     911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1646, in _iLocIndexer._has_valid_setitem_indexer(self, indexer)
#    1644 elif is_integer(i):
#    1645     if i >= len(ax):
# -> 1646         raise IndexError("iloc cannot enlarge its target object")
#    1647 elif isinstance(i, dict):
#    1648     raise IndexError("iloc cannot enlarge its target object")
#
# IndexError: iloc cannot enlarge its target object

# %%
df.loc['코', '학생1'] = 100

# %%
df
# Out:
#      학생1   학생2    학생3
# 국    NaN  95.0   85.0
# 영   85.0  90.0  100.0
# 수   80.0  85.0   90.0
# 사   75.0  80.0   70.0
# 과   70.0  75.0   85.0
# 코  100.0   NaN    NaN

# %% [markdown]
# #### describe
# 데이터 프레임의 기술통계량 산출 <br>

# %%
df.describe()
# Out:
#              학생1        학생2        학생3
# count   5.000000   5.000000   5.000000
# mean   80.000000  85.000000  85.000000
# std     7.905694   7.905694   9.354143
# min    70.000000  75.000000  70.000000
# 25%    75.000000  80.000000  85.000000
# 50%    80.000000  85.000000  85.000000
# 75%    85.000000  90.000000  90.000000
# max    90.000000  95.000000  95.000000

# %%
df.학생1.국 = np.nan
display(df)
df.describe()
# Out:
#     학생1  학생2  학생3
# 국   NaN   95   85
# 영  85.0   90   95
# 수  80.0   85   90
# 사  75.0   80   70
# 과  70.0   75   85
#              학생1        학생2        학생3
# count   4.000000   5.000000   5.000000
# mean   77.500000  85.000000  85.000000
# std     6.454972   7.905694   9.354143
# min    70.000000  75.000000  70.000000
# 25%    73.750000  80.000000  85.000000
# 50%    77.500000  85.000000  85.000000
# 75%    81.250000  90.000000  90.000000
# max    85.000000  95.000000  95.000000

# %% [markdown]
# #### values
# 데이터 프레임 값을 numpy로 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.values
# ```

# %%
df.values
# Out:
# array([[ nan,  95.,  85.],
#        [ 85.,  90., 100.],
#        [ 80.,  85.,  90.],
#        [ 75.,  80.,  70.],
#        [ 70.,  75.,  85.],
#        [100.,  50.,  nan]])

# %% [markdown]
# #### shape
# 데이터 프레임의 행,열을 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.shape
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.shape
# Out:
# (5, 4)

# %% [markdown]
# #### unique
# 중복값을 제거한 데이터 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.학생2.unique()
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

print(df.학생2.unique())
print(df.학생2.nunique())
# Out:
# [95 80 70]
# 3

# %% [markdown]
# #### count
# 행별 개수, 열별 개수 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.count()        # 행별 원소 개수
# df.count(axis=1)  # 열별 원소 개수
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.count(axis=1)
# Out:
# 국    4
# 영    4
# 수    4
# 사    4
# 과    4
# dtype: int64

# %% [markdown]
# #### sort_index
# 인덱스 정렬 <br>
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = [3, 1, 4, 2, 5]
# df = pd.DataFrame(data, index=index)
#
# df.sort_index()                   # 오름차순으로 정렬된 데이터 프레임 반환
# df.sort_index(inplace=True)       # 데이터 프레임 자체를 변환
# df.sort_index(ascending=False)    # 내림차순으로 정렬된 데이터 프레임 반환
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = [3, 0, 1, 2, 4]
df = pd.DataFrame(data, index=index)

display(df)
display(df.sort_index())
display(df.sort_index(ascending=False))
# Out:
#    학생1  학생2  학생3   재수
# 3   90   95   85   80
# 0   85   80   95  100
# 1   80   70   90   99
# 2   75   80   70   95
# 4   70   95   85   90
#    학생1  학생2  학생3   재수
# 0   85   80   95  100
# 1   80   70   90   99
# 2   75   80   70   95
# 3   90   95   85   80
# 4   70   95   85   90
#    학생1  학생2  학생3   재수
# 4   70   95   85   90
# 3   90   95   85   80
# 2   75   80   70   95
# 1   80   70   90   99
# 0   85   80   95  100

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.sort_index()
# Out:
#    학생1  학생2  학생3   재수
# 과   70   95   85   90
# 국   90   95   85   80
# 사   75   80   70   95
# 수   80   70   90   99
# 영   85   80   95  100

# %% [markdown]
# #### sort_values
# 특정 컬럼 값을 기준으로 정렬 <br>
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.sort_values(by=['학생1'])                      # 학생1의 점수를 기준으로 오름차순 정렬된 데이터 프레임 반환
# df.sort_values(by=['학생1'], ascending=False)     # 학생1의 점수를 기준으로 내림차순 정렬된 데이터 프레임 반환
# df.sort_values(by=['학생1'], inplace=True)        # 데이터 프레임을 학생1의 점수를 기준으로 오름차순 정렬
# df.sort_values(by=['학생1', '학생2'])              # 학생1, 학생2의 점수를 기준으로 (학생1 우선) 오름차순 정렬된 데이터프레임 반환
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)


display(df)
display(df.sort_values(by=['학생1']))
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90
#    학생1  학생2  학생3   재수
# 과   70   95   85   90
# 사   75   80   70   95
# 수   80   70   90   99
# 영   85   80   95  100
# 국   90   95   85   80

# %%
data = {
    '학생1': [90, 80, 80, 80, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)


display(df)
display(df.sort_values(by=['학생1']))
display(df.sort_values(by=['학생1', '학생2']))
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   80   80   95  100
# 수   80   70   90   99
# 사   80   80   70   95
# 과   70   95   85   90
#    학생1  학생2  학생3   재수
# 과   70   95   85   90
# 영   80   80   95  100
# 수   80   70   90   99
# 사   80   80   70   95
# 국   90   95   85   80
#    학생1  학생2  학생3   재수
# 과   70   95   85   90
# 수   80   70   90   99
# 영   80   80   95  100
# 사   80   80   70   95
# 국   90   95   85   80

# %% [markdown]
# #### apply
# 열 또는 축을 기준으로 함수 적용
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.apply(lambda x: x + 10, axis=1)
# ```

# %%
df
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   80   80   95  100
# 수   80   70   90   99
# 사   80   80   70   95
# 과   70   95   85   90

# %%
display(df.apply(lambda x: np.sum(x), axis=1))
display(df.apply(lambda x: np.sum(x), axis=0))
# Out:
# 국    350
# 영    355
# 수    339
# 사    325
# 과    340
# dtype: int64
# 학생1    400
# 학생2    420
# 학생3    425
# 재수     464
# dtype: int64

# %%
df.학생1.apply(lambda x: np.sqrt(x))
# Out:
# 국    9.486833
# 영    8.944272
# 수    8.944272
# 사    8.944272
# 과    8.366600
# Name: 학생1, dtype: float64

# %%
from kiwipiepy import Kiwi
kiwi = Kiwi()

# %%
df = pd.read_csv(r'article_202408271518.csv')
df.title.apply(lambda x: kiwi.analyze(x))
# Out:
# 0      [([Token(form='인구', tag='NNG', start=0, len=2)...
# 1      [([Token(form='이재명', tag='NNP', start=0, len=3...
# 2      [([Token(form='"', tag='SSO', start=0, len=1),...
# 3      [([Token(form='“', tag='SSO', start=0, len=1),...
# 4      [([Token(form='NASA', tag='SL', start=0, len=4...
#                              ...
# 759    [([Token(form='이종찬', tag='NNP', start=0, len=3...
# 760    [([Token(form='[', tag='SSO', start=0, len=1),...
# 761    [([Token(form='미국', tag='NNP', start=0, len=2)...
# 762    [([Token(form='우크라', tag='NNP', start=0, len=3...
# 763    [([Token(form='태풍', tag='NNG', start=0, len=2)...
# Name: title, Length: 764, dtype: object

# %% [markdown]
# #### value_counts
# 특정 열을 기준으로 값의 개수 산출
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.value_counts()
# ```

# %%
data = {
    '학생1': [90, 85, 90, 75, 70],
    '학생2': [95, 80, 95, 80, 95],
    '학생3': [85, 95, 85, 70, 85],
    '재수': [80, 100, 80, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df)
display(df.value_counts())
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   90   95   85   80
# 사   75   80   70   95
# 과   70   95   85   90
# 학생1  학생2  학생3  재수
# 90   95   85   80     2
# 70   95   85   90     1
# 75   80   70   95     1
# 85   80   95   100    1
# Name: count, dtype: int64

# %% [markdown]
# #### set_index
# 특정 열을 index로 설정
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.set_index('학생1')
# ```

# %%
data = {
    '과목': ['국', '영', '수', '사', '과'],
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
df = pd.DataFrame(data)
df.set_index('과목')
# Out:
#     학생1  학생2  학생3   재수
# 과목
# 국    90   95   85   80
# 영    85   80   95  100
# 수    80   70   90   99
# 사    75   80   70   95
# 과    70   95   85   90

# %% [markdown]
# ### 데이터 입출력

# %% [markdown]
# #### 입력
# pd.read_csv를 통하여 csv 데이터를 읽음
#
# ```python
# pd.read_csv(파일경로)
# ```
# <br>
#
# read_csv 내에는 다양한 옵션 존재
# - usecols: csv 컬럼에서 특정 컬럼만을 읽음
# - names: 읽어 들인 데이터의 열 이름 변경 가능
# - index_col: 입력하는 파일 내의 특정 column을 index로 설정 가능
# - sep: csv의 데이터 구분은 ",", 하지만 데이터 구분자가 다른 경우 (\t) 이러한 구분자를 sep을 통해 지정할 수 있음
# - skiprows: 읽어들인 데이터 중 필요 없는 row를 제거할 수 있음
# - na_values: 값 중 na_values에 지정한 값은 읽을 때 na 처리

# %%
pd.read_csv('./data_2635_20240827.csv', encoding='cp949')
# Out:
#               표준코드    단축코드        한글 종목명  한글 종목약명  \
# 0     KR7098120009  098120  (주)마이크로컨텍솔루션  마이크로컨텍솔
# 1     KR7009520008  009520      (주)포스코엠텍    포스코엠텍
# 2     KR7095570008  095570     AJ네트웍스보통주   AJ네트웍스
# 3     KR7006840003  006840      AK홀딩스보통주    AK홀딩스
# 4     KR7282330000  282330     BGF리테일보통주   BGF리테일
# ...            ...     ...           ...      ...
# 2827  KR7000541003  000545  흥국화재해상보험1우선주    흥국화재우
# 2828  KR7000540005  000540   흥국화재해상보험보통주     흥국화재
# 2829  KR7003280005  003280       흥아해운보통주     흥아해운
# 2830  KR7037440005  037440    희림종합건축사사무소       희림
# 2831  KR7238490007  238490            힘스       힘스
#
#                                영문 종목명         상장일           시장구분 증권구분    소속부  \
# 0     Micro Contact Solution Co.,Ltd.  2008/09/23         KOSDAQ   주권  중견기업부
# 1               POSCO M-TECH CO.,LTD.  1997/11/10  KOSDAQ GLOBAL   주권  우량기업부
# 2                AJ Networks Co.,Ltd.  2015/08/21          KOSPI   주권    NaN
# 3                   AK Holdings, Inc.  1999/08/11          KOSPI   주권    NaN
# 4                          BGF Retail  2017/12/08          KOSPI   주권    NaN
# ...                               ...         ...            ...  ...    ...
# 2827       HeungkukFire&MarineIns(1P)  1990/03/20          KOSPI   주권    NaN
# 2828     HeungkukFire&MarineInsurance  1974/12/05          KOSPI   주권    NaN
# 2829                   HeungaShipping  1976/06/29          KOSPI   주권    NaN
# 2830     Heerim Architects & Planners  2000/02/03         KOSDAQ   주권  우량기업부
# 2831                   HIMS CO., LTD.  2017/07/20         KOSDAQ   주권  벤처기업부
#
#        주식종류   액면가      상장주식수
# 0       보통주   500    8312766
# 1       보통주   500   41642703
# 2       보통주  1000   45252759
# 3       보통주  5000   13247561
# 4       보통주  1000   17283906
# ...     ...   ...        ...
# 2827  구형우선주  5000     768000
# 2828    보통주  5000   64242645
# 2829    보통주   500  240424899
# 2830    보통주   500   13922475
# 2831    보통주   500   11312236
#
# [2832 rows x 12 columns]

# %%
pd.read_csv('./data_2635_20240827.csv', encoding='cp949', usecols=['표준코드', '한글 종목약명'])
# Out:
#               표준코드  한글 종목약명
# 0     KR7098120009  마이크로컨텍솔
# 1     KR7009520008    포스코엠텍
# 2     KR7095570008   AJ네트웍스
# 3     KR7006840003    AK홀딩스
# 4     KR7282330000   BGF리테일
# ...            ...      ...
# 2827  KR7000541003    흥국화재우
# 2828  KR7000540005     흥국화재
# 2829  KR7003280005     흥아해운
# 2830  KR7037440005       희림
# 2831  KR7238490007       힘스
#
# [2832 rows x 2 columns]

# %%
pd.read_csv('./stock_code.csv', sep='★', engine='python')
# Out:
#               표준코드  한글 종목약명
# 0     KR7098120009  마이크로컨텍솔
# 1     KR7009520008    포스코엠텍
# 2     KR7095570008   AJ네트웍스
# 3     KR7006840003    AK홀딩스
# 4     KR7282330000   BGF리테일
# ...            ...      ...
# 2827  KR7000541003    흥국화재우
# 2828  KR7000540005     흥국화재
# 2829  KR7003280005     흥아해운
# 2830  KR7037440005       희림
# 2831  KR7238490007       힘스
#
# [2832 rows x 2 columns]

# %%
pd.read_csv('./stock_code.csv', sep='★', engine='python', skiprows=2)
# Out:
#               표준코드  한글 종목약명
# 0     KR7098120009  마이크로컨텍솔
# 1     KR7009520008    포스코엠텍
# 2     KR7095570008   AJ네트웍스
# 3     KR7006840003    AK홀딩스
# 4     KR7282330000   BGF리테일
# ...            ...      ...
# 2827  KR7000541003    흥국화재우
# 2828  KR7000540005     흥국화재
# 2829  KR7003280005     흥아해운
# 2830  KR7037440005       희림
# 2831  KR7238490007       힘스
#
# [2832 rows x 2 columns]

# %% [markdown]
# #### 출력
# pd.to_csv를 통하여 csv 데이터를 출력
#
# ```python
# pd.to_csv(파일경로)
# ```
# <br>
#
# to_csv 내에는 다양한 옵션 존재
#
# - encoding: encoding을 지정하지 않고 출력 시 excel에서 한글이 깨지는 경우가 존재. 이 경우 utf-8-sig를 사용하면 해결 가능. <br> cp949, euc-kr등의 옵션도 존재
# - sep: 입력 때와 마찬가지로 구분자를 지정해줄 수 있음
# - na_rep: 입력 때와 마찬가지로 특정 값을 na로 처리하여 저장할 수 있음
# - index: index를 출력할지 유무. True, False
# - headers: column을 출력할지 유무. True, False

# %%
df = pd.read_csv('./data/data_2635_20240827.csv', encoding='cp949', usecols=['표준코드', '한글 종목약명'])
df.to_csv('./data/stock_code.csv', sep='★')

# %%
df.to_csv('./data/stock_code.csv', sep='★', index=False)

# %%
## 전 종목 시세 데이터를 읽어들인 후 소속부가 관리종목(소속부없음) 선택
df = pd.read_csv('./data/stock_price.csv', encoding='cp949')
## 관리종목 데이터 프레임을 managed_stocks 이름으로 저장
managed_stocks = df.loc[df.소속부 == '관리종목(소속부없음)']
managed_stocks.to_csv('./data/managed_stock.csv', index=False)

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# #### drop_duplicates
# 데이터프레임 내 중복값 확인

# %%
data = {
    '학생1': [90, 85, 90, 75, 70],
    '학생2': [95, 80, 95, 80, 95],
    '학생3': [85, 95, 85, 70, 85],
    '재수': [80, 100, 80, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df)
display(df.drop_duplicates(keep='first'))
display(df.drop_duplicates(keep='last'))
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   90   95   85   80
# 사   75   80   70   95
# 과   70   95   85   90
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 사   75   80   70   95
# 과   70   95   85   90
#    학생1  학생2  학생3   재수
# 영   85   80   95  100
# 수   90   95   85   80
# 사   75   80   70   95
# 과   70   95   85   90

# %%
display(df)
df.drop_duplicates(subset=['학생2'], keep='last')
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   90   95   85   80
# 사   75   80   70   95
# 과   70   95   85   90
#    학생1  학생2  학생3  재수
# 사   75   80   70  95
# 과   70   95   85  90

# %% [markdown]
# #### duplicated

# %%
data = {
    '학생1': [90, 85, 90, 75, 70],
    '학생2': [95, 80, 95, 80, 95],
    '학생3': [85, 95, 85, 70, 85],
    '재수': [80, 100, 80, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.duplicated()
# Out:
# 국    False
# 영    False
# 수     True
# 사    False
# 과    False
# dtype: bool

# %%
df.loc[~df.duplicated()]
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 사   75   80   70   95
# 과   70   95   85   90

# %% [markdown]
# #### isna
# 결측값 확인
#
# ```python
# data = {
#     '학생1': [np.NaN, 85, 80, 75, 70],
#     '학생2': [95, 80, np.NaN, 80, 95],
#     '학생3': [85, 95, 90, np.NaN, 85],
#     '재수': [80, np.NaN, 99, 95, 90],
# }
# df = pd.DataFrame(data)
#
# df.isna()
# ```

# %%
data = {
    '학생1': [np.NaN, 85, 80, 75, 70],
    '학생2': [95, 80, np.NaN, 80, 95],
    '학생3': [85, 95, 90, np.NaN, 85],
    '재수': [80, np.NaN, 99, 95, 90],
}
df = pd.DataFrame(data)

df.isna()
# Out:
#      학생1    학생2    학생3     재수
# 0   True  False  False  False
# 1  False  False  False   True
# 2  False   True  False  False
# 3  False  False   True  False
# 4  False  False  False  False

# %% [markdown]
# #### dropna
# na가 포함된 row drop

# %%
data = {
    '학생1': [np.NaN, 85, 80, 75, 70],
    '학생2': [95, 80, np.NaN, 80, 95],
    '학생3': [85, 95, 90, np.NaN, 85],
    '재수': [80, np.NaN, 99, 95, 90],
}
df = pd.DataFrame(data)

display(df.dropna())
display(df.dropna(subset=['학생1', '학생2']))
# Out:
#     학생1   학생2   학생3    재수
# 4  70.0  95.0  85.0  90.0
#     학생1   학생2   학생3    재수
# 1  85.0  80.0  95.0   NaN
# 3  75.0  80.0   NaN  95.0
# 4  70.0  95.0  85.0  90.0

# %% [markdown]
# #### fillna
# 결측값을 특정 값으로 대체
#
# ```python
# data = {
#     '학생1': [np.NaN, 85, 80, 75, 70],
#     '학생2': [95, 80, np.NaN, 80, 95],
#     '학생3': [85, 95, 90, np.NaN, 85],
#     '재수': [80, np.NaN, 99, 95, 90],
# }
# df = pd.DataFrame(data)
#
# df.fillna(0)                   # 특정 값으로 대체
# df.fillna(method='ffill')      # 결측값을 앞의 값으로 대체
# df.fillna(method='bfill')      # 결측값을 뒤의 값으로 대체
# ```

# %%
data = {
    '학생1': [np.NaN, 85, 80, 75, 70],
    '학생2': [95, 80, np.NaN, 80, 95],
    '학생3': [85, 95, 90, np.NaN, 85],
    '재수': [80, np.NaN, 99, 95, 90],
}
df = pd.DataFrame(data)
display(df.fillna(1))

# %%
data = {
    '학생1': [np.NaN, 85, 80, 75, 70],
    '학생2': [95, 80, np.NaN, 80, 95],
    '학생3': [85, 95, 90, np.NaN, 85],
    '재수': [80, np.NaN, 99, 95, 90],
}
df = pd.DataFrame(data)
display(df)
display(df.fillna(method='ffill'))
# Out:
#     학생1   학생2   학생3    재수
# 0   NaN  95.0  85.0  80.0
# 1  85.0  80.0  95.0   NaN
# 2  80.0   NaN  90.0  99.0
# 3  75.0  80.0   NaN  95.0
# 4  70.0  95.0  85.0  90.0
# C:\Users\USER\AppData\Local\Temp\ipykernel_2224\2775822040.py:9: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   display(df.fillna(method='ffill'))
#     학생1   학생2   학생3    재수
# 0   NaN  95.0  85.0  80.0
# 1  85.0  80.0  95.0  80.0
# 2  80.0  80.0  90.0  99.0
# 3  75.0  80.0  90.0  95.0
# 4  70.0  95.0  85.0  90.0

# %%
data = {
    '학생1': [np.NaN, 85, 80, 75, 70],
    '학생2': [95, 80, np.NaN, 80, 95],
    '학생3': [85, 95, 90, np.NaN, 85],
    '재수': [80, np.NaN, 99, 95, 90],
}
df = pd.DataFrame(data)
display(df)
display(df.fillna(method='bfill'))
# Out:
#     학생1   학생2   학생3    재수
# 0   NaN  95.0  85.0  80.0
# 1  85.0  80.0  95.0   NaN
# 2  80.0   NaN  90.0  99.0
# 3  75.0  80.0   NaN  95.0
# 4  70.0  95.0  85.0  90.0
# C:\Users\USER\AppData\Local\Temp\ipykernel_2224\273323336.py:9: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   display(df.fillna(method='bfill'))
#     학생1   학생2   학생3    재수
# 0  85.0  95.0  85.0  80.0
# 1  85.0  80.0  95.0  99.0
# 2  80.0  80.0  90.0  99.0
# 3  75.0  80.0  85.0  95.0
# 4  70.0  95.0  85.0  90.0

# %% [markdown]
# ### 데이터 조회

# %% [markdown]
# #### isin
# 주어진 값이 데이터프레임 내에 존재하는지 확인
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.isin([80])
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df)
display(df.isin([90]))
# Out:
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90
#      학생1    학생2    학생3     재수
# 국   True  False  False  False
# 영  False  False  False  False
# 수  False  False   True  False
# 사  False  False  False  False
# 과  False  False  False   True

# %% [markdown]
# #### where
# 특정 조건을 만족하는지 검사 <br>
# 조건을 만족하는 경우 값 변경 가능 <br>
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.where(df%2==0, -df)
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.where(df%2==0, np.nan)
# Out:
#     학생1   학생2   학생3     재수
# 국  90.0   NaN   NaN   80.0
# 영   NaN  80.0   NaN  100.0
# 수  80.0  70.0  90.0    NaN
# 사   NaN  80.0  70.0    NaN
# 과  70.0   NaN   NaN   90.0

# %% [markdown]
# #### query
# column의 boolean 결과를 쿼리하는 표현 <br>
# 위의 loc를 활용한 방법보다 간단 <br>
# <br>
#
# ```python
# df = pd.DataFrame({
#     'A': range(1, 6),
#     'B': range(10, 0, -2),
#     'C C': range(10, 5, -1)
#     })
#
# df.query('A > B')        # df.loc[df.A > df.B]
# df.query('`C C` < 8')    # df.loc[df['C C'] < 8]
# ```

# %%
df = pd.DataFrame({
    'A': range(1, 6),
    'B': range(10, 0, -2),
    'C C': range(10, 5, -1)
    })
# B열 값이 6이상이면서 A열의 값이 3이상인 row 추출
df.query('A >= 3 and B >= 6')   # df.loc[(df.B >= 6) & (df.A >= 3)]
# A열 1 이상 B열 3 이상
df.query('A >= 1 and B >= 3')   # df.loc[(df.B >= 6) & (df.A >= 3)]
# C C열이 8이상이면서 A열이 3이상
df.query('`C C` >= 8 and A >= 3')
# A열이 값이 수학인 것을 추출
df.query('A == "수학"')
# Out:
# Empty DataFrame
# Columns: [A, B, C C]
# Index: []

# %% [markdown]
# ### 컬럼 조작

# %% [markdown]
# #### filter
# 특정 조건에 맞는 열이나 행을 추출
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
#     '재수': [80, 100, 99, 95, 90],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.filter(items=['학생1', '학생2'])    # 주어진 열을 선택
# df.filter(like='학생',  axis=1)       # 학생이라는 단어를 포함하는 열 선택
# df.filter(regex='\d', axis=1)        # 숫자를 포함하는 열 선택
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df.filter(items=['학생1', '학생2']))
display(df.filter(like='학생'))
display(df.filter(regex='\d'))
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\d'
# <>:12: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\USER\AppData\Local\Temp\ipykernel_2224\1073148079.py:12: SyntaxWarning: invalid escape sequence '\d'
#   display(df.filter(regex='\d'))
#    학생1  학생2
# 국   90   95
# 영   85   80
# 수   80   70
# 사   75   80
# 과   70   95
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %% [markdown]
# #### drop
# column이나 row를 제거
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.drop(columns='학생1')               # 1개 컬럼 drop
# df.drop(columns=['학생1', '학생2'])     # 복수개 컬럼 drop
#
# df.drop('국')             # 1개 row drop
# df.drop(['국', '영'])      # 복수개 row drop
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
    '재수': [80, 100, 99, 95, 90],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df.drop(columns=['재수', '학생3']))
display(df.drop(index=['국']))
display(df)
# Out:
#    학생1  학생2
# 국   90   95
# 영   85   80
# 수   80   70
# 사   75   80
# 과   70   95
#    학생1  학생2  학생3   재수
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90
#    학생1  학생2  학생3   재수
# 국   90   95   85   80
# 영   85   80   95  100
# 수   80   70   90   99
# 사   75   80   70   95
# 과   70   95   85   90

# %% [markdown]
# ### 통계

# %% [markdown]
# #### sum
# 데이터프레임의 행 또는 열 기준 합을 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.sum()         # default 0: 학생별 합
# df.sum(axis=1)   # 1: 과목별 합
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df.sum())
display(df.sum(axis=0))
display(df.sum(axis=1))
# Out:
# 학생1    400
# 학생2    420
# 학생3    425
# dtype: int64
# 학생1    400
# 학생2    420
# 학생3    425
# dtype: int64
# 국    270
# 영    260
# 수    240
# 사    225
# 과    250
# dtype: int64

# %% [markdown]
# #### mean
# 데이터프레임의 행 또는 열 기준 평균 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.mean()         # default 0: 학생별 평균
# df.mean(axis=1)   # 1: 과목별 평균
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df.mean())
display(df.mean(axis=0))
display(df.mean(axis=1))
# Out:
# 학생1    80.0
# 학생2    84.0
# 학생3    85.0
# dtype: float64
# 학생1    80.0
# 학생2    84.0
# 학생3    85.0
# dtype: float64
# 국    90.000000
# 영    86.666667
# 수    80.000000
# 사    75.000000
# 과    83.333333
# dtype: float64

# %% [markdown]
# #### median
# 데이터프레임의 행 또는 열 기준 중앙값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.median()         # default 0: 학생별 중앙값
# df.median(axis=1)   # 1: 과목별 중앙값
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df.median())
display(df.median(axis=0))
display(df.median(axis=1))
# Out:
# 학생1    80.0
# 학생2    80.0
# 학생3    85.0
# dtype: float64
# 학생1    80.0
# 학생2    80.0
# 학생3    85.0
# dtype: float64
# 국    90.0
# 영    85.0
# 수    80.0
# 사    75.0
# 과    85.0
# dtype: float64

# %% [markdown]
# #### mode
# 데이터프레임의 행 또는 열 기준 최빈값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.mode()         # default 0: 학생별 합
# df.mode(axis=1)   # 1: 과목별 합
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df)
display(df.mode())
display(df.mode(axis=0))
display(df.mode(axis=1))
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85
#    학생1   학생2   학생3
# 0   70  80.0  85.0
# 1   75  95.0   NaN
# 2   80   NaN   NaN
# 3   85   NaN   NaN
# 4   90   NaN   NaN
#    학생1   학생2   학생3
# 0   70  80.0  85.0
# 1   75  95.0   NaN
# 2   80   NaN   NaN
# 3   85   NaN   NaN
# 4   90   NaN   NaN
#     0   1   2
# 국  85  90  95
# 영  80  85  95
# 수  70  80  90
# 사  70  75  80
# 과  70  85  95

# %% [markdown]
# #### max
# 데이터프레임의 행 또는 열 기준 최댓값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.max()         # default 0: 학생별 최댓값
# df.max(axis=1)   # 1: 과목별 최댓값
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df.max())
display(df.max(axis=0))
display(df.max(axis=1))
# Out:
# 학생1    90
# 학생2    95
# 학생3    95
# dtype: int64
# 학생1    90
# 학생2    95
# 학생3    95
# dtype: int64
# 국    95
# 영    95
# 수    90
# 사    80
# 과    95
# dtype: int64

# %% [markdown]
# #### min
# 데이터프레임의 행 또는 열 기준 최솟값 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.min()         # default 0: 학생별 최솟값
# df.min(axis=1)   # 1: 과목별 최솟값
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df.min())
display(df.min(axis=0))
display(df.min(axis=1))
# Out:
# 학생1    70
# 학생2    70
# 학생3    70
# dtype: int64
# 학생1    70
# 학생2    70
# 학생3    70
# dtype: int64
# 국    85
# 영    80
# 수    70
# 사    70
# 과    70
# dtype: int64

# %% [markdown]
# #### cumsum
#
# 데이터프레임의 행 또는 열 기준 누적합 반환
#
# ```python
# data = {
#     '자산1': [0.01, 0.02, 0.03],
#     '자산2': [0.06, 0.09, 0.07],
#     '자산3': [0.04, 0.09, 0.01],
# }
# index = [8, 9, 0]
# df = pd.DataFrame(data, index=index)
#
# df.cumsum()         # default 0: 자산별 누적합
# df.cumsum(axis=1)   # 1: 연도별 누적합
# ```

# %%
data = {
    '자산1': [0.01, 0.02, 0.03],
    '자산2': [0.06, 0.09, 0.07],
    '자산3': [0.04, 0.09, 0.01],
}
index = [8, 9, 0]
df = pd.DataFrame(data, index=index)

display(df)
display(df.cumsum())
# Out:
#     자산1   자산2   자산3
# 8  0.01  0.06  0.04
# 9  0.02  0.09  0.09
# 0  0.03  0.07  0.01
#     자산1   자산2   자산3
# 8  0.01  0.06  0.04
# 9  0.03  0.15  0.13
# 0  0.06  0.22  0.14

# %% [markdown]
# #### cumprod
# 데이터프레임의 행 또는 열 기준 누적곱 반환
#
# ```python
# data = {
#     '자산1': [0.01, 0.02, 0.03],
#     '자산2': [0.06, 0.09, 0.07],
#     '자산3': [0.04, 0.09, 0.01],
# }
# index = [8, 9, 0]
# df = pd.DataFrame(data, index=index)
#
# df.cumprod()         # default 0: 자산별 누적곱
# df.cumprod(axis=1)   # 1: 연도별 누적곱
# ```

# %%
data = {
    '자산1': [0.01, 0.02, 0.03],
    '자산2': [0.06, 0.09, 0.07],
    '자산3': [0.04, 0.09, 0.01],
}
index = [8, 9, 0]
df = pd.DataFrame(data, index=index)

display(df)
display(df.prod(axis=0))
display(df.prod(axis=1))
# Out:
#     자산1   자산2   자산3
# 8  0.01  0.06  0.04
# 9  0.02  0.09  0.09
# 0  0.03  0.07  0.01
# 자산1    0.000006
# 자산2    0.000378
# 자산3    0.000036
# dtype: float64
# 8    0.000024
# 9    0.000162
# 0    0.000021
# dtype: float64

# %% [markdown]
# #### rank
# 데이터프레임의 행 또는 열 기준 순위 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.rank()         # default 0: 학생별 최솟값
# df.rank(axis=1)   # 1: 과목별 최솟값
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df)
display(df.rank(axis=0))
display(df.rank(axis=0, method='min'))
display(df.rank(axis=0, method='max'))
display(df.rank(axis=0, ascending=False))
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85
#    학생1  학생2  학생3
# 국  5.0  4.5  2.5
# 영  4.0  2.5  5.0
# 수  3.0  1.0  4.0
# 사  2.0  2.5  1.0
# 과  1.0  4.5  2.5
#    학생1  학생2  학생3
# 국  5.0  4.0  2.0
# 영  4.0  2.0  5.0
# 수  3.0  1.0  4.0
# 사  2.0  2.0  1.0
# 과  1.0  4.0  2.0
#    학생1  학생2  학생3
# 국  5.0  5.0  3.0
# 영  4.0  3.0  5.0
# 수  3.0  1.0  4.0
# 사  2.0  3.0  1.0
# 과  1.0  5.0  3.0
#    학생1  학생2  학생3
# 국  1.0  1.5  3.5
# 영  2.0  3.5  1.0
# 수  3.0  5.0  2.0
# 사  4.0  3.5  5.0
# 과  5.0  1.5  3.5

# %% [markdown]
# #### quantile
# 데이터프레임의 행 또는 열 기준 분위수 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.quantile()         # default 0: 학생별 중앙값
# df.quantile(q=0.8)    # default 0: 학생별 80%값 반환
# df.quantile(axis=1)   # 1: 과목별 학생별 중앙값
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

display(df.quantile())
display(df.quantile(axis=1))
display(df.quantile(q=0.2))
# Out:
# 학생1    80.0
# 학생2    80.0
# 학생3    85.0
# Name: 0.5, dtype: float64
# 국    90.0
# 영    85.0
# 수    80.0
# 사    75.0
# 과    85.0
# Name: 0.5, dtype: float64
# 학생1    74.0
# 학생2    78.0
# 학생3    82.0
# Name: 0.2, dtype: float64

# %% [markdown]
# #### var
# 데이터프레임의 행 또는 열 기준 분산 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.var()         # default 0: 학생별 분산
# df.var(axis=1)   # 1: 과목별 분산
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.var()
# Out:
# 학생1     62.5
# 학생2    117.5
# 학생3     87.5
# dtype: float64

# %% [markdown]
# #### std
# 데이터프레임의 행 또는 열 기준 표준편차 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.std()         # default 0: 학생별 표준편차
# df.std(axis=1)   # 1: 과목별 표준편차
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.std()
# Out:
# 학생1     7.905694
# 학생2    10.839742
# 학생3     9.354143
# dtype: float64

# %% [markdown]
# #### corr
# 데이터프레임 내 상관관계 행렬 반환 <br>
# 상관관계는 pearson, kendall, spearman 방법 가능
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.corr()                     # pearson
# df.corr(method='kendall')     # kendall
# df.corr(method='spearman')    # spearman
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.corr()
# Out:
#               학생1           학생2       학생3
# 학생1  1.000000e+00  8.291465e-17  0.422577
# 학생2  8.291465e-17  1.000000e+00 -0.123278
# 학생3  4.225771e-01 -1.232784e-01  1.000000

# %% [markdown]
# #### cov
# 데이터프레임 내 공분산 행렬 반환
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.cov()
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

df.cov()
# Out:
#        학생1    학생2    학생3
# 학생1  62.50    0.0  31.25
# 학생2   0.00  117.5 -12.50
# 학생3  31.25  -12.5  87.50

# %% [markdown]
# ### 집계

# %% [markdown]
# #### groupby
# 그룹별 집계
#
# ```python
# data = {
#     '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
#     '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
# }
# df = pd.DataFrame(data)
#
# df.groupby('구분').mean()
# ```

# %%
data = {
    '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
    '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
}
df = pd.DataFrame(data)

df.groupby(['구분']).mean()
# Out:
#       점수
# 구분
# 재수  92.0
# 현역  83.0

# %%
data = {
    '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
    '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5,
    '지역': ['서울']*10 + ['부산']*10 + ['제주']*5,
}
df = pd.DataFrame(data)

display(df.groupby(['구분', '지역']).mean())
display(df.groupby(['구분', '지역']).min())
# Out:
#          점수
# 구분 지역
# 재수 부산  90.0
#    제주  94.0
# 현역 부산  85.0
#    서울  82.0
#        점수
# 구분 지역
# 재수 부산  85
#    제주  85
# 현역 부산  70
#    서울  70

# %%
data = {
    '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
    '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5,
    '지역': ['서울']*10 + ['부산']*10 + ['제주']*5,
}
df = pd.DataFrame(data)

display(df.groupby(['구분', '지역']).mean())
display(df.groupby(['구분', '지역']).min())
display(df.groupby(['구분', '지역']).max())
# Out:
#          점수
# 구분 지역
# 재수 부산  90.0
#    제주  94.0
# 현역 부산  85.0
#    서울  82.0
#        점수
# 구분 지역
# 재수 부산  85
#    제주  85
# 현역 부산  70
#    서울  70
#         점수
# 구분 지역
# 재수 부산   95
#    제주  100
# 현역 부산   95
#    서울   95

# %%
df.groupby(['구분', '지역']).describe()
# Out:
#          점수
#       count  mean       std   min    25%   50%    75%    max
# 구분 지역
# 재수 부산   5.0  90.0  5.000000  85.0  85.00  90.0  95.00   95.0
#    제주   5.0  94.0  5.477226  85.0  95.00  95.0  95.00  100.0
# 현역 부산   5.0  85.0  9.354143  70.0  85.00  85.0  90.00   95.0
#    서울  10.0  82.0  9.189366  70.0  76.25  80.0  88.75   95.0

# %%
print(list(df.groupby(['구분', '지역']))[0])
print('-'*100)
print(list(df.groupby(['구분', '지역']))[1])
print('-'*100)
print(list(df.groupby(['구분', '지역']))[2])
print('-'*100)
print(list(df.groupby(['구분', '지역']))[3])
# Out:
# (('재수', '부산'),     점수  구분  지역
# 15  85  재수  부산
# 16  95  재수  부산
# 17  90  재수  부산
# 18  95  재수  부산
# 19  85  재수  부산)
# ----------------------------------------------------------------------------------------------------
# (('재수', '제주'),      점수  구분  지역
# 20   95  재수  제주
# 21   95  재수  제주
# 22   95  재수  제주
# 23  100  재수  제주
# 24   85  재수  제주)
# ----------------------------------------------------------------------------------------------------
# (('현역', '부산'),     점수  구분  지역
# 10  85  현역  부산
# 11  95  현역  부산
# 12  90  현역  부산
# 13  70  현역  부산
# 14  85  현역  부산)
# ----------------------------------------------------------------------------------------------------
# (('현역', '서울'),    점수  구분  지역
# 0  90  현역  서울
# 1  85  현역  서울
# 2  80  현역  서울
# 3  75  현역  서울
# 4  70  현역  서울
# 5  95  현역  서울
# 6  80  현역  서울
# 7  70  현역  서울
# 8  80  현역  서울
# 9  95  현역  서울)

# %% [markdown]
# #### agg
# 다양한 집계함수 사용 가능
#
# ```python
# data = {
#     '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
#     '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
# }
# df = pd.DataFrame(data)
#
# df.groupby('구분').agg(['min', 'max', 'mean'])
# ```

# %%
data = {
    '점수': [90, 85, 80, 75, 70, 95, 80, 70, 80, 95, 85, 95, 90, 70, 85, 85, 95, 90, 95, 85, 95, 95, 95, 100, 85],
    '구분': ['현역']*5 + ['현역']*5 + ['현역']*5 + ['재수']*5 + ['재수']*5
}
df = pd.DataFrame(data)

df.groupby(['구분']).agg(['min', 'max', 'mean', 'median', 'sum'])
# Out:
#     점수
#    min  max  mean median   sum
# 구분
# 재수  85  100  92.0   95.0   920
# 현역  70   95  83.0   85.0  1245

# %% [markdown]
# ### 결합

# %% [markdown]
# #### merge
# 두 데이터프레임 병합 <br>
#
# on: 결합 대상 key 컬럼 <br>
# how <br>
# - left: 왼쪽 데이터 프레임의 키를 중심으로 결합
# - right: 오른쪽 데이터 프레임의 키를 중심으로 결합
# - outer: 두 데이터 프레임의 키를 중심으로 결합
# - inner: 두 데이터 프레임에서 공통으로 존재하는 값만 결합
# - cross: 모든 경우의 수를 구하여 결합
#
# ```python
# df1 = pd.DataFrame({'a': ['foo', 'bar'], 'b': [1, 2]})
# df2 = pd.DataFrame({'a': ['foo', 'baz'], 'c': [3, 4]})
#
# df1.merge(df2, how='inner', on='a')
# df1.merge(df2, how='left', on='a')
# df1.merge(df2, how='cross')
#
#
# df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
#                     'value': [1, 2, 3, 5]})
# df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
#                     'value': [5, 6, 7, 8]})
#
# df1.merge(df2, left_on='lkey', right_on='rkey')
# df1.merge(df2, left_on='lkey', right_on='rkey', suffixes=('_left', '_right'))
# ```

# %%
df1 = pd.DataFrame({'a': ['foo', 'bar'], 'b': [1, 2]})
df2 = pd.DataFrame({'a': ['foo', 'baz'], 'c': [3, 4]})

# %%
display(df1.merge(df2, on='a'))
display(df1.merge(df2, on='a', how='left'))
display(df2)
display(df1.merge(df2, on='a', how='right'))
display(df1.merge(df2, how='cross'))
# Out:
#      a  b  c
# 0  foo  1  3
#      a  b    c
# 0  foo  1  3.0
# 1  bar  2  NaN
#      a  c
# 0  foo  3
# 1  baz  4
#      a    b  c
# 0  foo  1.0  3
# 1  baz  NaN  4
#    a_x  b  a_y  c
# 0  foo  1  foo  3
# 1  foo  1  baz  4
# 2  bar  2  foo  3
# 3  bar  2  baz  4

# %%
display(df1)
display(df2)
# Out:
#      a  b
# 0  foo  1
# 1  bar  2
#      a  c
# 0  foo  3
# 1  baz  4

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar'], 'b': [1, 2]})
df2 = pd.DataFrame({'rkey': ['foo', 'baz'], 'c': [3, 4]})

# %%
df1.merge(df2, left_on='lkey', right_on='rkey', how='left')
# Out:
#   lkey  b rkey    c
# 0  foo  1  foo  3.0
# 1  bar  2  NaN  NaN

# %% [markdown]
# #### concat
# 두 데이터프레임 결합 <br>
# 리스트 내의 데이터프레임 결합에도 사용 <br>
#
# ```python
# df1 = pd.DataFrame([['a', 1], ['b', 2]],
#                    columns=['letter', 'number'])
# df2 = pd.DataFrame([['c', 3], ['d', 4]],
#                    columns=['letter', 'number'])
#
# pd.concat([df1, df2])            # 아래로 결합
# pd.concat([df1, df2], axis=1)    # 옆으로 결합
#
#
# dataframe_list = [df1, df2]
# pd.concat(dataframe_list)
# ```

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])
df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter', 'number'])

display(df1)
display(df2)
display(pd.concat([df1, df2]))
display(pd.concat([df1, df2], axis=1))
# Out:
#   letter  number
# 0      a       1
# 1      b       2
#   letter  number
# 0      c       3
# 1      d       4
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4
#   letter  number letter  number
# 0      a       1      c       3
# 1      b       2      d       4

# %%
temp = pd.concat([df1, df2], axis=1)
# display(temp.filter(items=['letter']))
# display(temp.rename(columns={'letter': 'letter1'}))
temp.columns = ['letter', 'number', 'letter1', 'number1']
display(temp)
# Out:
#   letter  number letter1  number1
# 0      a       1       c        3
# 1      b       2       d        4

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'])
df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter1', 'number1'])

display(df1)
display(df2)
display(pd.concat([df1, df2], axis=0))
# Out:
#   letter  number
# 0      a       1
# 1      b       2
#   letter1  number1
# 0       c        3
# 1       d        4
#   letter  number letter1  number1
# 0      a     1.0     NaN      NaN
# 1      b     2.0     NaN      NaN
# 0    NaN     NaN       c      3.0
# 1    NaN     NaN       d      4.0

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                   columns=['letter', 'number'], index=[0, 1])
df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter', 'number'], index=[2, 3])

display(df1)
display(df2)
display(pd.concat([df1, df2], axis=1))
# Out:
#   letter  number
# 0      a       1
# 1      b       2
#   letter  number
# 2      c       3
# 3      d       4
#   letter  number letter  number
# 0      a     1.0    NaN     NaN
# 1      b     2.0    NaN     NaN
# 2    NaN     NaN      c     3.0
# 3    NaN     NaN      d     4.0

# %% [markdown]
# ### 데이터프레임 조작

# %% [markdown]
# #### explode
# 리스트 내의 값을 row로 분해
#
# ```python
# data = {
#     '학생1': [[90, 85, 80, 75, 70]],
#     '학생2': [[95, 80, 70, 80, 95]],
#     '학생3': [[85, 95, 90, 70, 85]],
# }
# df = pd.DataFrame(data)
#
# df.explode('학생1')
# df.explode('학생2')
# df.explode('학생3')
# ```

# %%
data = {
    '학생1': [[90, 85, 80, 75, 70]],
    '학생2': [[95, 80, 70, 80, 95]],
    '학생3': [[85, 95, 90, 70, 85]],
}
df = pd.DataFrame(data)
df = df.explode(['학생1', '학생2', '학생3'])
df
# Out:
#   학생1 학생2 학생3
# 0  90  95  85
# 0  85  80  95
# 0  80  70  90
# 0  75  80  70
# 0  70  95  85

# %% [markdown]
# #### pivot
# 인덱스, 컬럼 값으로 데이터 재정렬
#
# ```python
# df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
#                            'two'],
#                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
#                    'baz': [1, 2, 3, 4, 5, 6],
#                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
#
# df.pivot(index='foo', columns='bar', values='baz')
# df.pivot(index='foo', columns='bar')['baz']
# df.pivot(index='foo', columns='bar', values=['baz', 'zoo'])
# ```

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
temp = df.pivot(index='foo', columns='bar', values='baz')
temp
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %% [markdown]
# #### melt
# uppivot, 데이터 프레임 재정렬
#
# ```python
# data = {
#   'A': {0: 'a', 1: 'b', 2: 'c'},
#   'B': {0: 1, 1: 3, 2: 5},
#   'C': {0: 2, 1: 4, 2: 6}
#   }
# df = pd.DataFrame(data)
#
#
# df.melt(id_vars=['A'], value_vars=['B'])
# df.melt(id_vars=['A'], value_vars=['B', 'C'])
# df.melt(id_vars=['A'], value_vars=['B', 'C'], var_name='new_var_name', value_name='new_value_name')
# ```

# %%
data = {
  'A': {0: 'a', 1: 'b', 2: 'c'},
  'B': {0: 1, 1: 3, 2: 5},
  'C': {0: 2, 1: 4, 2: 6}
  }
df = pd.DataFrame(data)
display(df)
display(df.melt(id_vars=['A'], value_vars=['B', 'C']))
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %%
display(temp)
display(temp.reset_index())
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6
# bar  foo  A  B  C
# 0    one  1  2  3
# 1    two  4  5  6

# %%
temp.reset_index().melt(id_vars=['foo'], value_vars=['A', 'B', 'C'])
# Out:
#    foo bar  value
# 0  one   A      1
# 1  two   A      4
# 2  one   B      2
# 3  two   B      5
# 4  one   C      3
# 5  two   C      6

# %% [markdown]
# #### stack
# 데이터를 아래로 이어붙임
#
# ```python
# data = {
#     '학생1': [90, 85, 80, 75, 70],
#     '학생2': [95, 80, 70, 80, 95],
#     '학생3': [85, 95, 90, 70, 85],
# }
# index = ['국', '영', '수', '사', '과']
# df = pd.DataFrame(data, index=index)
#
# df.stack()
# ```

# %%
data = {
    '학생1': [90, 85, 80, 75, 70],
    '학생2': [95, 80, 70, 80, 95],
    '학생3': [85, 95, 90, 70, 85],
}
index = ['국', '영', '수', '사', '과']
df = pd.DataFrame(data, index=index)

# %%
df
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %%
df.stack()
# Out:
# 국  학생1    90
#    학생2    95
#    학생3    85
# 영  학생1    85
#    학생2    80
#    학생3    95
# 수  학생1    80
#    학생2    70
#    학생3    90
# 사  학생1    75
#    학생2    80
#    학생3    70
# 과  학생1    70
#    학생2    95
#    학생3    85
# dtype: int64

# %%
df.stack().reset_index()
# Out:
#    level_0 level_1   0
# 0        국     학생1  90
# 1        국     학생2  95
# 2        국     학생3  85
# 3        영     학생1  85
# 4        영     학생2  80
# 5        영     학생3  95
# 6        수     학생1  80
# 7        수     학생2  70
# 8        수     학생3  90
# 9        사     학생1  75
# 10       사     학생2  80
# 11       사     학생3  70
# 12       과     학생1  70
# 13       과     학생2  95
# 14       과     학생3  85

# %% [markdown]
# #### unstack
#
# 멀티 인덱스 데이터프레임을 컬럼으로 분할
#
#
# ```python
# scores = [90, 95, 85, 85, 80, 95, 80, 70, 90, 75, 80, 70, 70, 95, 85]
# index = pd.MultiIndex.from_tuples(
#     [('국', '학생1'),
#      ('국', '학생2'),
#      ('국', '학생3'),
#      ('영', '학생1'),
#      ('영', '학생2'),
#      ('영', '학생3'),
#      ('수', '학생1'),
#      ('수', '학생2'),
#      ('수', '학생3'),
#      ('사', '학생1'),
#      ('사', '학생2'),
#      ('사', '학생3'),
#      ('과', '학생1'),
#      ('과', '학생2'),
#      ('과', '학생3')],
# )
# df = pd.Series(scores, index=index)
#
# df.unstack()
# ```

# %%
df.stack()
# Out:
# 국  학생1    90
#    학생2    95
#    학생3    85
# 영  학생1    85
#    학생2    80
#    학생3    95
# 수  학생1    80
#    학생2    70
#    학생3    90
# 사  학생1    75
#    학생2    80
#    학생3    70
# 과  학생1    70
#    학생2    95
#    학생3    85
# dtype: int64

# %%
df.stack().unstack()
# Out:
#    학생1  학생2  학생3
# 국   90   95   85
# 영   85   80   95
# 수   80   70   90
# 사   75   80   70
# 과   70   95   85

# %% [markdown]
# ## 시계열 데이터

# %% [markdown]
# #### date_range
# 주어진 범위에 해당하는 date 리스트 반환
#
# https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases
#
# ```python
# pd.date_range(start='9/1/2', end='9/30/2')
# pd.date_range(start='9-01', end='9-30')
# pd.date_range(start='9-01', end='9-30', freq='1W')    # 1주 단위로 date 생성
# pd.date_range(start='9-01', periods=8)                      # 시작일 기준 8개의 날 생성
# pd.date_range(end='9-01', periods=8)                        # 종료일 기준 8개의 날 생성
# ```

# %%
pd.date_range('2024-01-01', '2024-08-31', freq='1M')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7120\2124436415.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.date_range('2024-01-01', '2024-08-31', freq='1M')
# DatetimeIndex(['2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
pd.date_range('2024-12-01', '2024-12-31', freq='B')
# Out:
# DatetimeIndex(['2024-12-02', '2024-12-03', '2024-12-04', '2024-12-05',
#                '2024-12-06', '2024-12-09', '2024-12-10', '2024-12-11',
#                '2024-12-12', '2024-12-13', '2024-12-16', '2024-12-17',
#                '2024-12-18', '2024-12-19', '2024-12-20', '2024-12-23',
#                '2024-12-24', '2024-12-25', '2024-12-26', '2024-12-27',
#                '2024-12-30', '2024-12-31'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# #### shift
#
# 데이터 프레임의 인덱스 또는 컬럼을 주어진 숫자 만큼 옮김
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("0-01-01", "0-01-05"))
#
# df.shift(periods=1)                 # 아래로 한 칸 이동
# df.shift(periods=1, axis='columns') # 컬럼 한 칸 이동
# df.shift(periods=3, fill_value=0)   # 아래로 세 칸 이동 후 nan값을 0으로 채움
# df.shift(periods=3, freq='D')       # 3일 이동
# ```

# %%
df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
                   "Col2": [13, 23, 18, 33, 48],
                   "Col3": [17, 27, 22, 37, 52]},
                  index=pd.date_range("2024-01-01", "2024-01-05"))


df
# Out:
#             Col1  Col2  Col3
# 2024-01-01    10    13    17
# 2024-01-02    20    23    27
# 2024-01-03    15    18    22
# 2024-01-04    30    33    37
# 2024-01-05    45    48    52

# %%
(df.values - np.roll(df.values, shift=1, axis=0)) / np.roll(df.values, shift=1, axis=0)
# Out:
# array([[-0.77777778, -0.72916667, -0.67307692],
#        [ 1.        ,  0.76923077,  0.58823529],
#        [-0.25      , -0.2173913 , -0.18518519],
#        [ 1.        ,  0.83333333,  0.68181818],
#        [ 0.5       ,  0.45454545,  0.40540541]])

# %%
df.shift(1)
# Out:
#             Col1  Col2  Col3
# 2024-01-01   NaN   NaN   NaN
# 2024-01-02  10.0  13.0  17.0
# 2024-01-03  20.0  23.0  27.0
# 2024-01-04  15.0  18.0  22.0
# 2024-01-05  30.0  33.0  37.0

# %%
(df - df.shift(1)) / df.shift(1)
# Out:
#             Col1      Col2      Col3
# 2024-01-01   NaN       NaN       NaN
# 2024-01-02  1.00  0.769231  0.588235
# 2024-01-03 -0.25 -0.217391 -0.185185
# 2024-01-04  1.00  0.833333  0.681818
# 2024-01-05  0.50  0.454545  0.405405

# %% [markdown]
# #### diff
# 주어진 숫자 만큼의 인덱스 혹은 컬럼 차를 계산
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("0-01-01", "0-01-05"))
#
# df.diff()
# df.diff(periods=3)     # 3칸 간격의 차를 계산
# ```

# %%
df
# Out:
#             Col1  Col2  Col3
# 2024-01-01    10    13    17
# 2024-01-02    20    23    27
# 2024-01-03    15    18    22
# 2024-01-04    30    33    37
# 2024-01-05    45    48    52

# %%
df.diff()
# Out:
#             Col1  Col2  Col3
# 2024-01-01   NaN   NaN   NaN
# 2024-01-02  10.0  10.0  10.0
# 2024-01-03  -5.0  -5.0  -5.0
# 2024-01-04  15.0  15.0  15.0
# 2024-01-05  15.0  15.0  15.0

# %%
df.diff() / df.shift(1)
# Out:
#             Col1      Col2      Col3
# 2024-01-01   NaN       NaN       NaN
# 2024-01-02  1.00  0.769231  0.588235
# 2024-01-03 -0.25 -0.217391 -0.185185
# 2024-01-04  1.00  0.833333  0.681818
# 2024-01-05  0.50  0.454545  0.405405

# %%
df.diff(periods=2)
# Out:
#             Col1  Col2  Col3
# 2024-01-01   NaN   NaN   NaN
# 2024-01-02   NaN   NaN   NaN
# 2024-01-03   5.0   5.0   5.0
# 2024-01-04  10.0  10.0  10.0
# 2024-01-05  30.0  30.0  30.0

# %% [markdown]
# #### pct_change
# 주어진 숫자 만큼의 인덱스 혹은 컬럼 변화율 계산
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("0-01-01", "0-01-05"))
#
# df.pct_change()
# df.pct_change(periods=3)     # 3칸 간격의 변화율 계산
# ```

# %%
df.pct_change()
# Out:
#             Col1      Col2      Col3
# 2024-01-01   NaN       NaN       NaN
# 2024-01-02  1.00  0.769231  0.588235
# 2024-01-03 -0.25 -0.217391 -0.185185
# 2024-01-04  1.00  0.833333  0.681818
# 2024-01-05  0.50  0.454545  0.405405

# %% [markdown]
# #### rolling
# 주어진 숫자 만큼의 윈도우 생성 <br>
# 생성된 윈도우 내에서 집계 함수 사용 가능 <br>
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("0-01-01", "0-01-05"))
#
# df.rolling(2).sum()
# ```

# %%
df.rolling(2).mean()
# Out:
#             Col1  Col2  Col3
# 2024-01-01   NaN   NaN   NaN
# 2024-01-02  15.0  18.0  22.0
# 2024-01-03  17.5  20.5  24.5
# 2024-01-04  22.5  25.5  29.5
# 2024-01-05  37.5  40.5  44.5

# %% [markdown]
# ##  시각화
# 데이터프레임 값을 시각화
#
# ```python
# df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
#                    "Col2": [13, 23, 18, 33, 48],
#                    "Col3": [17, 27, 22, 37, 52]},
#                   index=pd.date_range("2024-01-01", "2024-01-05"))
#
# df.plot()                            # 모든 컬럼에 대한 line 그래프
# df.plot(legend=False)                # 범주를 출력하지 않음
# df.plot(kind='box')                  # 열 별 box plot
# df.plot(kind='density')              # 열 별 밀도함수
# df.plot(kind='pie', subplots=True)   # pie 그래프
# ```

# %%
df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
                   "Col2": [13, 23, 18, 33, 48],
                   "Col3": [17, 27, 22, 37, 52]},
                  index=pd.date_range("2024-01-01", "2024-01-05"))
df
# Out:
#             Col1  Col2  Col3
# 2024-01-01    10    13    17
# 2024-01-02    20    23    27
# 2024-01-03    15    18    22
# 2024-01-04    30    33    37
# 2024-01-05    45    48    52

# %%
df.plot(legend=False)
# Out:
# <Axes: >

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind='pie', subplots=True, legend=False)
# Out:
# array([<Axes: ylabel='Col1'>, <Axes: ylabel='Col2'>,
#        <Axes: ylabel='Col3'>], dtype=object)
