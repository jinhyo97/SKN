# %%
import pandas as pd
import psycopg2
import requests
import json
from bs4 import BeautifulSoup
from tqdm import tqdm

# %% [markdown]
# # Crawling
#
# 스크레이핑(Scraping)이라고도 하며 웹 페이지 내의 데이터를 추출하는 것을 의미 <br>
# 데이터를 수집하기 위한 방법으로 많이 사용 <br>
# 크게 두 가지의 방법이 존재
# 1. 정적크롤링 <br>
# 정적 데이터를 수집하는 방법 <br>
# 정적 데이터란 페이지 내에 원하는 정보가 모두 들어남
#
# 2. 동적크롤링 <br>
# 동적 데이터를 수집하는 방법 <br>
# 동적 데이터란 클릭, 로그인 등의 행위를 통해 원하는 데이터에 접근 가능 <br>
#
#
# |    |정적 크롤링|동적 크롤링|
# |----|--------|--------|
# |방법 |주소 사용  |브라우저 사용|
# |수집 범위|제한적  |제한 없음|
# |속도|매우 빠름|매우 느림|
#
# <br>
#
# 크롤링 시 사이트에서 크롤링을 허용하는지를 반드시 확인해야 함 <br>
# robots.txt를 뒤에 붙여 확인 가능 <br>
# 강제는 아니나 이를 무시하면 추후 법률적 문제가 생길 수 있음
# ```
# www.daum.net/robots.txt
# User-agent: *
# Disallow: /
# ```
# *: All <br>
# /: All Directories

# %% [markdown]
# ## HTTP
#
# WWW(World Wide Web, W3) 상에서 정보를 주고받을 수 있는 프로토콜 <br>
# 클라이언트와 서버 사이에 이루어지는 요청/응답 프로토콜

# %% [markdown]
# ### API
# API(Application Programming Interface) <br>
# - Application: 고유한 기능을 가진 모든 소프트웨어
# - Interface: 두 애플리케이션 간의 규약 <br>
# 이 계약은 요청과 응답을 사용하여 두 애플리케이션이 서로 통신하는 방법을 정의합니다.

# %% [markdown]
# ### REST
# REST(Representational State Transfer): 자원을 이름으로 구분하여 해당 자원의 상태를 주고받는 것 <br>
#
# REST 구성
# 1. 자원(Resource): HTTP URI
# 2. 자원에 대한 행위(Verb): HTTP Method
# 3. 자원에 대한 행위의 내용(Representations): HTTP Message Pay Load
#
#
# - HTTP URI(Uniform Resource Identifier)를 통해 자원(Resource)을 명시
# - HTTP Method(POST, GET, PUT, DELETE)를 사용하여 URI에 대한 CRUD Operation을 적용 <br>
# <br>
#
# HTTP Methods
# - GET: 자원 검색
# - POST: 자원 작성
# - PUT: 자원 업데이트
# - DELETE: 데이터 삭제
# - HEAD: 자원 검색 (GET과 유사하나 상태 줄과 헤더만 반환)
# - OPTIONS: 자원이 지원하고 있는 메소드의 취득
# - PATCH: 자원 일부 수정 (PUT과 유사하나 일부만 수정)
# - CONNECT: 자원의 터널 접속을 변경
# - TRACE: 리소스에 대한 경로를 따라 메시지 루프백 테스트를 수행
# <br>
#
# HTTP Status
# 1. 1xx(Informational): 요청 처리중
# 2. 2xx(Successful): 요청 정상 처리 <br>
# 200: 요청 성공
# 3. 3xx(Redirection): 요청을 완료하려면 추가 행동이 필요
# 4. 4xx(Client Error): 클라이언트 오류, 잘못된 문법등으로 요청을 수행할 수 없음 <br>
# 400: Bad Request, 클라이언트의 잘못된 요청으로 서버가 요청을 처리할 수 없음 <br>
# 401: Unauthorized, 해당 리소스에 대한 인증이 필요함 <br>
# 403: Forbidden, 서버가 요청을 이해했지만 승인을 거부함 <br>
# 404: Not Found, 리소스를 찾을 수 없음 <br>
# 5. 5xx(Server Error): 서버 오류

# %% [markdown]
# ### REST API
# REST의 원리를 따르는 API <br>
# ※ RESTful: REST의 원리를 따르는 시스템

# %% [markdown]
# ## HTML
# HTML(HyperText Markup Language)은 웹 페이지 표시를 위해 개발된 지배적인 마크업 언어 <br>
# HTML은 웹 페이지 콘텐츠 안의 꺾쇠 괄호에 둘러싸인 "태그"로 되어있는 HTML 요소 형태로 작성 <br>
# HTML은 웹 브라우저와 같은 HTML 처리 장치의 행동에 영향을 주는 자바스크립트, 본문과 그 밖의 항목의 외관과 배치를 정의하는 CSS 같은 스크립트를 포함하거나 불러올 수 있음 <br>
# <br>
# HTML 선택자: HTML에서는 다수의 동일한 태그가 존재하는데 각 태그를 구별할 수 있도록 선택자를 이용
# ```html
# <div>
# 	<div>
#       <a> c </a>
#       <span> c++ </span>
#     </div>
#
#     <div>
#       <a> java </a>
#       <span> python </span>
#     </div>
# </div>
# ```
#
# ```html
# <div id="contents">
# 	<div class="data1">
#       <span class="language"> c++ </span>
#       <span class="language"> java </span>
#       <span class="language"> python </span>
#   </div>
#
#   <div class="data2">
#       <a class="framework"> tensorflow </a>
#       <a class="framework"> pytorch </a>
#       <a class="framework"> spring </a>
#   </div>
# </div>
# ```

# %%
response = requests.get("https://jsonplaceholder.typicode.com/users/1")
bs = BeautifulSoup(response.text, 'lxml')
bs
# Out:
# <html><body><p>{
#   "id": 1,
#   "name": "Leanne Graham",
#   "username": "Bret",
#   "email": "Sincere@april.biz",
#   "address": {
#     "street": "Kulas Light",
#     "suite": "Apt. 556",
#     "city": "Gwenborough",
#     "zipcode": "92998-3874",
#     "geo": {
#       "lat": "-37.3159",
#       "lng": "81.1496"
#     }
#   },
#   "phone": "1-770-736-8031 x56442",
#   "website": "hildegard.org",
#   "company": {
#     "name": "Romaguera-Crona",
#     "catchPhrase": "Multi-layered client-server neural-net",
#     "bs": "harness real-time e-markets"
#   }
# }</p></body></html>

# %% [markdown]
# ## 정적크롤링

# %% [markdown]
# ### 라이브러리

# %% [markdown]
# #### requests
#
# requests: 파이썬용 http 라이브러리 <br>
# reference: https://requests.readthedocs.io/en/latest/
#
# 메소드별 사용법
# ```python
# GET: requests.get()
# POST: requests.post()
# PUT: requests.put()
# DELETE: requests.delete()
# ```
#
# ```python
# import requests
#
# requests.get("https://jsonplaceholder.typicode.com/users/1")
# ```

# %% [markdown]
# ##### Response Body
#
# 요청이 정상적으로 처리가 되면, response body에 요청한 데이터가 담겨져 옴. <br>
# response body 크게 3가지 방식으로 읽을 수 있음 <br>
# 1. content: binary 원문을 읽음
# ```python
# response.content
# ```
# 2. text: utf-8로 인코딩 된 문자열로 읽음
# ```python
# response.text
# ```
# 3. json: 응답이 json이면 dict로 읽음
# ```python
# response.json()
# ```

# %% [markdown]
# ##### Request
#
# param: 주소에 포함된 변수를 담음<br>
# ex) https://www.naver.com/post/12345 <br>
# -> 12345 <br>
# query: 주소 바깥? 이후의 주소를 담음<br>
# ex) https://www.naver.com/post/post_id=12345&id=1 <br>
# -> 12345, 1
# body: XML, JSON 등의 데이터를 담음, 주소에서는 확인 불가<br>
# <br>
#
# requests에서는 아래와 같이 사용
# - get
# ```python
# response = requests.get("https://naver.com/post", params={"post_id": "12345", "id": "1"})
# ```
#
# - post, put: HTML 데이터 전송
# ```python
# response = requests.get("https://naver.com/post", data={"post_id": "12345", "id": "1"})
# ```
# json 형태로도 요청 가능
# ```python
# response = requests.get("https://naver.com/post", json={"post_id": "12345", "id": "1"})
# ```

# %% [markdown]
# ##### headers
#
# 일부 웹 사이트는 bot agent를 차단 <br>
# 이 경우 header의 user-agent를 아래와 같이 넘기면 해결 <br>
# ```python
# requests.get("https://naver.com/post", headers={'User-Agent': 'Mozilla 5.0'})
# ```

# %% [markdown]
# #### BeautifulSoup
#
# BeautifulSoup: html, xml 등으로부터 원하는 정보를 가지고 올 수 있도록 하는 라이브러리 <br>
# reference: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# ```python
# import requests
# from bs4 import BeautifulSoup
#
# response = requests.get(url)
# bs = BeautifulSoup(response.text, 'lxml')
# ```

# %% [markdown]
# ###### Parser
#
# |parser|특징|설치|속도|사용방법|
# |------|---|---|---|------|
# |html.parser||기본|보통|BeautifulSoup(html_doc, 'html.parser')|
# |lxml|xml 지원|lxml 필요|빠름|BeautifulSoup(html_doc, 'lxml')|
# |xml|xml 지원|lxml 필요|빠름|BeautifulSoup(html_doc, 'xml')|
# |html5lib|브라우저와 동일|html5lib 필요|느림|BeautifulSoup(html_doc, 'html5lib')|

# %% [markdown]
# ##### find
# 속성과 값을 이용하여 원하는 값을 찾음
#
# find: 매칭되는 값 중 상위 1개 반환
# find_all: 매칭되는 전체 반환
#
# 특정 태그 추출
# ```python
# soup.find_all('p') # p 태그 추출
# ```
# <br>
#
# 특정 클래스 추출
# ```python
# soup.find_all(class_='a') # a 클래스 추출
# ```
# <br>
#
# 특정 태그와 class 추출
# ```python
# soup.find_all('p', attrs={'class': 'a'}) # p 태그와 a 클래스 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 id 추출
# ```python
# soup.find_all(id='b') # b id를 갖는 값 추출
# ```
# <br>

# %% [markdown]
# ##### select
# CSS Selector로 태그를 찾아 반환 <br>
# CSS에서 HTML을 태깅하는 방법을 활용 <br>
# <br>
# select_one: 매칭되는 값 중 상위 1개 반환 <br>
# select: 매칭되는 전체 반환 <br>
# <br>
#
# 특정 태그 추출
# ```python
# soup.select('p') # p 태그 추출
# ```
# <br>
#
# 특정 클래스 추출
# ```python
# soup.select('.a') # a 클래스 추출
# ```
# <br>
#
# 특정 태그와 class 추출
# ```python
# soup.select('p.a') # p 태그와 a 클래스 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 id 추출
# ```python
# soup.select('#b') # b id를 갖는 값 추출
# ```
# <br>
#
# 특정 태그와 id 추출
# ```python
# soup.select('p#b') # p 태그와 b id 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 태그와 class, id 모두 추출
# ```python
# soup.select('p.a#b') # p 태그와 a 클래스 b id 모두 갖는 값 추출
# ```
# <br>
#
# 특정 태그 아래에 있는 태그 찾기
# ```python
# soup.select('div p') # div 아래 p태그가 있는 값 추출
# soup.select('div > p') # div 바로 아래 p태그가 있는 값 추출
# soup.select("div > #link") # div 바로 아래 link id가 있는 값 추출
# ```
# <br>
#
# 형제 태그 찾기
# ```python
# soup.select("#link + .sister") # link 태그와 형제 태그 중 바로 직후 1개
# soup.select("#link ~ .sister") # link 태그와 형제 태그 중 뒤에 태그 전부
# ```
# <br>
#
# 여러 태그 중 i번째 태그 추출
# ```python
# soup.select('a:nth-of-type(i)') # 추출된 a태그 중 i번째 값 반환
# ```
# <br>
# <br>
#
# 정규표현식 활용 <br>
# ```python
# soup.select('[class~=a]') # class 속성 중 a를 포함하는 태그
# soup.select('a[href]') # a 태그 중 href 속성이 존재하는 태그
# soup.select('a[href="https://www.naver.com"]') # a 태그 중 href 속성이 https://www.naver.com과 매칭되는 태그
# soup.select('a[href^="https://"]') # a 태그 중 href 속성이 https://로 시작하는 태그
# soup.select('a[href$="ac.kr"]') # a 태그 중 href 속성이 ac.kr로 끝나는 태그
# soup.select('a[href*="naver"]') # a 태그 중 href 속성 중 naver를 가지는 태그
# ```
#
# <br>
# <br>
#
# 출력
# ```python
# soup.strings # 값 반환
# soup.stripped_strings # 공백을 제거한 값 반환
# ```

# %% [markdown]
# ### 실습

# %% [markdown]
# ##### 예제
#
# ```html
# <div id="contents">
#     <div class="data1">
#       <span class="language"> c++ </span>
#       <span class="language"> java </span>
#       <span class="language"> python </span>
#   </div>
#
#   <div class="data2">
#       <a class="framework"> tensorflow </a>
#       <a class="framework"> pytorch </a>
#       <a class="framework"> spring </a>
#   </div>
# </div>
# ```

# %%
response = '''
<div> 
	<div> 
      <a> c </a> 
      <span> c++ </span> 
    </div> 
    
    <div> 
      <a> java </a> 
      <span> python </span> 
    </div> 
</div>
'''

# %%
bs4 = BeautifulSoup(response, 'lxml')

# %%
languages = bs4.select('a')
languages
# Out:
# [<a> c </a>, <a> java </a>]

# %%
languages[0].text.strip()
# Out:
# 'c'

# %%
[language.text.strip() for language in languages]
# Out:
# ['c', 'java']

# %%
bs4.select('div')[2]
# Out:
# <div>
# <a> java </a>
# <span> python </span>
# </div>

# %%
bs4.select('div div a')
# Out:
# [<a> c </a>, <a> java </a>]

# %%
bs4.select('div > a')
# Out:
# [<a> c </a>, <a> java </a>]

# %%
response = '''
<div id="contents"> 
	<div class="data1"> 
      <span class="language"> c++ </span> 
      <span class="language"> java </span> 
      <span class="language"> python </span> 
  </div> 
    
  <div class="data2"> 
      <a class="framework"> tensorflow </a> 
      <a class="framework"> pytorch </a> 
      <a class="framework"> spring </a> 
  </div> 
</div>
'''

# %%
bs4 = BeautifulSoup(response, 'lxml')

# %%
bs4.select('.language')
# Out:
# [<span class="language"> c++ </span>,
#  <span class="language"> java </span>,
#  <span class="language"> python </span>]

# %%
bs4.select('span.language')
# Out:
# [<span class="language"> c++ </span>,
#  <span class="language"> java </span>,
#  <span class="language"> python </span>]

# %%
bs4.select('.data2')[0].select('a')
# Out:
# [<a class="framework"> tensorflow </a>,
#  <a class="framework"> pytorch </a>,
#  <a class="framework"> spring </a>]

# %%
bs4.select('div#contents')
# Out:
# [<div id="contents">
#  <div class="data1">
#  <span class="language"> c++ </span>
#  <span class="language"> java </span>
#  <span class="language"> python </span>
#  </div>
#  <div class="data2">
#  <a class="framework"> tensorflow </a>
#  <a class="framework"> pytorch </a>
#  <a class="framework"> spring </a>
#  </div>
#  </div>]

# %%
# ['tensorflow', 'pytorch', 'spring']
frameworks = bs4.select('a.framework')
frameworks = [framework.text.strip() for framework in frameworks]
frameworks
# Out:
# ['tensorflow', 'pytorch', 'spring']

# %% [markdown]
# #### 네이버 뉴스

# %%
response = requests.get('https://n.news.naver.com/mnews/article/009/0005351727')
if response.status_code == 200:
    bs = BeautifulSoup(response.text, 'lxml')

# %%
times = bs.select('div.media_end_head_info_datestamp_bunch > span')

# %%
[time.text for time in times][0].split()
# Out:
# ['2024.08.18.', '오후', '6:05']

# %%
times[0].text.split()
# Out:
# ['2024.08.18.', '오후', '6:05']

# %%
def convert_to_datetime(date: str):
    date, am_pm, time = date.split()

    hour, minute = time.split(':')
    hour = int(hour)
    
    if (am_pm == '오후') and (hour != 12):
        hour += 12
    time = f'{hour}:{minute}'
    datetime_ = f'{date}{time}'

    return pd.to_datetime(datetime_, format='%Y.%m.%d.%H:%M')

# %%
posting_time, modifying_time = [convert_to_datetime(time.text) for time in times]

# %%
title = bs.select('h2#title_area > span')
title = title[0].text
title
# Out:
# '인구 비상사태, 기업 대응 낙제점'

# %%
reporter = bs.select('em.media_end_head_journalist_name')
reporter = reporter[0].text
reporter = reporter.split()[0]
reporter
# Out:
# '성승훈'

# %%
contents = bs.select('article#dic_area')
contents[0]
# Out:
# <article class="go_trans _article_content" id="dic_area">
# <span style="border-left:4px solid #959595; padding-left: 20px; display: inline-block"><strong>한미연 EPG 경영 평가, 300개 기업중 80점이상 5곳 그쳐<br/>육아 환경 여전히 팍팍 …"출산장려 기업 인센티브 부족"</strong></span><br/><br/>◆ 기업 인구대응 평가 ◆<br/><br/><span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP is_small">
# <div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a1">
# <img alt="" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/009/2024/08/18/0005351727_001_20240818204316565.jpg?type=w647" id="img1" style="display: none;"/>
# </div>
# </div></span><br/><br/>제조업 분야 중견기업에서 근무 중인 30대 여성 직장인 A씨는 수년째 출산을 미루고 있다. 회사에서 자리가 사라질 것 같은 불안감 때문이다. 그는 "주변 사례를 보면 육아휴직 후 돌아올 자리가 없을 것이라는 식으로 압박을 주는 일이 심심치 않게 있었다"며 "경력단절을 막기 위해 출산을 포기하든지 육아를 위해 퇴사하든지 선택지는 둘 중 하나"라고 토로했다.<br/><br/>국내 기업들의 인구위기 대응은 '낙제점'을 면치 못한 것으로 나타났다. 인구절벽에 직면해 정부가 출산·육아 지원책을 잇달아 내놓고 있지만 현장에서 제대로 작동하지 않고 있다는 지적이다. <br/><br/>18일 매일경제와 한반도미래인구연구원은 국내 최초로 자산 규모 1조원 이상 기업 300곳을 대상으로 EPG(환경·인구·투명경영) 경영평가 점수를 발표했다. 올해 3월 매일경제와 한미연이 제34차 국민보고대회에서 EPG 경영을 제안한 데 따른 후속 조치다. EPG는 ESG에서 'S(책임·Social)'를 'P(인구·Population)'로 바꾼 용어다. <br/><br/>EPG 평가에서 300개 기업 평균 점수는 55.5점에 그쳤다. 최고점은 85.3점이었으며 최저점은 16.2점으로 나타났다. 기초 평가 17개 지표를 기준으로 삼성전기(85.3점)가 1위를 차지했으며 롯데정밀화학(83.8점)과 신한카드·KB국민카드·KT&amp;G(80.9점)가 뒤를 이었다.<br/><br/>대부분 기업은 다방면에서 취약점을 노출했다. 남성 육아휴직을 의무화한 기업은 5%인 15곳에 불과했다. 출산·육아휴직 복귀 지원 프로그램을 체계적으로 운영하는 곳도 27곳에 그쳤다.<br/><br/>산업계에서는 대부분 출산·양육 지원 제도가 사용자가 아닌 근로자에게만 초점이 맞춰진 점을 지적한다. 정만기 한국산업연합포럼 회장은 "기업이 부담해야 하는 인력난이나 생산성 저하 등에 대한 사업주 지원책은 부족하다"며 "가령 출산을 장려하는 기업에 세금을 깎아주는 인적자본 투자세액공제 도입을 검토할 필요가 있다"고 조언했다.<br/><br/>우수 기업에 대한 지원을 강화하기 위해 기업공시 항목에 이를 반영하자는 의견도 제시됐다. 포괄적으로만 공시했던 출산·육아휴직 항목을 상세히 밝히자는 것이다. 출산·육아휴직 사용률, 휴직기간, 복직자 규모, 복직기간 등을 공시할 필요가 있다는 취지다. 일본은 종업원 1000명 이상 기업에 대해 남성 육아휴직 현황을 공시하게 한 이후 남성 육아휴직 사용률이 30%대를 넘어섰다.<br/><br/>이인실 한미연 원장은 "시대 변화에 따라 최고디지털책임자(CDO)나 최고인공지능책임자(CAIO) 같은 새 직책이 생겨나듯 기업에 최고인구책임자(CPO)를 만들고 인구위기 대응 전담 부서를 설치하는 방안도 생각할 수 있을 것"이라며 "근본적인 발상의 전환이 필요하다"고 강조했다. <br/><br/>[성승훈 기자]<br/><br/><!-- r_start //--><!-- r_end //-->
# </article>

# %%
press_id = '009'
article_id = 'https://n.news.naver.com/mnews/article/009/0005351727'.split('/')[-1]

# %%
with psycopg2.connect(
    host='localhost',
    dbname='postgres',
    user='postgres',
    password='1234',
    port=5432,
) as conn:
    with conn.cursor() as cur:
        f"""INSERT INTO article VALUES ('{press_id}', '{article_id}', '{posting_time}', '{modifying_time}', '{reporter}', '{title}', '{contents[0].text.replace('\'', '').replace('\"', '')}')"""
        cur.execute()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[149], line 9
#       1 with psycopg2.connect(
#       2     host='localhost',
#       3     dbname='postgres',
#    (...)
#       6     port=5432,
#       7 ) as conn:
#       8     with conn.cursor() as cur:
# ----> 9         f"""INSERT INTO article VALUES ('{press_id}', '{article_id}', '{posting_time}', '{modifying_time}', '{reporter}', '{title}', '{contents[0].text.replace('\'', '').replace('\"', '')}')"""
#      10         cur.execute()
#
# AttributeError: 'str' object has no attribute 'text'

# %%
## 한 페이지 crawling

# %%
response = requests.get('https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=009&date=20240819&page=1')
bs = BeautifulSoup(response.text, 'lxml')

url_with_problem = []
press_id = '009'
for url in tqdm(list(set([tag.attrs.get('href') for tag in bs.select('li dl a')]))):
    article_id = url.split('/')[-1]

    response = requests.get(url)
    if response.status_code == 200:
        bs = BeautifulSoup(response.text, 'lxml')
    else:
        url_with_problem.append(url)
        continue

    times = bs.select('div.media_end_head_info_datestamp_bunch > span')
    if times and len(times) == 2:
        posting_time, modifying_time = [convert_to_datetime(time.text) for time in times]
    elif times and len(times) == 1:
        posting_time = [convert_to_datetime(time.text) for time in times][0]
        modifying_time = posting_time
    else:
        url_with_problem.append(url)
        continue

    title = bs.select('h2#title_area > span')
    if title:
        title = title[0].text
    elif not title:
        title = bs.select('h2.NewsEndMain_article_title__kqEzS')
        title = title[0].text
    else:
        url_with_problem.append(url)
        continue

    reporter = bs.select('em.media_end_head_journalist_name')
    if reporter:
        reporter = reporter[0].text
        reporter = reporter.split()[0]
    else:
        reporter = ''
    
    contents = bs.select('article#dic_area')
    if contents:
        contents = contents[0].text.replace('\'', '').replace('\"', '')
    elif not contents:
        contents = bs.select('article#comp_news_article')
        contents = contents[0].text.replace('\'', '').replace('\"', '')
    else:
        url_with_problem.append(url)
        continue

    with psycopg2.connect(
        host='localhost',
        dbname='postgres',
        user='postgres',
        password='1234',
        port=5432,
    ) as conn:
        with conn.cursor() as cur:
            try:                
                cur.execute(f"""INSERT INTO article VALUES ('{press_id}', '{article_id}', '{posting_time}', '{modifying_time}', '{reporter}', '{title}', '{contents}')""")
            except Exception:
                url_with_problem.append(url)
# Out:
# 100%|██████████| 24/24 [00:03<00:00,  6.84it/s]

# %% [markdown]
# ## 전체 페이지 crawling

# %%
url = 'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=009&date=20240819&page=100000'
response = requests.get(url)
bs = BeautifulSoup(response.text, 'lxml')

last_page_num = bs.select('div.paging > strong')
last_page_num = int(last_page_num[0].text)

url_with_problem = []
press_id = '009'
for page in tqdm(range(1, last_page_num+1)):
    response = requests.get(f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=009&date=20240819&page={page}')
    bs = BeautifulSoup(response.text, 'lxml')

    for url in list(set([tag.attrs.get('href') for tag in bs.select('li dl a')])):
        article_id = url.split('/')[-1]

        response = requests.get(url)
        if response.status_code == 200:
            bs = BeautifulSoup(response.text, 'lxml')
        else:
            url_with_problem.append(url)
            continue

        times = bs.select('div.media_end_head_info_datestamp_bunch > span')
        if times and len(times) == 2:
            posting_time, modifying_time = [convert_to_datetime(time.text) for time in times]
        elif times and len(times) == 1:
            posting_time = [convert_to_datetime(time.text) for time in times][0]
            modifying_time = posting_time
        else:
            url_with_problem.append(url)
            continue

        title = bs.select('h2#title_area > span')
        if title:
            title = title[0].text
        elif not title:
            title = bs.select('h2.NewsEndMain_article_title__kqEzS')
            title = title[0].text
        else:
            url_with_problem.append(url)
            continue

        reporter = bs.select('em.media_end_head_journalist_name')
        if reporter:
            reporter = reporter[0].text
            reporter = reporter.split()[0]
        else:
            reporter = ''
        
        contents = bs.select('article#dic_area')
        if contents:
            contents = contents[0].text.replace('\'', '').replace('\"', '')
        elif not contents:
            contents = bs.select('article#comp_news_article')
            contents = contents[0].text.replace('\'', '').replace('\"', '')
        else:
            url_with_problem.append(url)
            continue

        with psycopg2.connect(
            host='localhost',
            dbname='postgres',
            user='postgres',
            password='1234',
            port=5432,
        ) as conn:
            with conn.cursor() as cur:
                try:                
                    cur.execute(f"""INSERT INTO article VALUES ('{press_id}', '{article_id}', '{posting_time}', '{modifying_time}', '{reporter}', '{title}', '{contents}')""")
                except Exception:
                    url_with_problem.append(url)
# Out:
# 100%|██████████| 24/24 [00:03<00:00,  6.69it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.92it/s]
# 100%|██████████| 20/20 [00:03<00:00,  6.61it/s]
# 100%|██████████| 20/20 [00:03<00:00,  6.04it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.58it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.92it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.47it/s]
# 100%|██████████| 20/20 [00:03<00:00,  6.03it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.27it/s]
# 100%|██████████| 20/20 [00:02<00:00,  6.70it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.85it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.61it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.32it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.99it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.43it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.37it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5.55it/s]t]
# 100%|██████████| 17/17 [01:03<00:00,  3.73s/it]

# %%
## 여러 날짜의 데이터 crawling

# %%
url_with_problem = []
press_id = '009'
for date in tqdm(pd.date_range('2024-08-17', '2024-08-19')):
    date = date.strftime('%Y%m%d')

    url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=009&date={date}&page=100000'
    response = requests.get(url)
    bs = BeautifulSoup(response.text, 'lxml')

    last_page_num = bs.select('div.paging > strong')
    last_page_num = int(last_page_num[0].text)

    for page in range(1, last_page_num+1):
        response = requests.get(f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=009&date={date}&page={page}')
        bs = BeautifulSoup(response.text, 'lxml')

        for url in list(set([tag.attrs.get('href') for tag in bs.select('li dl a')])):
            article_id = url.split('/')[-1]

            response = requests.get(url)
            if response.status_code == 200:
                bs = BeautifulSoup(response.text, 'lxml')
            else:
                url_with_problem.append(url)
                continue

            times = bs.select('div.media_end_head_info_datestamp_bunch > span')
            if times and len(times) == 2:
                posting_time, modifying_time = [convert_to_datetime(time.text) for time in times]
            elif times and len(times) == 1:
                posting_time = [convert_to_datetime(time.text) for time in times][0]
                modifying_time = posting_time
            else:
                url_with_problem.append(url)
                continue

            title = bs.select('h2#title_area > span')
            if title:
                title = title[0].text
            elif not title:
                title = bs.select('h2.NewsEndMain_article_title__kqEzS')
                title = title[0].text
            else:
                url_with_problem.append(url)
                continue

            reporter = bs.select('em.media_end_head_journalist_name')
            if reporter:
                reporter = reporter[0].text
                reporter = reporter.split()[0]
            else:
                reporter = ''
            
            contents = bs.select('article#dic_area')
            if contents:
                contents = contents[0].text.replace('\'', '').replace('\"', '')
            elif not contents:
                contents = bs.select('article#comp_news_article')
                contents = contents[0].text.replace('\'', '').replace('\"', '')
            else:
                url_with_problem.append(url)
                continue

            with psycopg2.connect(
                host='localhost',
                dbname='postgres',
                user='postgres',
                password='1234',
                port=5432,
            ) as conn:
                with conn.cursor() as cur:
                    try:                
                        cur.execute(f"""INSERT INTO article VALUES ('{press_id}', '{article_id}', '{posting_time}', '{modifying_time}', '{reporter}', '{title}', '{contents}')""")
                    except Exception:
                        url_with_problem.append(url)
# Out:
# 100%|██████████| 3/3 [03:03<00:00, 61.00s/it]

# %%
## 함수화

# %%
def crawler(press_id: str, start_date: str, end_date: str, **kwargs) -> list:
    url_with_problem = []
    for date in tqdm(pd.date_range(start_date, end_date)):
        date = date.strftime('%Y%m%d')

        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={press_id}&date={date}&page=100000'
        response = requests.get(url)
        bs = BeautifulSoup(response.text, 'lxml')

        last_page_num = bs.select('div.paging > strong')
        last_page_num = int(last_page_num[0].text)

        for page in range(1, last_page_num+1):
            response = requests.get(f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={press_id}&date={date}&page={page}')
            bs = BeautifulSoup(response.text, 'lxml')

            for url in list(set([tag.attrs.get('href') for tag in bs.select('li dl a')])):
                article_id = url.split('/')[-1]

                response = requests.get(url)
                if response.status_code == 200:
                    bs = BeautifulSoup(response.text, 'lxml')
                else:
                    url_with_problem.append(url)
                    continue

                times = bs.select('div.media_end_head_info_datestamp_bunch > span')
                if times and len(times) == 2:
                    posting_time, modifying_time = [convert_to_datetime(time.text) for time in times]
                elif times and len(times) == 1:
                    posting_time = [convert_to_datetime(time.text) for time in times][0]
                    modifying_time = posting_time
                else:
                    url_with_problem.append(url)
                    continue

                title = bs.select('h2#title_area > span')
                if title:
                    title = title[0].text
                elif not title:
                    title = bs.select('h2.NewsEndMain_article_title__kqEzS')
                    title = title[0].text
                else:
                    url_with_problem.append(url)
                    continue

                reporter = bs.select('em.media_end_head_journalist_name')
                if reporter:
                    reporter = reporter[0].text
                    reporter = reporter.split()[0]
                else:
                    reporter = ''
                
                contents = bs.select('article#dic_area')
                if contents:
                    contents = str(contents[0])
                elif not contents:
                    contents = bs.select('article#comp_news_article')
                    contents = str(contents[0])
                else:
                    url_with_problem.append(url)
                    continue

                with psycopg2.connect(
                    host=kwargs.get('host'),
                    dbname=kwargs.get('dbname'),
                    user=kwargs.get('user'),
                    password=kwargs.get('password'),
                    port=kwargs.get('port'),
                ) as conn:
                    with conn.cursor() as cur:
                        try:                
                            cur.execute(f"""INSERT INTO article VALUES ('{press_id}', '{article_id}', '{posting_time}', '{modifying_time}', '{reporter}', '{title}', '{contents}')""")
                        except Exception:
                            url_with_problem.append(url)
    
    return url_with_problem

# %%
url_with_problem = crawler(
    '025', '2024-08-18', '2024-08-19',
    host='localhost', dbname='postgres', user='postgres', password='1234', port=5432,
)
# Out:
# 100%|██████████| 2/2 [01:03<00:00, 31.58s/it]

# %% [markdown]
# #### 네이버 증권

# %%
url = 'https://finance.naver.com/item/main.naver?code=005930'
response = requests.get(url)
bs4 = BeautifulSoup(response.text, 'lxml')


# stock_code
stock_code = bs4.select('span.code')[0].text

# stock_name
stock_name = bs4.select('div.wrap_company > h2 > a')[0].text

# open_price
open_price = bs4.select('td.first em span.blind')[-1].text

# high_price
high_price = bs4.select('em.no_up span.blind')[-3]

# low_price
low_price = bs4.select('em.no_up span.blind')[-1]

# volume
volume = bs4.select('table.no_info')[0].select('tr')[0].select('td')[-1].select('span.blind')[0].text

# close_price
close_price = bs4.select('div.today span.blind')[0].text

# %%
# 시가총액
market_cap = bs4.select('em#_market_sum')[0].text.strip().replace('\n', '').replace('\t', '')

# 상장주식수
num_of_stocks = bs4.select('div.first table')[0].select('tr')[2].select('td')[0].text

# 액면가
face_price = bs4.select('div.first table')[0].select('tr')[-1].select('td')[0].text.strip().replace('\n', '').replace('\t', '')

# per
per = bs4.select('em#_per')[0].text

# pbr
pbr = bs4.select('em#_pbr')[0].text

# 배당수익률
dvr = bs4.select('em#_dvr')[0].text

# 동일업종 PER
same_field_per = bs4.select('div.gray')[-1].select('tr')[0].select('em')[0].text

# %%
def extract_information(stock_code):
    url = f'https://finance.naver.com/item/main.naver?code={stock_code}'
    response = requests.get(url)
    bs4 = BeautifulSoup(response.text, 'lxml')

    # stock_code
    stock_code = bs4.select('span.code')[0].text

    # stock_name
    stock_name = bs4.select('div.wrap_company > h2 > a')[0].text

    # open_price
    open_price = bs4.select('td.first em span.blind')[-1].text

    # high_price
    high_price = bs4.select('em.no_up span.blind')[-3].text

    # low_price
    low_price = bs4.select('em.no_up span.blind')[-1].text

    # volume
    volume = bs4.select('table.no_info')[0].select('tr')[0].select('td')[-1].select('span.blind')[0].text

    # close_price
    close_price = bs4.select('div.today span.blind')[0].text

    return stock_code, stock_name, open_price, high_price, low_price, volume, close_price

# %%
extract_information('005930')
# Out:
# ('005930', '삼성전자', '79,500', '79,800', '78,700', '4,774,832', '79,300')

# %%
# 시가총액 페이지에서 종목 코드 수집
all_codes= []
for page in range(1, 11):
    url = f'https://finance.naver.com/sise/sise_market_sum.naver?&page={page}'
    response = requests.get(url, headers={'user-agent': 'Mozilla 5.0'})
    bs = BeautifulSoup(response.text, 'lxml')

    codes = [tag.attrs.get('href').split('=')[-1] for tag in bs.select('tr td a') if 'main.naver?' in tag.attrs.get('href')]
    all_codes.extend(codes)

# %%
# 수집한 코드를 함수에 입력하여 정보 추출 후 디비 입력

for code in all_codes:
    extract_information(code)

# %% [markdown]
# #### 다음 증권

# %%
url = 'https://finance.daum.net/domestic/market_cap'
response = requests.get(url, headers={'user-agent': 'Mozilla 5.0'})
bs = BeautifulSoup(response.text, 'lxml')

# %%
bs.select('div.box_contents')
# Out:
# []

# %%
url = 'https://finance.daum.net/api/trend/market_capitalization?page=1&perPage=30&fieldName=marketCap&order=desc&market=KOSPI&pagination=true'
response = requests.get(
    url,
    headers={
        'user-agent': 'Mozilla 5.0',
        'Referer': 'https://finance.daum.net/domestic/market_cap',
        },
    )
result = json.loads(response.text)

# %%
def crawl_daum_finance(page):
    url = f'https://finance.daum.net/api/trend/market_capitalization?page={page}&perPage=30&fieldName=marketCap&order=desc&market=KOSPI&pagination=true'
    response = requests.get(
        url,
        headers={
            'user-agent': 'Mozilla 5.0',
            'Referer': 'https://finance.daum.net/domestic/market_cap',
            },
        )
    result = json.loads(response.text).get('data')

    return result

# %%
data = []

for page in tqdm(range(1, 77)):
    data.extend(crawl_daum_finance(page))
# Out:
# 100%|██████████| 76/76 [00:02<00:00, 37.92it/s]

# %%
data
# Out:
# [{'rank': 1,
#   'code': 'KR7005930003',
#   'name': '삼성전자',
#   'symbolCode': 'A005930',
#   'tradePrice': 79600.0,
#   'change': 'RISE',
#   'changePrice': 1300.0,
#   'changeRate': 0.0166028097,
#   'marketCap': 475194690980000,
#   'listedShareCount': 5969782550,
#   'foreignRatio': '0.5623283582'},
#  {'rank': 2,
#   'code': 'KR7000660001',
#   'name': 'SK하이닉스',
#   'symbolCode': 'A000660',
#   'tradePrice': 200500.0,
#   'change': 'RISE',
#   'changePrice': 6600.0,
#   'changeRate': 0.034038164,
#   'marketCap': 145964474182500,
#   'listedShareCount': 728002365,
#   'foreignRatio': '0.5491759563'},
#  {'rank': 3,
#   'code': 'KR7373220003',
#   'name': 'LG에너지솔루션',
#   'symbolCode': 'A373220',
#   'tradePrice': 329000.0,
#   'change': 'FALL',
#   'changePrice': 500.0,
#   'changeRate': 0.0015174507,
#   'marketCap': 76986000000000,
#   'listedShareCount': 234000000,
#   'foreignRatio': '0.0476472308'},
#  {'rank': 4,
#   'code': 'KR7207940008',
#   'name': '삼성바이오로직스',
#   'symbolCode': 'A207940',
#   'tradePrice': 908000.0,
#   'change': 'FALL',
#   'changePrice': 22000.0,
#   'changeRate': 0.023655914,
#   'marketCap': 64625992000000,
#   'listedShareCount': 71174000,
#   'foreignRatio': '0.1279159384'},
#  {'rank': 5,
#   'code': 'KR7005380001',
#   'name': '현대차',
#   'symbolCode': 'A005380',
#   'tradePrice': 258500.0,
#   'change': 'RISE',
#   'changePrice': 3500.0,
#   'changeRate': 0.0137254902,
#   'marketCap': 54134085373500,
#   'listedShareCount': 209416191,
#   'foreignRatio': '0.4101665998'},
#  {'rank': 6,
#   'code': 'KR7005931001',
#   'name': '삼성전자우',
#   'symbolCode': 'A005935',
#   'tradePrice': 63800.0,
#   'change': 'RISE',
#   'changePrice': 400.0,
#   'changeRate': 0.0063091483,
#   'marketCap': 52500171460000,
#   'listedShareCount': 822886700,
#   'foreignRatio': '0.760610694'},
#  {'rank': 7,
#   'code': 'KR7068270008',
#   'name': '셀트리온',
#   'symbolCode': 'A068270',
#   'tradePrice': 197100.0,
#   'change': 'FALL',
#   'changePrice': 500.0,
#   'changeRate': 0.0025303644,
#   'marketCap': 42774876549000,
#   'listedShareCount': 217021190,
#   'foreignRatio': '0.2271851196'},
#  {'rank': 8,
#   'code': 'KR7000270009',
#   'name': '기아',
#   'symbolCode': 'A000270',
#   'tradePrice': 103600.0,
#   'change': 'RISE',
#   'changePrice': 400.0,
#   'changeRate': 0.003875969,
#   'marketCap': 41425332001200,
#   'listedShareCount': 399858417,
#   'foreignRatio': '0.4131920824'},
#  {'rank': 9,
#   'code': 'KR7105560007',
#   'name': 'KB금융',
#   'symbolCode': 'A105560',
#   'tradePrice': 88200.0,
#   'change': 'RISE',
#   'changePrice': 1200.0,
#   'changeRate': 0.0137931034,
#   'marketCap': 35589676550400,
#   'listedShareCount': 403511072,
#   'foreignRatio': '0.7632441'},
#  {'rank': 10,
#   'code': 'KR7055550008',
#   'name': '신한지주',
#   'symbolCode': 'A055550',
#   'tradePrice': 58100.0,
#   'change': 'RISE',
#   'changePrice': 900.0,
#   'changeRate': 0.0157342657,
#   'marketCap': 29595745733400,
#   'listedShareCount': 509393214,
#   'foreignRatio': '0.6049753207'},
#  {'rank': 11,
#   'code': 'KR7005490008',
#   'name': 'POSCO홀딩스',
#   'symbolCode': 'A005490',
#   'tradePrice': 322000.0,
#   'change': 'FALL',
#   'changePrice': 500.0,
#   'changeRate': 0.0015503876,
#   'marketCap': 27231936060000,
#   'listedShareCount': 84571230,
#   'foreignRatio': '0.2820921488'},
#  {'rank': 12,
#   'code': 'KR7028260008',
#   'name': '삼성물산',
#   'symbolCode': 'A028260',
#   'tradePrice': 145800.0,
#   'change': 'RISE',
#   'changePrice': 1600.0,
#   'changeRate': 0.0110957004,
#   'marketCap': 25920922800600,
#   'listedShareCount': 177784107,
#   'foreignRatio': '0.2689634063'},
#  {'rank': 13,
#   'code': 'KR7035420009',
#   'name': 'NAVER',
#   'symbolCode': 'A035420',
#   'tradePrice': 157100.0,
#   'change': 'RISE',
#   'changePrice': 500.0,
#   'changeRate': 0.003192848,
#   'marketCap': 25259246206800,
#   'listedShareCount': 160784508,
#   'foreignRatio': '0.4316530297'},
#  {'rank': 14,
#   'code': 'KR7006400006',
#   'name': '삼성SDI',
#   'symbolCode': 'A006400',
#   'tradePrice': 307500.0,
#   'change': 'FALL',
#   'changePrice': 1500.0,
#   'changeRate': 0.0048543689,
#   'marketCap': 21145092975000,
#   'listedShareCount': 68764530,
#   'foreignRatio': '0.383352173'},
#  {'rank': 15,
#   'code': 'KR7012330007',
#   'name': '현대모비스',
#   'symbolCode': 'A012330',
#   'tradePrice': 221000.0,
#   'change': 'RISE',
#   'changePrice': 500.0,
#   'changeRate': 0.0022675737,
#   'marketCap': 20551915774000,
#   'listedShareCount': 92995094,
#   'foreignRatio': '0.4037451481'},
#  {'rank': 16,
#   'code': 'KR7051910008',
#   'name': 'LG화학',
#   'symbolCode': 'A051910',
#   'tradePrice': 286000.0,
#   'change': 'FALL',
#   'changePrice': 3500.0,
#   'changeRate': 0.01208981,
#   'marketCap': 20189410098000,
#   'listedShareCount': 70592343,
#   'foreignRatio': '0.3599401425'},
#  {'rank': 17,
#   'code': 'KR7032830002',
#   'name': '삼성생명',
#   'symbolCode': 'A032830',
#   'tradePrice': 95900.0,
#   'change': 'RISE',
#   'changePrice': 2300.0,
#   'changeRate': 0.0245726496,
#   'marketCap': 19180000000000,
#   'listedShareCount': 200000000,
#   'foreignRatio': '0.20862103'},
#  {'rank': 18,
#   'code': 'KR7086790003',
#   'name': '하나금융지주',
#   'symbolCode': 'A086790',
#   'tradePrice': 63800.0,
#   'change': 'RISE',
#   'changePrice': 900.0,
#   'changeRate': 0.0143084261,
#   'marketCap': 18652350952400,
#   'listedShareCount': 292356598,
#   'foreignRatio': '0.6943855668'},
#  {'rank': 19,
#   'code': 'KR7329180004',
#   'name': 'HD현대중공업',
#   'symbolCode': 'A329180',
#   'tradePrice': 209500.0,
#   'change': 'FALL',
#   'changePrice': 1500.0,
#   'changeRate': 0.0071090047,
#   'marketCap': 18597967802000,
#   'listedShareCount': 88773116,
#   'foreignRatio': '0.0988614616'},
#  {'rank': 20,
#   'code': 'KR7138040001',
#   'name': '메리츠금융지주',
#   'symbolCode': 'A138040',
#   'tradePrice': 92000.0,
#   'change': 'RISE',
#   'changePrice': 1000.0,
#   'changeRate': 0.010989011,
#   'marketCap': 17546250488000,
#   'listedShareCount': 190720114,
#   'foreignRatio': '0.1689468474'},
#  {'rank': 21,
#   'code': 'KR7000810002',
#   'name': '삼성화재',
#   'symbolCode': 'A000810',
#   'tradePrice': 348500.0,
#   'change': 'RISE',
#   'changePrice': 2000.0,
#   'changeRate': 0.0057720058,
#   'marketCap': 16510130694500,
#   'listedShareCount': 47374837,
#   'foreignRatio': '0.5405387252'},
#  {'rank': 22,
#   'code': 'KR7035720002',
#   'name': '카카오',
#   'symbolCode': 'A035720',
#   'tradePrice': 36500.0,
#   'change': 'FALL',
#   'changePrice': 150.0,
#   'changeRate': 0.0040927694,
#   'marketCap': 16187452269500,
#   'listedShareCount': 443491843,
#   'foreignRatio': '0.2664745719'},
#  {'rank': 23,
#   'code': 'KR7066570003',
#   'name': 'LG전자',
#   'symbolCode': 'A066570',
#   'tradePrice': 97400.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 15939297083600,
#   'listedShareCount': 163647814,
#   'foreignRatio': '0.3234428112'},
#  {'rank': 24,
#   'code': 'KR7259960003',
#   'name': '크래프톤',
#   'symbolCode': 'A259960',
#   'tradePrice': 331500.0,
#   'change': 'RISE',
#   'changePrice': 6500.0,
#   'changeRate': 0.02,
#   'marketCap': 15876868293000,
#   'listedShareCount': 47894022,
#   'foreignRatio': '0.4071125829'},
#  {'rank': 25,
#   'code': 'KR7003670007',
#   'name': '포스코퓨처엠',
#   'symbolCode': 'A003670',
#   'tradePrice': 201500.0,
#   'change': 'RISE',
#   'changePrice': 1000.0,
#   'changeRate': 0.0049875312,
#   'marketCap': 15608838830000,
#   'listedShareCount': 77463220,
#   'foreignRatio': '0.0950768248'},
#  {'rank': 26,
#   'code': 'KR7012450003',
#   'name': '한화에어로스페이스',
#   'symbolCode': 'A012450',
#   'tradePrice': 289000.0,
#   'change': 'FALL',
#   'changePrice': 11000.0,
#   'changeRate': 0.0366666667,
#   'marketCap': 14632070000000,
#   'listedShareCount': 50630000,
#   'foreignRatio': '0.3719600435'},
#  {'rank': 27,
#   'code': 'KR7009540006',
#   'name': 'HD한국조선해양',
#   'symbolCode': 'A009540',
#   'tradePrice': 200500.0,
#   'change': 'RISE',
#   'changePrice': 1200.0,
#   'changeRate': 0.0060210738,
#   'marketCap': 14190009758000,
#   'listedShareCount': 70773116,
#   'foreignRatio': '0.3003892749'},
#  {'rank': 28,
#   'code': 'KR7011200003',
#   'name': 'HMM',
#   'symbolCode': 'A011200',
#   'tradePrice': 17710.0,
#   'change': 'FALL',
#   'changePrice': 210.0,
#   'changeRate': 0.01171875,
#   'marketCap': 13265489474160,
#   'listedShareCount': 749039496,
#   'foreignRatio': '0.1048307765'},
#  {'rank': 29,
#   'code': 'KR7033780008',
#   'name': 'KT&G',
#   'symbolCode': 'A033780',
#   'tradePrice': 100700.0,
#   'change': 'FALL',
#   'changePrice': 400.0,
#   'changeRate': 0.0039564787,
#   'marketCap': 13123475447900,
#   'listedShareCount': 130322497,
#   'foreignRatio': '0.4509801788'},
#  {'rank': 30,
#   'code': 'KR7015760002',
#   'name': '한국전력',
#   'symbolCode': 'A015760',
#   'tradePrice': 19550.0,
#   'change': 'RISE',
#   'changePrice': 330.0,
#   'changeRate': 0.017169615,
#   'marketCap': 12550397705350,
#   'listedShareCount': 641964077,
#   'foreignRatio': '0.1463240769'},
#  {'rank': 31,
#   'code': 'KR7003550001',
#   'name': 'LG',
#   'symbolCode': 'A003550',
#   'tradePrice': 79600.0,
#   'change': 'FALL',
#   'changePrice': 400.0,
#   'changeRate': 0.005,
#   'marketCap': 12521159042800,
#   'listedShareCount': 157300993,
#   'foreignRatio': '0.3539386811'},
#  {'rank': 32,
#   'code': 'KR7042700005',
#   'name': '한미반도체',
#   'symbolCode': 'A042700',
#   'tradePrice': 126800.0,
#   'change': 'RISE',
#   'changePrice': 1900.0,
#   'changeRate': 0.0152121697,
#   'marketCap': 12298792791200,
#   'listedShareCount': 96993634,
#   'foreignRatio': '0.1266075875'},
#  {'rank': 33,
#   'code': 'KR7316140003',
#   'name': '우리금융지주',
#   'symbolCode': 'A316140',
#   'tradePrice': 16420.0,
#   'change': 'RISE',
#   'changePrice': 380.0,
#   'changeRate': 0.0236907731,
#   'marketCap': 12193352446420,
#   'listedShareCount': 742591501,
#   'foreignRatio': '0.4452553531'},
#  {'rank': 34,
#   'code': 'KR7402340004',
#   'name': 'SK스퀘어',
#   'symbolCode': 'A402340',
#   'tradePrice': 89200.0,
#   'change': 'RISE',
#   'changePrice': 3000.0,
#   'changeRate': 0.0348027842,
#   'marketCap': 12019696432000,
#   'listedShareCount': 134749960,
#   'foreignRatio': '0.5299858493'},
#  {'rank': 35,
#   'code': 'KR7017670001',
#   'name': 'SK텔레콤',
#   'symbolCode': 'A017670',
#   'tradePrice': 55200.0,
#   'change': 'RISE',
#   'changePrice': 100.0,
#   'changeRate': 0.001814882,
#   'marketCap': 11856410925600,
#   'listedShareCount': 214790053,
#   'foreignRatio': '0.4247522766'},
#  {'rank': 36,
#   'code': 'KR7034020008',
#   'name': '두산에너빌리티',
#   'symbolCode': 'A034020',
#   'tradePrice': 18090.0,
#   'change': 'FALL',
#   'changePrice': 140.0,
#   'changeRate': 0.0076796489,
#   'marketCap': 11587751131140,
#   'listedShareCount': 640561146,
#   'foreignRatio': '0.2131312566'},
#  {'rank': 37,
#   'code': 'KR7024110009',
#   'name': '기업은행',
#   'symbolCode': 'A024110',
#   'tradePrice': 14040.0,
#   'change': 'RISE',
#   'changePrice': 150.0,
#   'changeRate': 0.0107991361,
#   'marketCap': 11195859200760,
#   'listedShareCount': 797425869,
#   'foreignRatio': '0.1524230298'},
#  {'rank': 38,
#   'code': 'KR7267260008',
#   'name': 'HD현대일렉트릭',
#   'symbolCode': 'A267260',
#   'tradePrice': 309500.0,
#   'change': 'RISE',
#   'changePrice': 21000.0,
#   'changeRate': 0.0727902946,
#   'marketCap': 11156588282500,
#   'listedShareCount': 36047135,
#   'foreignRatio': '0.334745133'},
#  {'rank': 39,
#   'code': 'KR7010130003',
#   'name': '고려아연',
#   'symbolCode': 'A010130',
#   'tradePrice': 532000.0,
#   'change': 'RISE',
#   'changePrice': 6000.0,
#   'changeRate': 0.0114068441,
#   'marketCap': 11014146556000,
#   'listedShareCount': 20703283,
#   'foreignRatio': '0.1833897068'},
#  {'rank': 40,
#   'code': 'KR7018260000',
#   'name': '삼성에스디에스',
#   'symbolCode': 'A018260',
#   'tradePrice': 141800.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 10972172040000,
#   'listedShareCount': 77377800,
#   'foreignRatio': '0.1908435107'},
#  {'rank': 41,
#   'code': 'KR7009150004',
#   'name': '삼성전기',
#   'symbolCode': 'A009150',
#   'tradePrice': 144200.0,
#   'change': 'RISE',
#   'changePrice': 300.0,
#   'changeRate': 0.0020847811,
#   'marketCap': 10770830963200,
#   'listedShareCount': 74693696,
#   'foreignRatio': '0.3420671404'},
#  {'rank': 42,
#   'code': 'KR7323410001',
#   'name': '카카오뱅크',
#   'symbolCode': 'A323410',
#   'tradePrice': 21600.0,
#   'change': 'FALL',
#   'changePrice': 50.0,
#   'changeRate': 0.0023094688,
#   'marketCap': 10301604559200,
#   'listedShareCount': 476926137,
#   'foreignRatio': '0.1631696629'},
#  {'rank': 43,
#   'code': 'KR7034730002',
#   'name': 'SK',
#   'symbolCode': 'A034730',
#   'tradePrice': 139300.0,
#   'change': 'RISE',
#   'changePrice': 1000.0,
#   'changeRate': 0.007230658,
#   'marketCap': 10099626527900,
#   'listedShareCount': 72502703,
#   'foreignRatio': '0.2370731613'},
#  {'rank': 44,
#   'code': 'KR7030200000',
#   'name': 'KT',
#   'symbolCode': 'A030200',
#   'tradePrice': 38850.0,
#   'change': 'RISE',
#   'changePrice': 600.0,
#   'changeRate': 0.0156862745,
#   'marketCap': 9791042462250,
#   'listedShareCount': 252021685,
#   'foreignRatio': '0.4707251759'},
#  {'rank': 45,
#   'code': 'KR7010140002',
#   'name': '삼성중공업',
#   'symbolCode': 'A010140',
#   'tradePrice': 11030.0,
#   'change': 'RISE',
#   'changePrice': 230.0,
#   'changeRate': 0.0212962963,
#   'marketCap': 9706400000000,
#   'listedShareCount': 880000000,
#   'foreignRatio': '0.3184499398'},
#  {'rank': 46,
#   'code': 'KR7042660001',
#   'name': '한화오션',
#   'symbolCode': 'A042660',
#   'tradePrice': 31600.0,
#   'change': 'RISE',
#   'changePrice': 300.0,
#   'changeRate': 0.0095846645,
#   'marketCap': 9682663250400,
#   'listedShareCount': 306413394,
#   'foreignRatio': '0.16942745'},
#  {'rank': 47,
#   'code': 'KR7096770003',
#   'name': 'SK이노베이션',
#   'symbolCode': 'A096770',
#   'tradePrice': 100500.0,
#   'change': 'RISE',
#   'changePrice': 300.0,
#   'changeRate': 0.002994012,
#   'marketCap': 9621426795000,
#   'listedShareCount': 95735590,
#   'foreignRatio': '0.2163672778'},
#  {'rank': 48,
#   'code': 'KR7459580007',
#   'name': 'KODEX CD금리액티브(합성)',
#   'symbolCode': 'A459580',
#   'tradePrice': 1045550.0,
#   'change': 'RISE',
#   'changePrice': 95.0,
#   'changeRate': 9.08695e-05,
#   'marketCap': 9335402285000,
#   'listedShareCount': 8928700,
#   'foreignRatio': '8.62388E-5'},
#  {'rank': 49,
#   'code': 'KR7047050000',
#   'name': '포스코인터내셔널',
#   'symbolCode': 'A047050',
#   'tradePrice': 51000.0,
#   'change': 'RISE',
#   'changePrice': 300.0,
#   'changeRate': 0.0059171598,
#   'marketCap': 8972062188000,
#   'listedShareCount': 175922788,
#   'foreignRatio': '0.0655614212'},
#  {'rank': 50,
#   'code': 'KR7005830005',
#   'name': 'DB손해보험',
#   'symbolCode': 'A005830',
#   'tradePrice': 119900.0,
#   'change': 'RISE',
#   'changePrice': 8200.0,
#   'changeRate': 0.0734109221,
#   'marketCap': 8488920000000,
#   'listedShareCount': 70800000,
#   'foreignRatio': '0.4780240395'},
#  {'rank': 51,
#   'code': 'KR7326030004',
#   'name': 'SK바이오팜',
#   'symbolCode': 'A326030',
#   'tradePrice': 107700.0,
#   'change': 'RISE',
#   'changePrice': 300.0,
#   'changeRate': 0.0027932961,
#   'marketCap': 8434337025000,
#   'listedShareCount': 78313250,
#   'foreignRatio': '0.1136720031'},
#  {'rank': 52,
#   'code': 'KR7003490000',
#   'name': '대한항공',
#   'symbolCode': 'A003490',
#   'tradePrice': 21700.0,
#   'change': 'RISE',
#   'changePrice': 550.0,
#   'changeRate': 0.0260047281,
#   'marketCap': 7990388343700,
#   'listedShareCount': 368220661,
#   'foreignRatio': '0.1620569548'},
#  {'rank': 53,
#   'code': 'KR7086280005',
#   'name': '현대글로비스',
#   'symbolCode': 'A086280',
#   'tradePrice': 105700.0,
#   'change': 'RISE',
#   'changePrice': 1000.0,
#   'changeRate': 0.0095510984,
#   'marketCap': 7927500000000,
#   'listedShareCount': 75000000,
#   'foreignRatio': '0.4220469733'},
#  {'rank': 54,
#   'code': 'KR7000100008',
#   'name': '유한양행',
#   'symbolCode': 'A000100',
#   'tradePrice': 92200.0,
#   'change': 'FALL',
#   'changePrice': 4200.0,
#   'changeRate': 0.0435684647,
#   'marketCap': 7395275700800,
#   'listedShareCount': 80209064,
#   'foreignRatio': '0.2074113968'},
#  {'rank': 55,
#   'code': 'KR7090430000',
#   'name': '아모레퍼시픽',
#   'symbolCode': 'A090430',
#   'tradePrice': 121500.0,
#   'change': 'FALL',
#   'changePrice': 1400.0,
#   'changeRate': 0.0113913751,
#   'marketCap': 7106870218500,
#   'listedShareCount': 58492759,
#   'foreignRatio': '0.2971987695'},
#  {'rank': 56,
#   'code': 'KR7352820005',
#   'name': '하이브',
#   'symbolCode': 'A352820',
#   'tradePrice': 168800.0,
#   'change': 'RISE',
#   'changePrice': 400.0,
#   'changeRate': 0.0023752969,
#   'marketCap': 7030873973600,
#   'listedShareCount': 41652097,
#   'foreignRatio': '0.2005977754'},
#  {'rank': 57,
#   'code': 'KR7010950004',
#   'name': 'S-Oil',
#   'symbolCode': 'A010950',
#   'tradePrice': 62200.0,
#   'change': 'FALL',
#   'changePrice': 700.0,
#   'changeRate': 0.0111287758,
#   'marketCap': 7002649662400,
#   'listedShareCount': 112582792,
#   'foreignRatio': '0.7665779154'},
#  {'rank': 58,
#   'code': 'KR7267250009',
#   'name': 'HD현대',
#   'symbolCode': 'A267250',
#   'tradePrice': 83200.0,
#   'change': 'RISE',
#   'changePrice': 1700.0,
#   'changeRate': 0.0208588957,
#   'marketCap': 6572224672000,
#   'listedShareCount': 78993085,
#   'foreignRatio': '0.1992151718'},
#  {'rank': 59,
#   'code': 'KR7357870005',
#   'name': 'TIGER CD금리투자KIS(합성)',
#   'symbolCode': 'A357870',
#   'tradePrice': 54800.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 6118748800000,
#   'listedShareCount': 111656000,
#   'foreignRatio': '4.68224E-5'},
#  {'rank': 60,
#   'code': 'KR7005382007',
#   'name': '현대차2우B',
#   'symbolCode': 'A005387',
#   'tradePrice': 169100.0,
#   'change': 'RISE',
#   'changePrice': 900.0,
#   'changeRate': 0.0053507729,
#   'marketCap': 6046913018100,
#   'listedShareCount': 35759391,
#   'foreignRatio': '0.628506481'},
#  {'rank': 61,
#   'code': 'KR7011070000',
#   'name': 'LG이노텍',
#   'symbolCode': 'A011070',
#   'tradePrice': 250000.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 5916776750000,
#   'listedShareCount': 23667107,
#   'foreignRatio': '0.266181625'},
#  {'rank': 62,
#   'code': 'KR7069500007',
#   'name': 'KODEX 200',
#   'symbolCode': 'A069500',
#   'tradePrice': 36980.0,
#   'change': 'RISE',
#   'changePrice': 415.0,
#   'changeRate': 0.0113496513,
#   'marketCap': 5894612000000,
#   'listedShareCount': 159400000,
#   'foreignRatio': '0.315263739'},
#  {'rank': 63,
#   'code': 'KR7064350002',
#   'name': '현대로템',
#   'symbolCode': 'A064350',
#   'tradePrice': 51900.0,
#   'change': 'FALL',
#   'changePrice': 1300.0,
#   'changeRate': 0.0244360902,
#   'marketCap': 5664485006700,
#   'listedShareCount': 109142293,
#   'foreignRatio': '0.2406755739'},
#  {'rank': 64,
#   'code': 'KR7047810007',
#   'name': '한국항공우주',
#   'symbolCode': 'A047810',
#   'tradePrice': 57600.0,
#   'change': 'FALL',
#   'changePrice': 600.0,
#   'changeRate': 0.0103092784,
#   'marketCap': 5614566163200,
#   'listedShareCount': 97475107,
#   'foreignRatio': '0.3221551221'},
#  {'rank': 65,
#   'code': 'KR7034220004',
#   'name': 'LG디스플레이',
#   'symbolCode': 'A034220',
#   'tradePrice': 11130.0,
#   'change': 'FALL',
#   'changePrice': 150.0,
#   'changeRate': 0.0132978723,
#   'marketCap': 5565000000000,
#   'listedShareCount': 500000000,
#   'foreignRatio': '0.213124086'},
#  {'rank': 66,
#   'code': 'KR7450080007',
#   'name': '에코프로머티',
#   'symbolCode': 'A450080',
#   'tradePrice': 80000.0,
#   'change': 'RISE',
#   'changePrice': 1000.0,
#   'changeRate': 0.0126582278,
#   'marketCap': 5525647840000,
#   'listedShareCount': 69070598,
#   'foreignRatio': '0.244689658'},
#  {'rank': 67,
#   'code': 'KR7028050003',
#   'name': '삼성E&A',
#   'symbolCode': 'A028050',
#   'tradePrice': 27550.0,
#   'change': 'RISE',
#   'changePrice': 950.0,
#   'changeRate': 0.0357142857,
#   'marketCap': 5399800000000,
#   'listedShareCount': 196000000,
#   'foreignRatio': '0.4717925'},
#  {'rank': 68,
#   'code': 'KR7051900009',
#   'name': 'LG생활건강',
#   'symbolCode': 'A051900',
#   'tradePrice': 339000.0,
#   'change': 'RISE',
#   'changePrice': 1000.0,
#   'changeRate': 0.0029585799,
#   'marketCap': 5294568783000,
#   'listedShareCount': 15618197,
#   'foreignRatio': '0.2757517401'},
#  {'rank': 69,
#   'code': 'KR7161390000',
#   'name': '한국타이어앤테크놀로지',
#   'symbolCode': 'A161390',
#   'tradePrice': 42550.0,
#   'change': 'FALL',
#   'changePrice': 700.0,
#   'changeRate': 0.0161849711,
#   'marketCap': 5270884185950,
#   'listedShareCount': 123875069,
#   'foreignRatio': '0.3981610537'},
#  {'rank': 70,
#   'code': 'KR7097950000',
#   'name': 'CJ제일제당',
#   'symbolCode': 'A097950',
#   'tradePrice': 349500.0,
#   'change': 'RISE',
#   'changePrice': 7000.0,
#   'changeRate': 0.0204379562,
#   'marketCap': 5261438007000,
#   'listedShareCount': 15054186,
#   'foreignRatio': '0.2597989689'},
#  {'rank': 71,
#   'code': 'KR7010120004',
#   'name': 'LS ELECTRIC',
#   'symbolCode': 'A010120',
#   'tradePrice': 174200.0,
#   'change': 'RISE',
#   'changePrice': 2300.0,
#   'changeRate': 0.013379872,
#   'marketCap': 5226000000000,
#   'listedShareCount': 30000000,
#   'foreignRatio': '0.1956'},
#  {'rank': 72,
#   'code': 'KR7088980008',
#   'name': '맥쿼리인프라',
#   'symbolCode': 'A088980',
#   'tradePrice': 11870.0,
#   'change': 'FALL',
#   'changePrice': 70.0,
#   'changeRate': 0.0058626466,
#   'marketCap': 5172724683850,
#   'listedShareCount': 435781355,
#   'foreignRatio': '0.1158929505'},
#  {'rank': 73,
#   'code': 'KR7443060009',
#   'name': 'HD현대마린솔루션',
#   'symbolCode': 'A443060',
#   'tradePrice': 114900.0,
#   'change': 'RISE',
#   'changePrice': 1100.0,
#   'changeRate': 0.0096660808,
#   'marketCap': 5107305000000,
#   'listedShareCount': 44450000,
#   'foreignRatio': '0.0162227447'},
#  {'rank': 74,
#   'code': 'KR7251270005',
#   'name': '넷마블',
#   'symbolCode': 'A251270',
#   'tradePrice': 57400.0,
#   'change': 'RISE',
#   'changePrice': 300.0,
#   'changeRate': 0.0052539405,
#   'marketCap': 4933731014800,
#   'listedShareCount': 85953502,
#   'foreignRatio': '0.2559396591'},
#  {'rank': 75,
#   'code': 'KR7006800007',
#   'name': '미래에셋증권',
#   'symbolCode': 'A006800',
#   'tradePrice': 8150.0,
#   'change': 'RISE',
#   'changePrice': 30.0,
#   'changeRate': 0.0036945813,
#   'marketCap': 4851828725200,
#   'listedShareCount': 595316408,
#   'foreignRatio': '0.1368583612'},
#  {'rank': 76,
#   'code': 'KR7029780004',
#   'name': '삼성카드',
#   'symbolCode': 'A029780',
#   'tradePrice': 41450.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 4802351031950,
#   'listedShareCount': 115858891,
#   'foreignRatio': '0.0692943539'},
#  {'rank': 77,
#   'code': 'KR7009830001',
#   'name': '한화솔루션',
#   'symbolCode': 'A009830',
#   'tradePrice': 27750.0,
#   'change': 'RISE',
#   'changePrice': 150.0,
#   'changeRate': 0.0054347826,
#   'marketCap': 4770017874000,
#   'listedShareCount': 171892536,
#   'foreignRatio': '0.2168165696'},
#  {'rank': 78,
#   'code': 'KR7011790003',
#   'name': 'SKC',
#   'symbolCode': 'A011790',
#   'tradePrice': 122100.0,
#   'change': 'RISE',
#   'changePrice': 600.0,
#   'changeRate': 0.0049382716,
#   'marketCap': 4623719185800,
#   'listedShareCount': 37868298,
#   'foreignRatio': '0.162544934'},
#  {'rank': 79,
#   'code': 'KR7005940002',
#   'name': 'NH투자증권',
#   'symbolCode': 'A005940',
#   'tradePrice': 13840.0,
#   'change': 'RISE',
#   'changePrice': 220.0,
#   'changeRate': 0.0161527166,
#   'marketCap': 4532493418160,
#   'listedShareCount': 327492299,
#   'foreignRatio': '0.1800169231'},
#  {'rank': 80,
#   'code': 'KR7010620003',
#   'name': 'HD현대미포',
#   'symbolCode': 'A010620',
#   'tradePrice': 113200.0,
#   'change': 'RISE',
#   'changePrice': 1200.0,
#   'changeRate': 0.0107142857,
#   'marketCap': 4521451266800,
#   'listedShareCount': 39942149,
#   'foreignRatio': '0.2050203158'},
#  {'rank': 81,
#   'code': 'KR7021240007',
#   'name': '코웨이',
#   'symbolCode': 'A021240',
#   'tradePrice': 61100.0,
#   'change': 'FALL',
#   'changePrice': 1100.0,
#   'changeRate': 0.0176848875,
#   'marketCap': 4509156720900,
#   'listedShareCount': 73799619,
#   'foreignRatio': '0.6029211614'},
#  {'rank': 82,
#   'code': 'KR7302440003',
#   'name': 'SK바이오사이언스',
#   'symbolCode': 'A302440',
#   'tradePrice': 58600.0,
#   'change': 'FALL',
#   'changePrice': 1600.0,
#   'changeRate': 0.0265780731,
#   'marketCap': 4502106150000,
#   'listedShareCount': 76827750,
#   'foreignRatio': '0.0692534924'},
#  {'rank': 83,
#   'code': 'KR7423160001',
#   'name': 'KODEX KOFR금리액티브(합성)',
#   'symbolCode': 'A423160',
#   'tradePrice': 107765.0,
#   'change': 'RISE',
#   'changePrice': 5.0,
#   'changeRate': 4.63994e-05,
#   'marketCap': 4483562825000,
#   'listedShareCount': 41605000,
#   'foreignRatio': '0.0'},
#  {'rank': 84,
#   'code': 'KR7454910001',
#   'name': '두산로보틱스',
#   'symbolCode': 'A454910',
#   'tradePrice': 67800.0,
#   'change': 'RISE',
#   'changePrice': 500.0,
#   'changeRate': 0.0074294205,
#   'marketCap': 4394794644000,
#   'listedShareCount': 64819980,
#   'foreignRatio': '0.0346229049'},
#  {'rank': 85,
#   'code': 'KR7180640005',
#   'name': '한진칼',
#   'symbolCode': 'A180640',
#   'tradePrice': 65700.0,
#   'change': 'FALL',
#   'changePrice': 500.0,
#   'changeRate': 0.0075528701,
#   'marketCap': 4386281730300,
#   'listedShareCount': 66762279,
#   'foreignRatio': '0.2193579401'},
#  {'rank': 86,
#   'code': 'KR7307950006',
#   'name': '현대오토에버',
#   'symbolCode': 'A307950',
#   'tradePrice': 159500.0,
#   'change': 'RISE',
#   'changePrice': 600.0,
#   'changeRate': 0.0037759597,
#   'marketCap': 4374125129000,
#   'listedShareCount': 27423982,
#   'foreignRatio': '0.0172013313'},
#  {'rank': 87,
#   'code': 'KR7036460004',
#   'name': '한국가스공사',
#   'symbolCode': 'A036460',
#   'tradePrice': 47000.0,
#   'change': 'RISE',
#   'changePrice': 100.0,
#   'changeRate': 0.0021321962,
#   'marketCap': 4338711000000,
#   'listedShareCount': 92313000,
#   'foreignRatio': '0.068866281'},
#  {'rank': 88,
#   'code': 'KR7079550000',
#   'name': 'LIG넥스원',
#   'symbolCode': 'A079550',
#   'tradePrice': 194700.0,
#   'change': 'FALL',
#   'changePrice': 5800.0,
#   'changeRate': 0.0289276808,
#   'marketCap': 4283400000000,
#   'listedShareCount': 22000000,
#   'foreignRatio': '0.2060654545'},
#  {'rank': 89,
#   'code': 'KR7360750004',
#   'name': 'TIGER 미국S&P500',
#   'symbolCode': 'A360750',
#   'tradePrice': 18595.0,
#   'change': 'RISE',
#   'changePrice': 170.0,
#   'changeRate': 0.0092265943,
#   'marketCap': 4252676500000,
#   'listedShareCount': 228700000,
#   'foreignRatio': '0.0012079274'},
#  {'rank': 90,
#   'code': 'KR7032640005',
#   'name': 'LG유플러스',
#   'symbolCode': 'A032640',
#   'tradePrice': 9700.0,
#   'change': 'RISE',
#   'changePrice': 10.0,
#   'changeRate': 0.0010319917,
#   'marketCap': 4235130201700,
#   'listedShareCount': 436611361,
#   'foreignRatio': '0.3501387221'},
#  {'rank': 91,
#   'code': 'KR7016360000',
#   'name': '삼성증권',
#   'symbolCode': 'A016360',
#   'tradePrice': 47400.0,
#   'change': 'RISE',
#   'changePrice': 1800.0,
#   'changeRate': 0.0394736842,
#   'marketCap': 4232820000000,
#   'listedShareCount': 89300000,
#   'foreignRatio': '0.3012435386'},
#  {'rank': 92,
#   'code': 'KR7036570000',
#   'name': '엔씨소프트',
#   'symbolCode': 'A036570',
#   'tradePrice': 191300.0,
#   'change': 'FALL',
#   'changePrice': 400.0,
#   'changeRate': 0.0020865936,
#   'marketCap': 4199804408600,
#   'listedShareCount': 21954022,
#   'foreignRatio': '0.3636776897'},
#  {'rank': 93,
#   'code': 'KR7078930005',
#   'name': 'GS',
#   'symbolCode': 'A078930',
#   'tradePrice': 44600.0,
#   'change': 'FALL',
#   'changePrice': 400.0,
#   'changeRate': 0.0088888889,
#   'marketCap': 4144025858800,
#   'listedShareCount': 92915378,
#   'foreignRatio': '0.2312094129'},
#  {'rank': 94,
#   'code': 'KR7071050009',
#   'name': '한국금융지주',
#   'symbolCode': 'A071050',
#   'tradePrice': 73800.0,
#   'change': 'RISE',
#   'changePrice': 300.0,
#   'changeRate': 0.0040816327,
#   'marketCap': 4112578209600,
#   'listedShareCount': 55725992,
#   'foreignRatio': '0.4128491782'},
#  {'rank': 95,
#   'code': 'KR7241560002',
#   'name': '두산밥캣',
#   'symbolCode': 'A241560',
#   'tradePrice': 40500.0,
#   'change': 'RISE',
#   'changePrice': 700.0,
#   'changeRate': 0.0175879397,
#   'marketCap': 4060091223000,
#   'listedShareCount': 100249166,
#   'foreignRatio': '0.3671006001'},
#  {'rank': 96,
#   'code': 'KR7003230000',
#   'name': '삼양식품',
#   'symbolCode': 'A003230',
#   'tradePrice': 533000.0,
#   'change': 'RISE',
#   'changePrice': 12000.0,
#   'changeRate': 0.0230326296,
#   'marketCap': 4015096995000,
#   'listedShareCount': 7533015,
#   'foreignRatio': '0.1419494054'},
#  {'rank': 97,
#   'code': 'KR7005381009',
#   'name': '현대차우',
#   'symbolCode': 'A005385',
#   'tradePrice': 167800.0,
#   'change': 'RISE',
#   'changePrice': 900.0,
#   'changeRate': 0.0053924506,
#   'marketCap': 4005719586400,
#   'listedShareCount': 23871988,
#   'foreignRatio': '0.6644980301'},
#  {'rank': 98,
#   'code': 'KR7022100002',
#   'name': '포스코DX',
#   'symbolCode': 'A022100',
#   'tradePrice': 26300.0,
#   'change': 'RISE',
#   'changePrice': 50.0,
#   'changeRate': 0.0019047619,
#   'marketCap': 3998513372700,
#   'listedShareCount': 152034729,
#   'foreignRatio': '0.0692086609'},
#  {'rank': 99,
#   'code': 'KR7006260004',
#   'name': 'LS',
#   'symbolCode': 'A006260',
#   'tradePrice': 118100.0,
#   'change': 'RISE',
#   'changePrice': 800.0,
#   'changeRate': 0.0068201194,
#   'marketCap': 3802820000000,
#   'listedShareCount': 32200000,
#   'foreignRatio': '0.1643277019'},
#  {'rank': 100,
#   'code': 'KR7462870007',
#   'name': '시프트업',
#   'symbolCode': 'A462870',
#   'tradePrice': 65500.0,
#   'change': 'RISE',
#   'changePrice': 3000.0,
#   'changeRate': 0.048,
#   'marketCap': 3800684660000,
#   'listedShareCount': 58025720,
#   'foreignRatio': '0.0124626631'},
#  {'rank': 101,
#   'code': 'KR7128940004',
#   'name': '한미약품',
#   'symbolCode': 'A128940',
#   'tradePrice': 289500.0,
#   'change': 'FALL',
#   'changePrice': 6000.0,
#   'changeRate': 0.0203045685,
#   'marketCap': 3708781894500,
#   'listedShareCount': 12810991,
#   'foreignRatio': '0.191325792'},
#  {'rank': 102,
#   'code': 'KR7271560005',
#   'name': '오리온',
#   'symbolCode': 'A271560',
#   'tradePrice': 93500.0,
#   'change': 'RISE',
#   'changePrice': 1500.0,
#   'changeRate': 0.0163043478,
#   'marketCap': 3696628342000,
#   'listedShareCount': 39536132,
#   'foreignRatio': '0.2767655167'},
#  {'rank': 103,
#   'code': 'KR7449170000',
#   'name': 'TIGER KOFR금리액티브(합성)',
#   'symbolCode': 'A449170',
#   'tradePrice': 106290.0,
#   'change': 'RISE',
#   'changePrice': 10.0,
#   'changeRate': 9.40911e-05,
#   'marketCap': 3687731550000,
#   'listedShareCount': 34695000,
#   'foreignRatio': '3.6893E-6'},
#  {'rank': 104,
#   'code': 'KR7001040005',
#   'name': 'CJ',
#   'symbolCode': 'A001040',
#   'tradePrice': 124900.0,
#   'change': 'FALL',
#   'changePrice': 2600.0,
#   'changeRate': 0.0203921569,
#   'marketCap': 3644207050200,
#   'listedShareCount': 29176998,
#   'foreignRatio': '0.1486793809'},
#  {'rank': 105,
#   'code': 'KR7133690008',
#   'name': 'TIGER 미국나스닥100',
#   'symbolCode': 'A133690',
#   'tradePrice': 117345.0,
#   'change': 'RISE',
#   'changePrice': 1600.0,
#   'changeRate': 0.0138234913,
#   'marketCap': 3621266700000,
#   'listedShareCount': 30860000,
#   'foreignRatio': '1.888853E-4'},
#  {'rank': 106,
#   'code': 'KR7272210006',
#   'name': '한화시스템',
#   'symbolCode': 'A272210',
#   'tradePrice': 19000.0,
#   'change': 'FALL',
#   'changePrice': 140.0,
#   'changeRate': 0.0073145246,
#   'marketCap': 3589468391000,
#   'listedShareCount': 188919389,
#   'foreignRatio': '0.0589655835'},
#  {'rank': 107,
#   'code': 'KR7011780004',
#   'name': '금호석유',
#   'symbolCode': 'A011780',
#   'tradePrice': 129100.0,
#   'change': 'FALL',
#   'changePrice': 3300.0,
#   'changeRate': 0.0249244713,
#   'marketCap': 3572542858900,
#   'listedShareCount': 27672679,
#   'foreignRatio': '0.2400784904'},
#  {'rank': 108,
#   'code': 'KR7000720003',
#   'name': '현대건설',
#   'symbolCode': 'A000720',
#   'tradePrice': 31500.0,
#   'change': 'RISE',
#   'changePrice': 650.0,
#   'changeRate': 0.0210696921,
#   'marketCap': 3507706597500,
#   'listedShareCount': 111355765,
#   'foreignRatio': '0.2371191559'},
#  {'rank': 109,
#   'code': 'KR7039490008',
#   'name': '키움증권',
#   'symbolCode': 'A039490',
#   'tradePrice': 136600.0,
#   'change': 'RISE',
#   'changePrice': 1600.0,
#   'changeRate': 0.0118518519,
#   'marketCap': 3486948039600,
#   'listedShareCount': 25526706,
#   'foreignRatio': '0.2670040153'},
#  {'rank': 110,
#   'code': 'KR7005070008',
#   'name': '코스모신소재',
#   'symbolCode': 'A005070',
#   'tradePrice': 107200.0,
#   'change': 'FALL',
#   'changePrice': 1600.0,
#   'changeRate': 0.0147058824,
#   'marketCap': 3485153043200,
#   'listedShareCount': 32510756,
#   'foreignRatio': '0.1390044267'},
#  {'rank': 111,
#   'code': 'KR7011170008',
#   'name': '롯데케미칼',
#   'symbolCode': 'A011170',
#   'tradePrice': 79800.0,
#   'change': 'FALL',
#   'changePrice': 2600.0,
#   'changeRate': 0.0315533981,
#   'marketCap': 3413478436200,
#   'listedShareCount': 42775419,
#   'foreignRatio': '0.2453994898'},
#  {'rank': 112,
#   'code': 'KR7004020004',
#   'name': '현대제철',
#   'symbolCode': 'A004020',
#   'tradePrice': 25400.0,
#   'change': 'FALL',
#   'changePrice': 450.0,
#   'changeRate': 0.0174081238,
#   'marketCap': 3389522939000,
#   'listedShareCount': 133445785,
#   'foreignRatio': '0.2197259434'},
#  {'rank': 113,
#   'code': 'KR7001570001',
#   'name': '금양',
#   'symbolCode': 'A001570',
#   'tradePrice': 57300.0,
#   'change': 'RISE',
#   'changePrice': 100.0,
#   'changeRate': 0.0017482517,
#   'marketCap': 3326267120100,
#   'listedShareCount': 58050037,
#   'foreignRatio': '0.1188792007'},
#  {'rank': 114,
#   'code': 'KR7066970005',
#   'name': '엘앤에프',
#   'symbolCode': 'A066970',
#   'tradePrice': 89900.0,
#   'change': 'RISE',
#   'changePrice': 600.0,
#   'changeRate': 0.006718925,
#   'marketCap': 3262896946200,
#   'listedShareCount': 36294738,
#   'foreignRatio': '0.2208110994'},
#  {'rank': 115,
#   'code': 'KR7377300009',
#   'name': '카카오페이',
#   'symbolCode': 'A377300',
#   'tradePrice': 23850.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 3210263400150,
#   'listedShareCount': 134602239,
#   'foreignRatio': '0.3799590436'},
#  {'rank': 116,
#   'code': 'KR7035250000',
#   'name': '강원랜드',
#   'symbolCode': 'A035250',
#   'tradePrice': 14850.0,
#   'change': 'RISE',
#   'changePrice': 180.0,
#   'changeRate': 0.0122699387,
#   'marketCap': 3177016425000,
#   'listedShareCount': 213940500,
#   'foreignRatio': '0.1168675356'},
#  {'rank': 117,
#   'code': 'KR7001450006',
#   'name': '현대해상',
#   'symbolCode': 'A001450',
#   'tradePrice': 35400.0,
#   'change': 'RISE',
#   'changePrice': 500.0,
#   'changeRate': 0.0143266476,
#   'marketCap': 3164760000000,
#   'listedShareCount': 89400000,
#   'foreignRatio': '0.3952512528'},
#  {'rank': 118,
#   'code': 'KR7138930003',
#   'name': 'BNK금융지주',
#   'symbolCode': 'A138930',
#   'tradePrice': 9760.0,
#   'change': 'RISE',
#   'changePrice': 10.0,
#   'changeRate': 0.001025641,
#   'marketCap': 3143583154880,
#   'listedShareCount': 322088438,
#   'foreignRatio': '0.3907863281'},
#  {'rank': 119,
#   'code': 'KR7003410008',
#   'name': '쌍용C&E',
#   'symbolCode': 'A003410',
#   'tradePrice': None,
#   'change': None,
#   'changePrice': None,
#   'changeRate': None,
#   'marketCap': None,
#   'listedShareCount': 443786866,
#   'foreignRatio': '0.0126121083'},
#  {'rank': 120,
#   'code': 'KR7298040007',
#   'name': '효성중공업',
#   'symbolCode': 'A298040',
#   'tradePrice': 327500.0,
#   'change': 'RISE',
#   'changePrice': 17500.0,
#   'changeRate': 0.0564516129,
#   'marketCap': 3053789470000,
#   'listedShareCount': 9324548,
#   'foreignRatio': '0.1203106038'},
#  {'rank': 121,
#   'code': 'KR7175330000',
#   'name': 'JB금융지주',
#   'symbolCode': 'A175330',
#   'tradePrice': 15050.0,
#   'change': 'RISE',
#   'changePrice': 300.0,
#   'changeRate': 0.0203389831,
#   'marketCap': 2936002129900,
#   'listedShareCount': 195083198,
#   'foreignRatio': '0.3774280346'},
#  {'rank': 122,
#   'code': 'KR7007660004',
#   'name': '이수페타시스',
#   'symbolCode': 'A007660',
#   'tradePrice': 45100.0,
#   'change': 'RISE',
#   'changePrice': 1700.0,
#   'changeRate': 0.0391705069,
#   'marketCap': 2852413496900,
#   'listedShareCount': 63246419,
#   'foreignRatio': '0.1140916769'},
#  {'rank': 123,
#   'code': 'KR7273130005',
#   'name': 'KODEX 종합채권(AA-이상)액티브',
#   'symbolCode': 'A273130',
#   'tradePrice': 113945.0,
#   'change': 'FALL',
#   'changePrice': 55.0,
#   'changeRate': 0.0004824561,
#   'marketCap': 2838256005000,
#   'listedShareCount': 24909000,
#   'foreignRatio': '1.113252E-4'},
#  {'rank': 124,
#   'code': 'KR7381180009',
#   'name': 'TIGER 미국필라델피아반도체나스닥',
#   'symbolCode': 'A381180',
#   'tradePrice': 18560.0,
#   'change': 'RISE',
#   'changePrice': 335.0,
#   'changeRate': 0.0183813443,
#   'marketCap': 2775648000000,
#   'listedShareCount': 149550000,
#   'foreignRatio': '0.0'},
#  {'rank': 125,
#   'code': 'KR7112610001',
#   'name': '씨에스윈드',
#   'symbolCode': 'A112610',
#   'tradePrice': 65300.0,
#   'change': 'RISE',
#   'changePrice': 2000.0,
#   'changeRate': 0.0315955766,
#   'marketCap': 2753792615900,
#   'listedShareCount': 42171403,
#   'foreignRatio': '0.1437835967'},
#  {'rank': 126,
#   'code': 'KR7002380004',
#   'name': 'KCC',
#   'symbolCode': 'A002380',
#   'tradePrice': 308500.0,
#   'change': 'RISE',
#   'changePrice': 5000.0,
#   'changeRate': 0.0164744646,
#   'marketCap': 2741476303500,
#   'listedShareCount': 8886471,
#   'foreignRatio': '0.1471216189'},
#  {'rank': 127,
#   'code': 'KR7381170000',
#   'name': 'TIGER 미국테크TOP10 INDXX',
#   'symbolCode': 'A381170',
#   'tradePrice': 20325.0,
#   'change': 'RISE',
#   'changePrice': 305.0,
#   'changeRate': 0.0152347652,
#   'marketCap': 2735745000000,
#   'listedShareCount': 134600000,
#   'foreignRatio': '7.884324E-4'},
#  {'rank': 128,
#   'code': 'KR7052690005',
#   'name': '한전기술',
#   'symbolCode': 'A052690',
#   'tradePrice': 70500.0,
#   'change': 'RISE',
#   'changePrice': 1100.0,
#   'changeRate': 0.0158501441,
#   'marketCap': 2694510000000,
#   'listedShareCount': 38220000,
#   'foreignRatio': '0.0790163789'},
#  {'rank': 129,
#   'code': 'KR7088350004',
#   'name': '한화생명',
#   'symbolCode': 'A088350',
#   'tradePrice': 3025.0,
#   'change': 'RISE',
#   'changePrice': 30.0,
#   'changeRate': 0.0100166945,
#   'marketCap': 2627303250000,
#   'listedShareCount': 868530000,
#   'foreignRatio': '0.1065844784'},
#  {'rank': 130,
#   'code': 'KR7000150003',
#   'name': '두산',
#   'symbolCode': 'A000150',
#   'tradePrice': 150800.0,
#   'change': 'RISE',
#   'changePrice': 1500.0,
#   'changeRate': 0.0100468855,
#   'marketCap': 2491794318000,
#   'listedShareCount': 16523835,
#   'foreignRatio': '0.207461585'},
#  {'rank': 131,
#   'code': 'KR7004990008',
#   'name': '롯데지주',
#   'symbolCode': 'A004990',
#   'tradePrice': 23700.0,
#   'change': 'FALL',
#   'changePrice': 100.0,
#   'changeRate': 0.0042016807,
#   'marketCap': 2486348916900,
#   'listedShareCount': 104909237,
#   'foreignRatio': '0.0814076267'},
#  {'rank': 132,
#   'code': 'KR7004370003',
#   'name': '농심',
#   'symbolCode': 'A004370',
#   'tradePrice': 408000.0,
#   'change': 'RISE',
#   'changePrice': 5000.0,
#   'changeRate': 0.0124069479,
#   'marketCap': 2481717936000,
#   'listedShareCount': 6082642,
#   'foreignRatio': '0.1910092687'},
#  {'rank': 133,
#   'code': 'KR7081660003',
#   'name': '휠라홀딩스',
#   'symbolCode': 'A081660',
#   'tradePrice': 40900.0,
#   'change': 'FALL',
#   'changePrice': 1400.0,
#   'changeRate': 0.0330969267,
#   'marketCap': 2457919815100,
#   'listedShareCount': 60095839,
#   'foreignRatio': '0.4684618015'},
#  {'rank': 134,
#   'code': 'KR7001440007',
#   'name': '대한전선',
#   'symbolCode': 'A001440',
#   'tradePrice': 13110.0,
#   'change': 'RISE',
#   'changePrice': 200.0,
#   'changeRate': 0.0154918668,
#   'marketCap': 2444324103000,
#   'listedShareCount': 186447300,
#   'foreignRatio': '0.0778344229'},
#  {'rank': 135,
#   'code': 'KR7122630007',
#   'name': 'KODEX 레버리지',
#   'symbolCode': 'A122630',
#   'tradePrice': 18935.0,
#   'change': 'RISE',
#   'changePrice': 415.0,
#   'changeRate': 0.0224082073,
#   'marketCap': 2314803750000,
#   'listedShareCount': 122250000,
#   'foreignRatio': '0.0083972434'},
#  {'rank': 136,
#   'code': 'KR7278530001',
#   'name': 'KODEX 200TR',
#   'symbolCode': 'A278530',
#   'tradePrice': 12905.0,
#   'change': 'RISE',
#   'changePrice': 140.0,
#   'changeRate': 0.0109674892,
#   'marketCap': 2278377750000,
#   'listedShareCount': 176550000,
#   'foreignRatio': '2.4469E-5'},
#  {'rank': 137,
#   'code': 'KR7361610009',
#   'name': 'SK아이이테크놀로지',
#   'symbolCode': 'A361610',
#   'tradePrice': 31850.0,
#   'change': 'RISE',
#   'changePrice': 200.0,
#   'changeRate': 0.0063191153,
#   'marketCap': 2270828305200,
#   'listedShareCount': 71297592,
#   'foreignRatio': '0.1048863614'},
#  {'rank': 138,
#   'code': 'KR7000880005',
#   'name': '한화',
#   'symbolCode': 'A000880',
#   'tradePrice': 30000.0,
#   'change': 'FALL',
#   'changePrice': 150.0,
#   'changeRate': 0.0049751244,
#   'marketCap': 2248762050000,
#   'listedShareCount': 74958735,
#   'foreignRatio': '0.1250125152'},
#  {'rank': 139,
#   'code': 'KR7465680007',
#   'name': 'KODEX 24-12 은행채(AA+이상)액티브',
#   'symbolCode': 'A465680',
#   'tradePrice': 10385.0,
#   'change': 'RISE',
#   'changePrice': 5.0,
#   'changeRate': 0.0004816956,
#   'marketCap': 2182511600000,
#   'listedShareCount': 210160000,
#   'foreignRatio': '0.0'},
#  {'rank': 140,
#   'code': 'KR7008930000',
#   'name': '한미사이언스',
#   'symbolCode': 'A008930',
#   'tradePrice': 31900.0,
#   'change': 'FALL',
#   'changePrice': 500.0,
#   'changeRate': 0.0154320988,
#   'marketCap': 2181690445000,
#   'listedShareCount': 68391550,
#   'foreignRatio': '0.0240950819'},
#  {'rank': 141,
#   'code': 'KR7012750006',
#   'name': '에스원',
#   'symbolCode': 'A012750',
#   'tradePrice': 57200.0,
#   'change': 'FALL',
#   'changePrice': 100.0,
#   'changeRate': 0.0017452007,
#   'marketCap': 2173552981600,
#   'listedShareCount': 37999178,
#   'foreignRatio': '0.5583846577'},
#  {'rank': 142,
#   'code': 'KR7007070006',
#   'name': 'GS리테일',
#   'symbolCode': 'A007070',
#   'tradePrice': 20700.0,
#   'change': 'FALL',
#   'changePrice': 600.0,
#   'changeRate': 0.0281690141,
#   'marketCap': 2167660985400,
#   'listedShareCount': 104717922,
#   'foreignRatio': '0.0740072363'},
#  {'rank': 143,
#   'code': 'KR7018880005',
#   'name': '한온시스템',
#   'symbolCode': 'A018880',
#   'tradePrice': 4055.0,
#   'change': 'FALL',
#   'changePrice': 5.0,
#   'changeRate': 0.0012315271,
#   'marketCap': 2164559000000,
#   'listedShareCount': 533800000,
#   'foreignRatio': '0.100135474'},
#  {'rank': 144,
#   'code': 'KR7000120006',
#   'name': 'CJ대한통운',
#   'symbolCode': 'A000120',
#   'tradePrice': 94100.0,
#   'change': 'FALL',
#   'changePrice': 500.0,
#   'changeRate': 0.0052854123,
#   'marketCap': 2146641570400,
#   'listedShareCount': 22812344,
#   'foreignRatio': '0.1276124891'},
#  {'rank': 145,
#   'code': 'KR7383220001',
#   'name': 'F&F',
#   'symbolCode': 'A383220',
#   'tradePrice': 54200.0,
#   'change': 'RISE',
#   'changePrice': 500.0,
#   'changeRate': 0.009310987,
#   'marketCap': 2076243465000,
#   'listedShareCount': 38307075,
#   'foreignRatio': '0.1255911343'},
#  {'rank': 146,
#   'code': 'KR7002790004',
#   'name': '아모레G',
#   'symbolCode': 'A002790',
#   'tradePrice': 24900.0,
#   'change': 'FALL',
#   'changePrice': 150.0,
#   'changeRate': 0.005988024,
#   'marketCap': 2053208682000,
#   'listedShareCount': 82458180,
#   'foreignRatio': '0.1086456674'},
#  {'rank': 147,
#   'code': 'KR7278470000',
#   'name': '에이피알',
#   'symbolCode': 'A278470',
#   'tradePrice': 268500.0,
#   'change': 'RISE',
#   'changePrice': 5000.0,
#   'changeRate': 0.0189753321,
#   'marketCap': 2046017793000,
#   'listedShareCount': 7620178,
#   'foreignRatio': '0.1099138367'},
#  {'rank': 148,
#   'code': 'KR7030000004',
#   'name': '제일기획',
#   'symbolCode': 'A030000',
#   'tradePrice': 17630.0,
#   'change': 'RISE',
#   'changePrice': 300.0,
#   'changeRate': 0.0173110214,
#   'marketCap': 2028176796750,
#   'listedShareCount': 115041225,
#   'foreignRatio': '0.2359233657'},
#  {'rank': 149,
#   'code': 'KR7028670008',
#   'name': '팬오션',
#   'symbolCode': 'A028670',
#   'tradePrice': 3720.0,
#   'change': 'FALL',
#   'changePrice': 5.0,
#   'changeRate': 0.0013422819,
#   'marketCap': 1988598584640,
#   'listedShareCount': 534569512,
#   'foreignRatio': '0.1207966982'},
#  {'rank': 150,
#   'code': 'KR7102110004',
#   'name': 'TIGER 200',
#   'symbolCode': 'A102110',
#   'tradePrice': 37055.0,
#   'change': 'RISE',
#   'changePrice': 415.0,
#   'changeRate': 0.0113264192,
#   'marketCap': 1978737000000,
#   'listedShareCount': 53400000,
#   'foreignRatio': '0.1077851311'},
#  {'rank': 151,
#   'code': 'KR7051600005',
#   'name': '한전KPS',
#   'symbolCode': 'A051600',
#   'tradePrice': 43200.0,
#   'change': 'RISE',
#   'changePrice': 850.0,
#   'changeRate': 0.0200708383,
#   'marketCap': 1944000000000,
#   'listedShareCount': 45000000,
#   'foreignRatio': '0.1219497333'},
#  {'rank': 152,
#   'code': 'KR7000990002',
#   'name': 'DB하이텍',
#   'symbolCode': 'A000990',
#   'tradePrice': 43250.0,
#   'change': 'RISE',
#   'changePrice': 600.0,
#   'changeRate': 0.0140679953,
#   'marketCap': 1920238931000,
#   'listedShareCount': 44398588,
#   'foreignRatio': '0.2235315682'},
#  {'rank': 153,
#   'code': 'KR7282330000',
#   'name': 'BGF리테일',
#   'symbolCode': 'A282330',
#   'tradePrice': 108800.0,
#   'change': 'FALL',
#   'changePrice': 1900.0,
#   'changeRate': 0.017163505,
#   'marketCap': 1880488972800,
#   'listedShareCount': 17283906,
#   'foreignRatio': '0.3084468291'},
#  {'rank': 154,
#   'code': 'KR7009420001',
#   'name': '한올바이오파마',
#   'symbolCode': 'A009420',
#   'tradePrice': 35800.0,
#   'change': 'FALL',
#   'changePrice': 400.0,
#   'changeRate': 0.0110497238,
#   'marketCap': 1870214840400,
#   'listedShareCount': 52240638,
#   'foreignRatio': '0.0696026722'},
#  {'rank': 155,
#   'code': 'KR7008770000',
#   'name': '호텔신라',
#   'symbolCode': 'A008770',
#   'tradePrice': 47550.0,
#   'change': 'RISE',
#   'changePrice': 200.0,
#   'changeRate': 0.0042238648,
#   'marketCap': 1866248153550,
#   'listedShareCount': 39248121,
#   'foreignRatio': '0.1432845664'},
#  {'rank': 156,
#   'code': 'KR7012510004',
#   'name': '더존비즈온',
#   'symbolCode': 'A012510',
#   'tradePrice': 61200.0,
#   'change': 'RISE',
#   'changePrice': 600.0,
#   'changeRate': 0.0099009901,
#   'marketCap': 1859426380800,
#   'listedShareCount': 30382784,
#   'foreignRatio': '0.1044870016'},
#  {'rank': 157,
#   'code': 'KR7026960005',
#   'name': '동서',
#   'symbolCode': 'A026960',
#   'tradePrice': 18590.0,
#   'change': 'FALL',
#   'changePrice': 160.0,
#   'changeRate': 0.0085333333,
#   'marketCap': 1853423000000,
#   'listedShareCount': 99700000,
#   'foreignRatio': '0.0409932096'},
#  {'rank': 158,
#   'code': 'KR7455890004',
#   'name': 'RISE 머니마켓액티브',
#   'symbolCode': 'A455890',
#   'tradePrice': 52775.0,
#   'change': 'RISE',
#   'changePrice': 5.0,
#   'changeRate': 9.47508e-05,
#   'marketCap': 1849024900000,
#   'listedShareCount': 35036000,
#   'foreignRatio': '3.93595E-5'},
#  {'rank': 159,
#   'code': 'KR7111770004',
#   'name': '영원무역',
#   'symbolCode': 'A111770',
#   'tradePrice': 40500.0,
#   'change': 'FALL',
#   'changePrice': 450.0,
#   'changeRate': 0.010989011,
#   'marketCap': 1794614454000,
#   'listedShareCount': 44311468,
#   'foreignRatio': '0.2869637946'},
#  {'rank': 160,
#   'code': 'KR7006360002',
#   'name': 'GS건설',
#   'symbolCode': 'A006360',
#   'tradePrice': 20950.0,
#   'change': 'RISE',
#   'changePrice': 1010.0,
#   'changeRate': 0.0506519559,
#   'marketCap': 1792932215500,
#   'listedShareCount': 85581490,
#   'foreignRatio': '0.217238307'},
#  {'rank': 161,
#   'code': 'KR7006280002',
#   'name': '녹십자',
#   'symbolCode': 'A006280',
#   'tradePrice': 152400.0,
#   'change': 'FALL',
#   'changePrice': 1600.0,
#   'changeRate': 0.0103896104,
#   'marketCap': 1781028391200,
#   'listedShareCount': 11686538,
#   'foreignRatio': '0.1999652934'},
#  {'rank': 162,
#   'code': 'KR7137310009',
#   'name': '에스디바이오센서',
#   'symbolCode': 'A137310',
#   'tradePrice': 14180.0,
#   'change': 'FALL',
#   'changePrice': 670.0,
#   'changeRate': 0.0451178451,
#   'marketCap': 1765088865540,
#   'listedShareCount': 124477353,
#   'foreignRatio': '0.0674985915'},
#  {'rank': 163,
#   'code': 'KR7481050003',
#   'name': 'KODEX 1년은행양도성예금증서+액티브(합성)',
#   'symbolCode': 'A481050',
#   'tradePrice': 1012440.0,
#   'change': 'RISE',
#   'changePrice': 85.0,
#   'changeRate': 8.39626e-05,
#   'marketCap': 1723274124000,
#   'listedShareCount': 1702100,
#   'foreignRatio': '0.0'},
#  {'rank': 164,
#   'code': 'KR7139480008',
#   'name': '이마트',
#   'symbolCode': 'A139480',
#   'tradePrice': 61600.0,
#   'change': 'FALL',
#   'changePrice': 400.0,
#   'changeRate': 0.0064516129,
#   'marketCap': 1717150450400,
#   'listedShareCount': 27875819,
#   'foreignRatio': '0.1865647786'},
#  {'rank': 165,
#   'code': 'KR7047040001',
#   'name': '대우건설',
#   'symbolCode': 'A047040',
#   'tradePrice': 4115.0,
#   'change': 'RISE',
#   'changePrice': 160.0,
#   'changeRate': 0.0404551201,
#   'marketCap': 1710287155370,
#   'listedShareCount': 415622638,
#   'foreignRatio': '0.1118286921'},
#  {'rank': 166,
#   'code': 'KR7017800004',
#   'name': '현대엘리베이',
#   'symbolCode': 'A017800',
#   'tradePrice': 43500.0,
#   'change': 'RISE',
#   'changePrice': 150.0,
#   'changeRate': 0.0034602076,
#   'marketCap': 1700518747500,
#   'listedShareCount': 39092385,
#   'foreignRatio': '0.2680492121'},
#  {'rank': 167,
#   'code': 'KR7014680003',
#   'name': '한솔케미칼',
#   'symbolCode': 'A014680',
#   'tradePrice': 149700.0,
#   'change': 'RISE',
#   'changePrice': 2800.0,
#   'changeRate': 0.0190605854,
#   'marketCap': 1696878691500,
#   'listedShareCount': 11335195,
#   'foreignRatio': '0.4037586473'},
#  {'rank': 168,
#   'code': 'KR7023530009',
#   'name': '롯데쇼핑',
#   'symbolCode': 'A023530',
#   'tradePrice': 59700.0,
#   'change': 'FALL',
#   'changePrice': 700.0,
#   'changeRate': 0.011589404,
#   'marketCap': 1688838673500,
#   'listedShareCount': 28288755,
#   'foreignRatio': '0.0810044486'},
#  {'rank': 169,
#   'code': 'KR7007310006',
#   'name': '오뚜기',
#   'symbolCode': 'A007310',
#   'tradePrice': 418500.0,
#   'change': 'FALL',
#   'changePrice': 2500.0,
#   'changeRate': 0.0059382423,
#   'marketCap': 1677276855000,
#   'listedShareCount': 4007830,
#   'foreignRatio': '0.1191662321'},
#  {'rank': 170,
#   'code': 'KR7204320006',
#   'name': 'HL만도',
#   'symbolCode': 'A204320',
#   'tradePrice': 35600.0,
# ...
#   'changePrice': 105.0,
#   'changeRate': 0.0081237911,
#   'marketCap': 97464400000,
#   'listedShareCount': 7480000,
#   'foreignRatio': '4.411765E-4'},
#  {'rank': 945,
#   'code': 'KR7032560005',
#   'name': '황금에스티',
#   'symbolCode': 'A032560',
#   'tradePrice': 5720.0,
#   'change': 'RISE',
#   'changePrice': 10.0,
#   'changeRate': 0.0017513135,
#   'marketCap': 97240000000,
#   'listedShareCount': 17000000,
#   'foreignRatio': '0.0303465294'},
#  {'rank': 946,
#   'code': 'KR7006090005',
#   'name': '사조오양',
#   'symbolCode': 'A006090',
#   'tradePrice': 10310.0,
#   'change': 'RISE',
#   'changePrice': 50.0,
#   'changeRate': 0.0048732943,
#   'marketCap': 97148439090,
#   'listedShareCount': 9422739,
#   'foreignRatio': '0.0571715931'},
#  {'rank': 947,
#   'code': 'KR7227840006',
#   'name': '현대코퍼레이션홀딩스',
#   'symbolCode': 'A227840',
#   'tradePrice': 10660.0,
#   'change': 'RISE',
#   'changePrice': 20.0,
#   'changeRate': 0.0018796992,
#   'marketCap': 97014911760,
#   'listedShareCount': 9100836,
#   'foreignRatio': '0.0249172713'},
#  {'rank': 948,
#   'code': 'KRG502400291',
#   'name': '신한 레버리지 은 선물 ETN(H)',
#   'symbolCode': 'Q500029',
#   'tradePrice': 9700.0,
#   'change': 'RISE',
#   'changePrice': 140.0,
#   'changeRate': 0.0146443515,
#   'marketCap': 97000000000,
#   'listedShareCount': 10000000,
#   'foreignRatio': '0.0'},
#  {'rank': 949,
#   'code': 'KR7466930005',
#   'name': 'SOL 자동차TOP3플러스',
#   'symbolCode': 'A466930',
#   'tradePrice': 11210.0,
#   'change': 'RISE',
#   'changePrice': 55.0,
#   'changeRate': 0.0049305244,
#   'marketCap': 96966500000,
#   'listedShareCount': 8650000,
#   'foreignRatio': '5.71098E-5'},
#  {'rank': 950,
#   'code': 'KR7047400007',
#   'name': '유니온머티리얼',
#   'symbolCode': 'A047400',
#   'tradePrice': 2305.0,
#   'change': 'RISE',
#   'changePrice': 30.0,
#   'changeRate': 0.0131868132,
#   'marketCap': 96810000000,
#   'listedShareCount': 42000000,
#   'foreignRatio': '0.0029780952'},
#  {'rank': 951,
#   'code': 'KR7400970000',
#   'name': 'TIGER Fn메타버스',
#   'symbolCode': 'A400970',
#   'tradePrice': 6530.0,
#   'change': 'FALL',
#   'changePrice': 10.0,
#   'changeRate': 0.001529052,
#   'marketCap': 96644000000,
#   'listedShareCount': 14800000,
#   'foreignRatio': '0.0025683784'},
#  {'rank': 952,
#   'code': 'KR7232080002',
#   'name': 'TIGER 코스닥150',
#   'symbolCode': 'A232080',
#   'tradePrice': 13455.0,
#   'change': 'RISE',
#   'changePrice': 105.0,
#   'changeRate': 0.0078651685,
#   'marketCap': 96606900000,
#   'listedShareCount': 7180000,
#   'foreignRatio': '0.0118910864'},
#  {'rank': 953,
#   'code': 'KR7433330008',
#   'name': 'SOL 미국S&P500',
#   'symbolCode': 'A433330',
#   'tradePrice': 15535.0,
#   'change': 'RISE',
#   'changePrice': 140.0,
#   'changeRate': 0.0090938616,
#   'marketCap': 96317000000,
#   'listedShareCount': 6200000,
#   'foreignRatio': '5.8871E-5'},
#  {'rank': 954,
#   'code': 'KR7476750005',
#   'name': 'ACE 미국30년국채엔화노출액티브(H)',
#   'symbolCode': 'A476750',
#   'tradePrice': 10095.0,
#   'change': 'FALL',
#   'changePrice': 115.0,
#   'changeRate': 0.0112634672,
#   'marketCap': 95902500000,
#   'listedShareCount': 9500000,
#   'foreignRatio': '7.309474E-4'},
#  {'rank': 955,
#   'code': 'KR7363580002',
#   'name': 'KODEX 200IT TR',
#   'symbolCode': 'A363580',
#   'tradePrice': 12725.0,
#   'change': 'RISE',
#   'changePrice': 130.0,
#   'changeRate': 0.0103215562,
#   'marketCap': 95437500000,
#   'listedShareCount': 7500000,
#   'foreignRatio': '2.667E-7'},
#  {'rank': 956,
#   'code': 'KR7438080004',
#   'name': 'ACE 미국S&P500채권혼합액티브',
#   'symbolCode': 'A438080',
#   'tradePrice': 11605.0,
#   'change': 'RISE',
#   'changePrice': 5.0,
#   'changeRate': 0.0004310345,
#   'marketCap': 95161000000,
#   'listedShareCount': 8200000,
#   'foreignRatio': '3.5E-5'},
#  {'rank': 957,
#   'code': 'KR7002450005',
#   'name': '삼익악기',
#   'symbolCode': 'A002450',
#   'tradePrice': 1049.0,
#   'change': 'FALL',
#   'changePrice': 3.0,
#   'changeRate': 0.002851711,
#   'marketCap': 94966929835,
#   'listedShareCount': 90530915,
#   'foreignRatio': '0.0140772796'},
#  {'rank': 958,
#   'code': 'KRG570000502',
#   'name': '한투 S&P500 선물 ETN',
#   'symbolCode': 'Q570050',
#   'tradePrice': 18960.0,
#   'change': 'FALL',
#   'changePrice': 120.0,
#   'changeRate': 0.0062893082,
#   'marketCap': 94800000000,
#   'listedShareCount': 5000000,
#   'foreignRatio': '0.0'},
#  {'rank': 959,
#   'code': 'KRG570001039',
#   'name': '한투 인버스2X 나스닥100 ETN B',
#   'symbolCode': 'Q570103',
#   'tradePrice': 9470.0,
#   'change': 'FALL',
#   'changePrice': 330.0,
#   'changeRate': 0.0336734694,
#   'marketCap': 94700000000,
#   'listedShareCount': 10000000,
#   'foreignRatio': '0.0'},
#  {'rank': 960,
#   'code': 'KR7480030006',
#   'name': 'ACE 미국500 15%프리미엄분배(합성)',
#   'symbolCode': 'A480030',
#   'tradePrice': 10065.0,
#   'change': 'RISE',
#   'changePrice': 70.0,
#   'changeRate': 0.0070035018,
#   'marketCap': 94611000000,
#   'listedShareCount': 9400000,
#   'foreignRatio': '9.574E-7'},
#  {'rank': 961,
#   'code': 'KR7096771001',
#   'name': 'SK이노베이션우',
#   'symbolCode': 'A096775',
#   'tradePrice': 75700.0,
#   'change': 'RISE',
#   'changePrice': 100.0,
#   'changeRate': 0.0013227513,
#   'marketCap': 94505848200,
#   'listedShareCount': 1248426,
#   'foreignRatio': '0.1189169402'},
#  {'rank': 962,
#   'code': 'KR7426030003',
#   'name': 'TIMEFOLIO 미국나스닥100액티브',
#   'symbolCode': 'A426030',
#   'tradePrice': 19870.0,
#   'change': 'RISE',
#   'changePrice': 250.0,
#   'changeRate': 0.0127420999,
#   'marketCap': 94183800000,
#   'listedShareCount': 4740000,
#   'foreignRatio': '2.527426E-4'},
#  {'rank': 963,
#   'code': 'KR7007280001',
#   'name': '한국특강',
#   'symbolCode': 'A007280',
#   'tradePrice': 1545.0,
#   'change': 'FALL',
#   'changePrice': 9.0,
#   'changeRate': 0.0057915058,
#   'marketCap': 93956565495,
#   'listedShareCount': 60813311,
#   'foreignRatio': '0.0050166813'},
#  {'rank': 964,
#   'code': 'KR7101140002',
#   'name': '인바이오젠',
#   'symbolCode': 'A101140',
#   'tradePrice': 9340.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 93812977440,
#   'listedShareCount': 10044216,
#   'foreignRatio': '0.0021916096'},
#  {'rank': 965,
#   'code': 'KR7055490007',
#   'name': '테이팩스',
#   'symbolCode': 'A055490',
#   'tradePrice': 19640.0,
#   'change': 'RISE',
#   'changePrice': 270.0,
#   'changeRate': 0.0139390811,
#   'marketCap': 93675926000,
#   'listedShareCount': 4769650,
#   'foreignRatio': '0.0547788622'},
#  {'rank': 966,
#   'code': 'KR7438570004',
#   'name': 'SOL 국고채10년',
#   'symbolCode': 'A438570',
#   'tradePrice': 109190.0,
#   'change': 'FALL',
#   'changePrice': 20.0,
#   'changeRate': 0.0001831334,
#   'marketCap': 93575830000,
#   'listedShareCount': 857000,
#   'foreignRatio': '0.0'},
#  {'rank': 967,
#   'code': 'KRG520000578',
#   'name': '미래에셋 인버스 2X 코스닥150 선물 ETN',
#   'symbolCode': 'Q520057',
#   'tradePrice': 6220.0,
#   'change': 'FALL',
#   'changePrice': 110.0,
#   'changeRate': 0.0173775671,
#   'marketCap': 93300000000,
#   'listedShareCount': 15000000,
#   'foreignRatio': '0.0'},
#  {'rank': 968,
#   'code': 'KR7245340005',
#   'name': 'TIGER 미국다우존스30',
#   'symbolCode': 'A245340',
#   'tradePrice': 26790.0,
#   'change': 'RISE',
#   'changePrice': 155.0,
#   'changeRate': 0.0058194106,
#   'marketCap': 93229200000,
#   'listedShareCount': 3480000,
#   'foreignRatio': '0.0'},
#  {'rank': 969,
#   'code': 'KR7078000007',
#   'name': '텔코웨어',
#   'symbolCode': 'A078000',
#   'tradePrice': 10070.0,
#   'change': 'FALL',
#   'changePrice': 50.0,
#   'changeRate': 0.0049407115,
#   'marketCap': 93047575390,
#   'listedShareCount': 9240077,
#   'foreignRatio': '0.008632612'},
#  {'rank': 970,
#   'code': 'KR7009200007',
#   'name': '무림페이퍼',
#   'symbolCode': 'A009200',
#   'tradePrice': 2235.0,
#   'change': 'RISE',
#   'changePrice': 20.0,
#   'changeRate': 0.0090293454,
#   'marketCap': 92996807850,
#   'listedShareCount': 41609310,
#   'foreignRatio': '0.0233595799'},
#  {'rank': 971,
#   'code': 'KR7475270005',
#   'name': 'ACE 5월만기자동연장회사채AA-이상액티브',
#   'symbolCode': 'A475270',
#   'tradePrice': 10250.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 92967500000,
#   'listedShareCount': 9070000,
#   'foreignRatio': '0.0'},
#  {'rank': 972,
#   'code': 'KR7395290000',
#   'name': 'HANARO Fn K-POP&미디어',
#   'symbolCode': 'A395290',
#   'tradePrice': 5920.0,
#   'change': 'RISE',
#   'changePrice': 5.0,
#   'changeRate': 0.0008453085,
#   'marketCap': 92944000000,
#   'listedShareCount': 15700000,
#   'foreignRatio': '7.97452E-5'},
#  {'rank': 973,
#   'code': 'KR7139230007',
#   'name': 'TIGER 200 중공업',
#   'symbolCode': 'A139230',
#   'tradePrice': 5085.0,
#   'change': 'RISE',
#   'changePrice': 65.0,
#   'changeRate': 0.0129482072,
#   'marketCap': 92445300000,
#   'listedShareCount': 18180000,
#   'foreignRatio': '0.0012051155'},
#  {'rank': 974,
#   'code': 'KR7434060000',
#   'name': 'KODEX TDF2050액티브',
#   'symbolCode': 'A434060',
#   'tradePrice': 13185.0,
#   'change': 'RISE',
#   'changePrice': 125.0,
#   'changeRate': 0.0095712098,
#   'marketCap': 92295000000,
#   'listedShareCount': 7000000,
#   'foreignRatio': '0.0'},
#  {'rank': 975,
#   'code': 'KR7465350007',
#   'name': 'RISE 2차전지TOP10인버스(합성)',
#   'symbolCode': 'A465350',
#   'tradePrice': 31085.0,
#   'change': 'RISE',
#   'changePrice': 5.0,
#   'changeRate': 0.0001608752,
#   'marketCap': 91700750000,
#   'listedShareCount': 2950000,
#   'foreignRatio': '0.1211311864'},
#  {'rank': 976,
#   'code': 'KR7278240007',
#   'name': 'RISE 코스닥150선물레버리지',
#   'symbolCode': 'A278240',
#   'tradePrice': 10660.0,
#   'change': 'RISE',
#   'changePrice': 175.0,
#   'changeRate': 0.0166905103,
#   'marketCap': 91462800000,
#   'listedShareCount': 8580000,
#   'foreignRatio': '0.0'},
#  {'rank': 977,
#   'code': 'KR7002460004',
#   'name': 'HS화성',
#   'symbolCode': 'A002460',
#   'tradePrice': 9010.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 91451500000,
#   'listedShareCount': 10150000,
#   'foreignRatio': '0.0174608867'},
#  {'rank': 978,
#   'code': 'KR7000101006',
#   'name': '유한양행우',
#   'symbolCode': 'A000105',
#   'tradePrice': 77400.0,
#   'change': 'FALL',
#   'changePrice': 2400.0,
#   'changeRate': 0.030075188,
#   'marketCap': 91404756000,
#   'listedShareCount': 1180940,
#   'foreignRatio': '0.0149237048'},
#  {'rank': 979,
#   'code': 'KR7004910006',
#   'name': '조광페인트',
#   'symbolCode': 'A004910',
#   'tradePrice': 7120.0,
#   'change': 'RISE',
#   'changePrice': 70.0,
#   'changeRate': 0.009929078,
#   'marketCap': 91136000000,
#   'listedShareCount': 12800000,
#   'foreignRatio': '0.0048746094'},
#  {'rank': 980,
#   'code': 'KR7036580009',
#   'name': '팜스코',
#   'symbolCode': 'A036580',
#   'tradePrice': 2480.0,
#   'change': 'RISE',
#   'changePrice': 20.0,
#   'changeRate': 0.0081300813,
#   'marketCap': 91085298640,
#   'listedShareCount': 36727943,
#   'foreignRatio': '0.0038230292'},
#  {'rank': 981,
#   'code': 'KR7114820004',
#   'name': 'TIGER 국채3년',
#   'symbolCode': 'A114820',
#   'tradePrice': 107670.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 90442800000,
#   'listedShareCount': 840000,
#   'foreignRatio': '9.7619E-5'},
#  {'rank': 982,
#   'code': 'KR7000220004',
#   'name': '유유제약',
#   'symbolCode': 'A000220',
#   'tradePrice': 5310.0,
#   'change': 'FALL',
#   'changePrice': 10.0,
#   'changeRate': 0.0018796992,
#   'marketCap': 90441783810,
#   'listedShareCount': 17032351,
#   'foreignRatio': '0.0277301119'},
#  {'rank': 983,
#   'code': 'KR7421320003',
#   'name': 'PLUS 우주항공&UAM',
#   'symbolCode': 'A421320',
#   'tradePrice': 13270.0,
#   'change': 'FALL',
#   'changePrice': 95.0,
#   'changeRate': 0.0071081182,
#   'marketCap': 90236000000,
#   'listedShareCount': 6800000,
#   'foreignRatio': '4.412E-7'},
#  {'rank': 984,
#   'code': 'KR7058860008',
#   'name': 'KTis',
#   'symbolCode': 'A058860',
#   'tradePrice': 2585.0,
#   'change': 'RISE',
#   'changePrice': 15.0,
#   'changeRate': 0.0058365759,
#   'marketCap': 89963170000,
#   'listedShareCount': 34802000,
#   'foreignRatio': '0.0253303833'},
#  {'rank': 985,
#   'code': 'KR7005740006',
#   'name': '크라운해태홀딩스',
#   'symbolCode': 'A005740',
#   'tradePrice': 6040.0,
#   'change': 'RISE',
#   'changePrice': 20.0,
#   'changeRate': 0.0033222591,
#   'marketCap': 89677975880,
#   'listedShareCount': 14847347,
#   'foreignRatio': '0.0239691306'},
#  {'rank': 986,
#   'code': 'KR7157490004',
#   'name': 'TIGER 소프트웨어',
#   'symbolCode': 'A157490',
#   'tradePrice': 7470.0,
#   'change': 'RISE',
#   'changePrice': 30.0,
#   'changeRate': 0.0040322581,
#   'marketCap': 89191800000,
#   'listedShareCount': 11940000,
#   'foreignRatio': '2.722781E-4'},
#  {'rank': 987,
#   'code': 'KR7437080005',
#   'name': 'KODEX 미국종합채권ESG액티브(H)',
#   'symbolCode': 'A437080',
#   'tradePrice': 102805.0,
#   'change': 'FALL',
#   'changePrice': 50.0,
#   'changeRate': 0.0004861212,
#   'marketCap': 89029130000,
#   'listedShareCount': 866000,
#   'foreignRatio': '0.0'},
#  {'rank': 988,
#   'code': 'KR7067830000',
#   'name': '세이브존I&C',
#   'symbolCode': 'A067830',
#   'tradePrice': 2160.0,
#   'change': 'RISE',
#   'changePrice': 25.0,
#   'changeRate': 0.0117096019,
#   'marketCap': 88648333200,
#   'listedShareCount': 41040895,
#   'foreignRatio': '0.0845790278'},
#  {'rank': 989,
#   'code': 'KR7325010007',
#   'name': 'KODEX 성장주',
#   'symbolCode': 'A325010',
#   'tradePrice': 14680.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 88080000000,
#   'listedShareCount': 6000000,
#   'foreignRatio': '0.0'},
#  {'rank': 990,
#   'code': 'KR7461490005',
#   'name': 'RISE 글로벌자산배분액티브',
#   'symbolCode': 'A461490',
#   'tradePrice': 11925.0,
#   'change': 'RISE',
#   'changePrice': 50.0,
#   'changeRate': 0.0042105263,
#   'marketCap': 87648750000,
#   'listedShareCount': 7350000,
#   'foreignRatio': '3.5102E-5'},
#  {'rank': 991,
#   'code': 'KRG500000820',
#   'name': '신한 블룸버그 2X 천연가스 선물 ETN',
#   'symbolCode': 'Q500082',
#   'tradePrice': 5835.0,
#   'change': 'RISE',
#   'changePrice': 555.0,
#   'changeRate': 0.1051136364,
#   'marketCap': 87525000000,
#   'listedShareCount': 15000000,
#   'foreignRatio': '0.0'},
#  {'rank': 992,
#   'code': 'KR7267770006',
#   'name': 'TIGER 200선물레버리지',
#   'symbolCode': 'A267770',
#   'tradePrice': 14520.0,
#   'change': 'RISE',
#   'changePrice': 320.0,
#   'changeRate': 0.0225352113,
#   'marketCap': 87120000000,
#   'listedShareCount': 6000000,
#   'foreignRatio': '0.0'},
#  {'rank': 993,
#   'code': 'KR7465770006',
#   'name': 'STX그린로지스',
#   'symbolCode': 'A465770',
#   'tradePrice': 12090.0,
#   'change': 'FALL',
#   'changePrice': 10.0,
#   'changeRate': 0.0008264463,
#   'marketCap': 86697776880,
#   'listedShareCount': 7171032,
#   'foreignRatio': '0.0142570832'},
#  {'rank': 994,
#   'code': 'KR7145210001',
#   'name': '다이나믹디자인',
#   'symbolCode': 'A145210',
#   'tradePrice': 4995.0,
#   'change': 'FALL',
#   'changePrice': 135.0,
#   'changeRate': 0.0263157895,
#   'marketCap': 86418959535,
#   'listedShareCount': 17301093,
#   'foreignRatio': '0.0'},
#  {'rank': 995,
#   'code': 'KRG520000636',
#   'name': '미래에셋 -0.5X S&P500 VIX S/T선물 ETN(H)',
#   'symbolCode': 'Q520063',
#   'tradePrice': 34510.0,
#   'change': 'RISE',
#   'changePrice': 705.0,
#   'changeRate': 0.0208549031,
#   'marketCap': 86275000000,
#   'listedShareCount': 2500000,
#   'foreignRatio': '0.0'},
#  {'rank': 996,
#   'code': 'KR7044820009',
#   'name': '코스맥스비티아이',
#   'symbolCode': 'A044820',
#   'tradePrice': 8980.0,
#   'change': 'FALL',
#   'changePrice': 110.0,
#   'changeRate': 0.0121012101,
#   'marketCap': 86243210580,
#   'listedShareCount': 9603921,
#   'foreignRatio': '0.0370026992'},
#  {'rank': 997,
#   'code': 'KR7452250004',
#   'name': 'ACE 미국30년국채선물레버리지(합성 H)',
#   'symbolCode': 'A452250',
#   'tradePrice': 7195.0,
#   'change': 'FALL',
#   'changePrice': 15.0,
#   'changeRate': 0.0020804438,
#   'marketCap': 85980250000,
#   'listedShareCount': 11950000,
#   'foreignRatio': '4.632636E-4'},
#  {'rank': 998,
#   'code': 'KR7480040005',
#   'name': 'ACE 미국반도체15%프리미엄분배(합성)',
#   'symbolCode': 'A480040',
#   'tradePrice': 10440.0,
#   'change': 'RISE',
#   'changePrice': 155.0,
#   'changeRate': 0.015070491,
#   'marketCap': 85608000000,
#   'listedShareCount': 8200000,
#   'foreignRatio': '2.120732E-4'},
#  {'rank': 999,
#   'code': 'KRG700000208',
#   'name': '하나 블룸버그 -2X 천연가스 선물 ETN(H)',
#   'symbolCode': 'Q700020',
#   'tradePrice': 85535.0,
#   'change': 'EVEN',
#   'changePrice': 0.0,
#   'changeRate': 0.0,
#   'marketCap': 85535000000,
#   'listedShareCount': 1000000,
#   'foreignRatio': '0.0'},
#  {'rank': 1000,
#   'code': 'KR7150460004',
#   'name': 'TIGER 중국소비테마',
#   'symbolCode': 'A150460',
#   'tradePrice': 6310.0,
#   'change': 'RISE',
#   'changePrice': 25.0,
#   'changeRate': 0.0039777247,
#   'marketCap': 85185000000,
#   'listedShareCount': 13500000,
#   'foreignRatio': '0.0012139259'},
#  ...]
